# %% [markdown]
# # spaCy Tutorial

# %% [markdown]
# **(C) 2019 by [Damir Cavar](http://damir.cavar.me/)**

# %% [markdown]
# **Version:** 1.3, November 2019

# %% [markdown]
# **Download:** This and various other Jupyter notebooks are available from my [GitHub repo](https://github.com/dcavar/python-tutorial-for-ipython).

# %% [markdown]
# This is a tutorial related to the L665 course on Machine Learning for NLP focusing on Deep Learning, Spring 2018 at Indiana University. The following tutorial assumes that you are using a newer distribution of Python 3 and spaCy 2.2 or newer.

# %% [markdown]
# ## Introduction to spaCy

# %% [markdown]
# Follow the instructions on the [spaCy homepage](https://spacy.io/usage/) about installation of the module and language models. Your local spaCy module is correctly installed, if the following command is successfull:

# %%
import spacy

# %%
# !python -m spacy download es_core_news_md
# Out:
# Collecting es_core_news_md==2.2.5 from https://github.com/explosion/spacy-models/releases/download/es_core_news_md-2.2.5/es_core_news_md-2.2.5.tar.gz#egg=es_core_news_md==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-2.2.5/es_core_news_md-2.2.5.tar.gz (78.4MB)
# Requirement already satisfied: spacy>=2.2.2 in c:\users\falconrr\anaconda3\lib\site-packages (from es_core_news_md==2.2.5) (2.2.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (3.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (0.9.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (1.16.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (2.0.2)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (41.4.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (0.23)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (7.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\falconrr\anaconda3\lib\site-packages (from spacy>=2.2.2->es_core_news_md==2.2.5) (2.22.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\falconrr\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->es_core_news_md==2.2.5) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\falconrr\anaconda3\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->es_core_news_md==2.2.5) (4.36.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\falconrr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_md==2.2.5) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\falconrr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_md==2.2.5) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\falconrr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_md==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\falconrr\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_md==2.2.5) (2019.9.11)
# Requirement already satisfied: more-itertools in c:\users\falconrr\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.2->es_core_news_md==2.2.5) (7.2.0)
# Building wheels for collected packages: es-core-news-md
#   Building wheel for es-core-news-md (setup.py): started
#   Building wheel for es-core-news-md (setup.py): finished with status 'done'
#   Created wheel for es-core-news-md: filename=es_core_news_md-2.2.5-cp37-none-any.whl size=79649485 sha256=77858dfdbe2d8db9089e85a4a1b2a11f8e57e3cef5eeb973edc7dc1467a92f75
#   Stored in directory: C:\Users\FalconRR\AppData\Local\Temp\pip-ephem-wheel-cache-8apll7zl\wheels\b7\bb\a3\29ab5cf80c2c0a8fa0f2af8402fdace3f159e8265f0fdcbcdb
# Successfully built es-core-news-md
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-2.2.5
# [+] Download and installation successful
# You can now load the model via spacy.load('es_core_news_md')

# %% [markdown]
# We can load the English NLP pipeline in the following way:

# %%
import nltk

# %%
# !python -m spacy link es_core_news_md es2
# Out:
# symbolic link created for C:\Users\FalconRR\Anaconda3\lib\site-packages\spacy\data\es2 <<===>> C:\Users\FalconRR\Anaconda3\lib\site-packages\es_core_news_md
# [+] Linking successful
# C:\Users\FalconRR\Anaconda3\lib\site-packages\es_core_news_md -->
# C:\Users\FalconRR\Anaconda3\lib\site-packages\spacy\data\es2
# You can now load the model via spacy.load('es2')

# %%
nlp = spacy.load('es2')

# %%
tu = open("Files/tuunique2.txt", mode='r', encoding='utf-8')
texttu = tu.read()
tu.close()
print(texttu[:300], "...")
# Out:
# ﻿Má, te estoy contando una noticia muy importante y sólo me preguntas si pagué mi tarjeta. Qué _____ que eres.
# Ma, por favor si yo confío en ti, te cuento mis cosas, es para que me aconseje, no para que estés todo impaciente...por todo.
#
# Amigo? ...Mis papás y a ellos no les gusta el desorden. Entonc ...

# %%
doc1 = nlp(texttu)
for token in doc1:
    print(token.text)
# Out:
# ﻿Má
# ,
# te
# estoy
# contando
# una
# noticia
# muy
# importante
# y
# sólo
# me
# preguntas
# si
# pagué
# mi
# tarjeta
# .
# Qué
# _
# _
# _
# _
# _
# que
# eres
# .
#
#
# Ma
# ,
# por
# favor
# si
# yo
# confío
# en
# ti
# ,
# te
# cuento
# mis
# cosas
# ,
# es
# para
# que
# me
# aconseje
# ,
# no
# para
# que
# estés
# todo
# impaciente
# ...
# por
# todo
# .
#
#
#
# Amigo
# ?
# ...
# Mis
# papás
# y
# a
# ellos
# no
# les
# gusta
# el
# desorden
# .
# Entonces
# necesito
# que
# me
# ayudes
# por
# favor
# a
# organizar
# las
# cosas
# rápido
# .
#
#
#
# Soy
# consciente
# del
# estado
# de
# salud
# en
# el
# que
# tienes
# y
# me
# gustaría
# verte
# mejor
# ,
# poder
# seguir
# charlando
# ,
# seguir
# jugando
# naipes
# .
# charlamos
# pues
# entonces
# para
# que
# mejores
# tu
# salud
# ,
# me
# gustaría
# que
# te
# tomes
# las
# pastillas
# y
# que
# no
# fingas
# que
# las
# botes
# .
# La
# verdad
# es
# muy
# importante
# para
# mí
# que
# estés
# bien
# porque
# me
# gustar
# estar
# contigo
# .
#
#
# Ma
# ,
# hola
# te
# acuerdas
# de
# las
# galletas
# que
# preparamos
# en
# las
# vacaciones
# pasadas
# es
# que
# quiero
# volverlas
# a
# preparar
# porque
#
# a
# mi
# novio
# le
# gustaron
# mucho
# pero
# no
# recuerdo
# cómo
# hacerlas
# ,
# ¿
# me
# puedes
# ayudarme
# ?
#
#
# Hola
# te
# quería
# preguntar
# qué
# día
# te
# queda
# fácil
# reunirnos
# para
# empezar
# con
# las
# investigaciones
# de
# química
# que
# nos
# ...
# para
# que
# no
# nos
# dejemos
# correr
# del
# tiempo
# y
# podamos
# me
# ...
# me
# avisas
# o
# a
# qué
# horas
#
#
# He
# visto
# que
# te
# gustan
# mucho
# los
# perros
# .
# ¿
# cuántos
# perros
# tienes
# ?
#
#
# ¿
# Madre
# por
# qué
# no
# primero
# preguntas
# por
# mí
# ?
#
#
# Ten
# más
# cuidado
# .
#
#
# Madre
# por
# favor
# préstame
# más
# atención
# .
#
#
# Por
# favor
# ayúdame
# a
# limpiar
# que
# viene
# gente
# para
# mi
# casa
# .
#
#
# Por
# favor
# tómate
# las
# pastillas
# que
# son
# bien
# para
# ti
# .
#
#
# Madre
# ,
# quiero
# que
# me
# enseñes
# a
# hacer
# las
# galletas
# especiales
# que
# quiero
# tener
# un
# presente
# con
# mis
# amigos
# .
#
#
# ¿
# Cuándo
# quieres
# que
# empecemos
# a
# hacer
# los
# trabajos
# para
# adelantar
# ?
#
#
# ¿
# Solamente
# tienes
# este
# o
# tienes
# más
# ?
#
#
# Es
# que
# no
# recuerdo
# tu
# nombre
# .
# ¿
# Me
# lo
# puedes
# volver
# a
# decir
# por
# favor
# ?
#
#
# Oye
# presta
# atención
# ,
# mira
# que
# estamos
# acá
# .
# Todos
# queremos
# ver
# .
#
#
# ¿
# Ma
# qué
# pasó
# ?
# ¿
# Te
# dije
# algo
# que
# te
# molesta
# o
# qué
# pasa
# contigo
# que
# estás
# tan
# rara
# ?
#
#
# Hey
# ,
# en
# la
# próxima
# ,
# me
# pasas
# la
# pelota
# .
#
#
# Mami
# ,
# te
# acuerdas
# el
# año
# pasado
# hicimos
# unas
# galletas
# súper
# ricas
# a
# mi
# mejor
# amiga
# .
# ¿
# Será
# que
# me
# ayudarías
# otra
# vez
# a
# hacerselas
# ?
#
#
# Hola
# ,
# ¿
# cuándo
# tienes
# tiempo
# para
# hacer
# el
# trabajo
# ?
#
#
# ¿
# Y
# este
# perrito
# tan
# lindo
# ,
# también
# es
# tuyo
# o
# no
# lo
# conoces
# ?
#
#
# No
# puedes
# hacer
# eso
# .
# Si
# te
# ven
# ,
# te
# van
# a
# regañar
# .
# Además
# ,
# es
# por
# tu
# bien
# .
# No
# te
# las
# están
# dando
# para
# que
# te
# enfermes
# más
# .
#
#
# Ay
# respeta
# por
# favor
# .
#
#
# ¿
# Será
# que
# me
# puedes
# ayudar
# a
# organizar
# un
# poco
# esta
# casa
# ?
#
#
# Vamos
# ,
# pásala
# .
#
#
# Mamá
# a
# mi
# amiga
# le
# gustan
# tus
# galletas
# .
# ¿
# Será
# que
# me
# indicas
# cómo
# se
# hacen
# ?
#
#
# Debemos
# reunirnos
# lo
# más
# pronto
# posible
# .
# Mira
# a
# ver
# cuándo
# y
# me
# avisas
# .
#
#
# ¿
# Por
# qué
# eres
# tan
# traicionera
# ?
# ¿
# Por
# qué
# no
# me
# hablaste
# con
# la
# verdad
# de
# un
# comienzo
# de
# que
# me
# ibas
# a
# reventar
# ?
# Eso
# no
# es
# correcto
# ,
# una
# amiga
# no
# le
# hace
# eso
# a
# una
# compañera
# .
#
#
# ¿
# Mamá
# qué
# te
# pasa
# ultimamente
# que
# ya
# no
# me
# escuchas
# que
# ya
# no
# eres
# conmigo
# la
# misma?Cuéntame
# .
# ¿
# Tienes
# algún
# problema
# o
# estás
# enferma
# ?
#
#
# Pero
# recoge
# el
# reblujo
# .
# Mira
# que
# vienen
# mis
# papás
# y
# no
# les
# gusta
# el
# desorden
# .
# Entonces
# colabórame
# .
# Ayúdame
# ,
# colabórame
# con
# eso
# .
# Para
# que
# ...
# cuando
# mis
# papas
# lleguen
# ,
# encuentran
# una
# casa
# organizada
# …
# .
#
#
#
# Pero
# mira
# que
# si
# no
# te
# tomas
# la
# drogra
# ,
# te
# vas
# a
# enfermar
# .
# No
# finja
# delante
# de
# mí
# porque
# no
# voy
# a
# estar
# todo
# el
# tiempo
# contigo
# .
#
#
# ¿
# Es
# que
# acaso
# no
# te
# caigo
# bien
# ?
# Por
# favor
# pásame
# la
# pelota
# o
# al
# menos
# trata
# de
# compartirla
# o
# dime
# si
# es
# que
# no
# te
# caigo
# bien
# y
# ya
# punto
# .
# Pero
# dímelo
# con
# sinceridad
# .
#
#
# Mamá
# como
# tú
# te
# acuerdas
# de
# las
# galletas
# que
# tú
# preparabas
# tan
# deliciosas
# ,
# dame
# tu
# receta
# que
# yo
# quiero
# volverlas
# a
# preparar
# para
# mis
# amigas
# .
#
#
# Eh
# profe
# ,
# ¿
# para
# que
# no
# llegastes
# si
# me
# citaste
# tan
# temprano
# ?
# Me
# parece
# una
# falta
# de
# respeto
# ,
# ya
# que
# yo
# tomé
# mi
# tiempo
# y
# si
# no
# llegaste
# entonces
# no
# era
# tan
# importante
# para
# ti
# .
#
#
# Mami
# ,
# si
# quieres
# que
# yo
# te
# tenga
# teniendo
# la
# misma
# confianza
# deberías
# de
# no
# criticarme
# tanto
# .
# Para
# así
# ,
# tener
# una
# mejor
# relación
# .
#
#
# Mhh
# por
# favor
# señora
# ,
# tome
# su
# medicamente
# .
# Mira
# que
# son
# recomendados
# por
# el
# médico
# y
# si
# no
# te
# los
# tomas
# te
# puedes
# morir
# .
#
#
# Sí
# .
# Si
# me
# vas
# a
# hacer
# un
# favor
# ,
# cómo
# me
#
# vas
# a
# echar
# al
# agua
# .
# Pues
# …
# no
# hay
# razón
# para
# que
# …
# no
# hay
# razón
# para
# que
# me
# …
# me
# prerjudiques
# así
# ,
# si
# ,
# si
# me
# hiciste
# el
# favor
# tenía
# que
# hacelo
# ..
# Pues
# tenías
# que
# hacerlo
# bien
# ,
# aunque
# sé
# que
# eso
# está
# mal
# pero
# de
# igual
# manera
# ...
# eso
# me
# afecta
# demasiado
# .
#
#
# Que
# por
# qué
# ,
# pues
# por
# qué
# me
# hacés
# eso
# ?
# Ya
# ves
# que
# estoy
# en
# finales
# y
# …
# y
# no
# tengo
# tiempo
# y
# me
# pones
# a
# …
# a
# ir
# hasta
# el
# otro
# lado
# del
# campus
# y
# bien
# temprano
# .
# Pues
# y
# a
# parte
# de
# eso
# me
# toca
# esperate
# dos
# horas
# .
# Vos
# sabé
# que
# eso
# es
# un
# momento
# donde
# yo
# debería
# estar
# estudiando
# y
# usted
# debería
# estar
# preocupado
# por
# ...
# por
# cosas
# como
# el
# ...
# el
# final
# .
# Pues
# deberías
# de
# tener
# más
# consideración
# con
# mi
# tiempo
# y
# no
# deberías
# de
# jugar
# así
# .
#
#
# Hey
# señora
# ,
# pues
# que
# pena
# contigo
# ser
# tan
# entrometido
# en
# tus
# asuntos
# pero
# he
# notado
# que
# has
# botado
# tus
# pastillas
# varias
# veces
# y
# pues
# la
# verdad
# no
# estás
# muy
# bien
# de
# salud
# .
# Deberías
# replantear
# botar
# esas
# pastillas
# .
# Eso
# …
# pues
# mirá
# que
# eso
# es
# por
# tu
# bien
# .
# Vos
# verás
# y
# todo
# ,
# pero
# ...
# pero
# pues
# con
# las
# salud
# no
# se
# puede
# jugar
# .
# Deberías
# ,
# debería
# de
# tomartelas
# muy
# en
# serio
# .
# Y
# ...
# y
# espero
# ,
# pues
# espero
# no
# volvete
# a
# ver
# porque
# ,
# porque
# de
# lo
# contrario
# voy
# a
# avisar
# porque
# es
# que
# es
# jugar
# con
# tu
# salud
# .
#
#
# Esas
# pastillas
# son
# para
# tu
# salud
# .
# Espero
# que
# lo
# hagas
# a
# conciencia
# .
#
#
# Dime
# qué
# fechas
# tienes
# disponibles
# .
# Haber
# en
# cuál
# coincidimos
# .
#
#
# Discúlpame
# ,
# tengo
# muchas
# cosas
# en
# la
# cabeza
# para
# este
# entrenamiento
# .
# ¿
# Cómo
# es
# que
# te
# llamas
# ?
#
#
# Hola
# ,
# por
# qué
# no
# me
# pasas
# la
# pelota
# en
# la
# siguiente
# forma
# para
# ver
# si
# nos
# defendemos
# .
#
#
# Hola
# ,
# me
# recuerdas
# cómo
# es
# tu
# nombre
# que
# lo
# olvidé
# ?
# Lo
# siento
# .
#
#
# Mami
# ,
# por
# qué
# cambias
# tanto
# ?
# Sí
# ?
# Primero
# tenía
# paciencia
# y
# esperabas
# y
# quería
# que
# conversábamos
# .
#
#
# Nena
# ,
# ayúdame
# a
# arreglar
# la
# casa
# .
# Acuérdate
# que
# aquí
# son
# muy
# ordenados
# y
# me
# gusta
# tener
# todo
# en
# orden
# y
# que
# se
# vea
# bien
# buena
# …
# .
#
#
#
# Cómo
# sigues
# con
# tu
# tratamiento
# ?
# Te
# veo
# muy
# bien
# .
#
#
# No
# pá
# ,
# por
# tu
# culpa
# me
# he
# demorado
# más
# buscando
# mi
# mochila
# …
# qué
# pereza
# .
# Por
# favor
# ,
# no
# me
# vuelvas
# a
# poner
# ahí
# .
#
#
# Amigo
# ,
# te
# acabo
# de
# ver
# en
# facebook
# comiendo
# sushi
# .
# Cuando
# te
# pedí
# el
# dinero
# ,
# me
# dijiste
# que
# no
# lo
# tenías
# .
# ¿
# Por
# qué
# ?
# Me
# parece
# una
# falta
# de
# respeto
# que
# seas
# capaz
# de
# pagarme
# el
# dinero
# que
# te
# presté
# y
# te
# lo
# gastes
# en
# otras
# cosas
# .
#
#
# Disculpa
# pero
# yo
# fui
# muy
# clara
# cuando
# te
# pedí
# mi
# plato
# que
# no
# trajera
# berenjena
# porque
# soy
# alérgica
# .
# ¿
# Entonces
# me
# puedes
# cambiar
# el
# plato
# por
# favor
# ?
#
# porque
# no
# lo
# puedo
# comer
# .
#
#
# La
# verdad
# no
# me
# gustó
# cómo
# le
# gritaste
# a
# mi
# perrro
# aquel
# día
# que
# vino
# tu
# amigo
# .
# Por
# favor
# no
# lo
# vuelvas
# a
# hacer
# que
# la
# verdad
# me
# molestó
# demasiado
# .
#
#
#
# Papi
# por
# favor
# hagas
# eso
# ,
# me
# retrasas
# .
#
#
#
# ¿
# Por
# qué
# no
# me
# pagas
# mi
# dinero
# ?
#
#
# Debes
# prestar
# más
# atención
# a
# lo
# que
# te
# dije
# .
# Me
# hace
# daño
# .
#
#
# Por
# favor
# colabórame
# .
#
#
# Cambiemos
# de
# género
# .
# La
# gente
# no
# le
# está
# gustando
# .
# Pon
# esta
# en
#
# especial
# .
#
#
#
# Sabes
# el
# trabajo
# que
# tengo
# padre
# .
#
#
# ¿
# Qué
# quieres
# que
# hagamos
# ?
#
#
# ¿
# Será
# que
# ya
# tienes
# el
# dinero
# ?
# Es
# que
# en
# verdad
# me
# urge
# tener
# el
# dinero
# .
#
#
# Hola
# qué
# pena
# contigo
# ,
# ¿
# pero
# será
# que
# me
# podrías
# cambiar
# este
# plato
# por
# favor
# ?
# Porque
# te
# dije
# que
# no
# podía
# comer
# berenjena
# sin
# embargo
# aquí
# hay
# un
# pedazo
# de
# berenjena
# .
#
#
# Pa
# ,
# hacéme
# porfis
# un
# favor
# .
# Pues
# es
# que
# mira
# ,
# las
# cajas
# están
# súper
# desorganizadas
# y
# no
# me
# estás
# ayudando
# casi
# .
#
#
# Mira
# es
# que
# no
# me
# gustó
# la
# manera
# en
# que
# trataste
# a
# mi
# perro
# ese
# día
# que
# vino
# tu
# amigo
# y
# la
# verdad
# me
# gustaría
# que
# lo
# trataras
# mejor
# porque
# es
# muy
# lindo
# contigo
# .
#
#
# ¿
# Qué
# pasa
# contigo
# ?
# ¿
# Por
# qué
# estás
# poniendo
# las
# canciones
# tan
# malucas
# ?
#
#
# La
# verdad
# es
# que
# ya
# he
# hablado
# tanto
# de
# mí
# .
# Cuéntame
# tú
# .
# ¿
# Qué
# te
# gustaría
# hacer
# para
# tu
# cumpleaños
# ?
#
#
# ¿
# Y
# tú
# conoces
# al
# novio
# o
# la
# novia
# ?
#
#
# No
# le
# vuelvas
# a
# gritar
# al
# perro
# .
#
#
# ¿
# Puedes
# poner
# otras
# canciones
# ?
# Es
# que
# estas
# están
# como
# maluquitas
# .
#
#
# Recureda
# que
# necesito
# lo
# que
# te
# presté
# .
#
#
# Papá
# mira
# que
# las
# cajas
# están
# marcadas
# para
# que
# vaya
# colocando
# cada
# una
# en
# su
# lugar
# .
#
#
# No
# es
# que
# quieres
# tanto
# a
# los
# perros
# .
#
#
# Papá
# ,
# ¿
# será
# que
# me
# puedes
# ayudar
# con
# esto
# ?
#
#
# Para
# mi
# cumpleaños
# ,
# ¿
# me
# acompañas
# a
# un
# lugar
# muy
# bonito
# ?
#
#
# Por
# favor
# no
# lo
# vuelvas
# a
# coger
# .
# Por
# favor
# no
# me
# mueva
# las
# cosas
# .
#
#
# Papá
# ten
# más
# paciencia
# ,
# mira
# que
# nos
# estamos
# mudando
# y
# hay
# que
# tener
# paciencia
# y
# espera
# que
# todo
# va
# a
# quedar
# bien
# .
# Pero
# ten
# paciencia
# .
#
#
# ¿
# Por
# qué
# no
# fuiste
# sincero
# de
# un
# comienzo
# y
# me
# dijiste
# que
# no
# te
# gustaban
# los
# perros
# que
# te
# gustaban
# los
# gatos
# ?
# ¿
# Entonces
# por
# qué
# vienes
# ahora
# a
# gritar
# a
# mi
# perro
# si
# no
# te
# gustan
# los
# perros
# ?
#
#
# Por
# favor
# presiona
# el
# botón
# para
# que
# yo
# pueda
# pasar
# con
# este
# material
# .
#
#
# Señor
# por
# favor
# ponga
# música
# para
# que
# todos
# lo
# pasemos
# bien
# .
# A
# unos
# les
# gusta
# el
# reggaeton
# a
# otras
# les
# gusta
# la
# ranchera
# y
# a
# otra
# le
# gusta
# la
# de
# valle
# .
# Entonces
# colócate
# un
# disco
# para
# que
# nos
# dé
# gusto
# a
# todos
# ,
# para
# no
# aburrirnos
# .
# Colócame
# un
# disco
# que
# me
# guste
# a
# mí
# .
# Colócame
# nadie
# es
# eterno
# en
# el
# mundo
# y
# lo
# pasamos
# bien
# .
#
#
# Papá
# dime
# el
# nombre
# de
# todo
# los
# antepasados
# de
# mis
# abuelos
# ,
# mis
# bisabuelas
# ,
# mis
# abuelos
# ,
# mis
# bisabuelos
# ,
# mis
# tatarabuelos
# .
# Si
# tú
# lo
# sabes
# ,
# dímelo
# para
# yo
# hacer
# un
# árbol
# genealógico
# .
#
#
# ¿
# Ya
# pensaste
# qué
# quieres
# preparar
# para
# el
# cumpleaños
# ?
# Dime
# .
# Dímelo
# para
# saber
# cómo
# nos
# programos
# los
# dos
# para
# ir
# al
# cumpleaños
# .
#
#
# ¿
# Señor
# cómo
# puedo
# volver
# a
# llegar
# al
# hotel
# ?
# Salí
# de
# compras
# y
# estoy
# enbolatada
# .
# Por
# favor
# dame
# la
# dirección
# y
# ayúdame
# cómo
# llegar
# al
# hotel
# donde
# me
# hospedé
# .
#
#
# Hemos
# estado
# hablando
# de
# todo
# y
# todavía
# no
# me
# dices
# por
# parte
# de
# quién
# viniste
# si
# eres
# conocido
# de
# la
# novia
# o
# eres
# concido
# del
# novio
# .
#
#
# Ehh
# me
# parece
# muy
# mal
# de
# que
# hayas
# traido
# eso
# ,
# sabiendo
# que
# ..
# Desde
# un
# principio
# te
# especifiqué
# que
# estaba
# mal
# y
# que
# no
# podía
# consumir
# este
# tipo
# de
# berenjena
# .
#
#
# Pa
# !
# No
# me
# muevas
# por
# favor
# las
# cajas
# .
# Si
# las
# vas
# a
# mover
# ,
# por
# favor
# tíralas
# organizádamente
# .
#
#
# Parce
# ,
# es
# que
# la
# verda
# .
# Desde
# un
# principio
# yo
# te
# dije
# que
# yo
# tenía
# un
# perro
# y
# deberíamos
# de
# arreglar
# bien
# las
# cosas
# para
# que
# no
# haya
# inconvenientes
# entre
# tú
# y
# yo
# y
# el
# perro
# .
#
#
# Amigo
# ,
# por
# favor
# me
# hundes
# el
# tres
# por
# favor
# .
# Y
# que
# pena
# !
#
#
# Amigo
# y
# a
# ti
# qué
# te
# gustaría
# hacer
# para
# el
# día
# de
# tu
# cumpleaños
# ?
# Podemos
# hacer
# algo
# que
# nos
# guste
# a
# los
# dos
# .
#
#
# Y
# de
# qué
# parte
# vienes
# ?
# Ehhh
# yo
# creo
# que
# vienes
# de
# parte
# del
# esposo
# ,
# no
# ?
#
#
# Hey
# no
# ,
# si
# ,
# si
# yo
# respeto
# ,
# si
# yo
# respeto
# tus
# dos
# mascotas
# ,
# porque
# no
# ,
# porque
# no
# puede
# respetar
# a
# la
# mía
# .
#
# Está
# bien
# ,
# él
# es
# así
# ,
# por
# qué
# no
# lo
# deja
# ser
# cómo
# es
# .
# Si
# el
# perro
# quiere
# saludalo
# ,
# déjalo
# saludar
# .
# Además
# ,
# no
# sé
# si
# a
# él
# le
# moleste
# o
# no.
# Pero
# igual
# ,
# esta
# es
# la
# habitación
# de
# loh
# dos
# y
# así
# son
# las
# cosas
# y
# si
# vos
# me
# dijiste
# que
# ..
# que
# te
# gustaban
# los
# perros
# ,
# entonces
# ,
# no
# hay
# razón
# como
# para
# que
# le
# grités
# al
# mío
# .
# Cómo
# así
# ?
# tiene
# es
# que
# respetar
# lo
# mío
# también
# .
# Y
# al
# perro
# no
# le
# volvás
# a
# gritar
# ...
# que
# dijo
# pues
# ?
#
#
# Qué
# pena
# ,
# me
# puedes
# ayudar
# marcando
# el
# tercer
# piso
# ?
# Es
# que
# desde
# acá
# no
# ,
# no
# me
# alcanza
# .
#
#
# Papá
# ,
# no
# me
# vuelvas
# a
# coger
# la
# mochila
# por
# favor
# .
#
#
# Oye
# ,
# por
# favor
# págame
# .
# Sé
# que
# sí
# tienes
# dinero
# .
#
#
# Papá
# ,
# por
# favor
# organiza
# bien
# las
# cajas
# .
#
#
# Por
# favor
# ,
# pon
# algo
# bailable
# .
#
#
# Perdona
# mi
# indiferencia
# .
# Dime
# qué
# quieres
# hacer
# para
# tu
# cumpleaños
# .
#
#
# Parce
# ,
# qué
# pena
# con
# vos
# ,
# pero
# yo
# dije
# que
# no
# podía
# comer
# berenjena
# .
# ¿
# Me
# lo
# puedes
# cambiar
# por
# otro
# sin
# berenjena
# ?
#
#
# Pá
# ,
# cuidado
# con
# eso
# .
# Por
# favor
# ,
# ponlas
# en
# este
# lugar
# .
# Por
# ahí
# no
# se
# pueden
# poner
# porque
# se
# dañan
# .
# Eso
# es
# muy
# delicado
# .
#
#
# Disculpe
# ,
# será
# que
# me
# puedes
# ayudar
# a
# marcar
# el
# botón
# ?
#
#
# Papá
# ,
# déjame
# que
# yo
# arregle
# …
# que
# yo
# me
# concentre
# y
# organice
# las
# cosas
# .
#
#
# Cuando
# traigas
# animales
# en
# mi
# casa
# ,
# contrólalo
# porque
# si
# no
# ,
# no
# te
# puedo
# admitir
# .
#
#
# Ten
# cuidado
# que
# puede
# ocurrir
# un
# accidente
# .
#
#
# La
# fiesta
# está
# muy
# sabrosa
# pero
# quiero
# que
# me
# coloques
# música
# ranchera
# .
#
#
# Ay
# amiga
# ,
# ¿
# me
# puedes
# ayudar
# a
# organizar
# mi
# cuarto
# ?
# Que
# es
# que
# vienen
# mis
# papás
# .
#
#
# Hey
# me
# puedes
# poner
# esta
# canción
# .
# Es
# para
# animar
# más
# la
# fiesta
# …
# .
#
#
#
# Hey
# ,
# pásamela
# pues
# .
# Mira
# que
# estoy
# sola
# .
#
#
# Disculpa
# señora
# ,
# ¿
# cómo
# es
# que
# es
# su
# nombre
# ?
#
#
# Papi
# por
# favor
# ponme
# las
# cosas
# donde
# yo
# siempore
# las
# he
# puesto
# .
#
#
# Bueno
# madre
# ,
# tenía
# algo
# intresante
# que
# contarte
# pero
# parece
# que
# para
# ti
# hay
# cosas
# más
# importantes
# .
#
#
# me
# muero
# de
# la
# pena
# pero
# si
# tú
# tienes
# una
# deuda
# conmigo
# ,
# yo
# espero
# que
# tú
# me
# lo
# pagues
# en
# el
# tiempo
# de
# la
# -
# para
# pagar
# ...
# ,
# entonces
# respeta
# eso
# .
#
#
# Pues
# bueno
# Profe
# ,
# tú
# mismo
# me
# aconsejaste
# un
# tema
# ,
# pero
# a
# mí
# no
# me
# gustaba
# .
# Yo
# creo
# que
# a
# veces
# es
# mejor
# dejarnos
# trabaar
# sobre
# lo
# que
# nosotros
# trabajamos
# .
#
#
# Hey
# ,
# ¡
# pasa
# la
# pelota
# !
# todos
# estamos
# jugando
# .
#
#
# Mami
# ,
# ayuda
# a
# prepar
# esas
# galletas
# que
# es
# que
# a
# mi
# amiga
# le
# gustaron
# mucho
# .
#
#
# ¿
# Y
# a
# la
# parte
# de
# los
# dos
# conoces
# al
# novio
# o
# la
# novia
# ?
#
#
# Veo
# que
# ya
# te
# has
# recuperado
# económicamente
# .
# ¿
# me
# puedes
# pagar
# ?
#
#
# Disculpa
# ,
# pero
# debe
# de
# respetar
# el
# espacio
# de
# todos
# .
#
#
# Papi
# ,
# me
# puedes
# ayudar
# organizando
# bien
# las
# cajas
# .
# Gracias
# .
#
#
# Mami
# ,
# entiende
# que
# yo
# soy
# una
# persona
# independiente
# .
# Te
# quiero
# contar
# mis
# problemas
# pero
# no
# quiero
# .
#
#
#
# Por
# favor
# ,
# no
# le
# grites
# a
# mi
# perro
# .
# El
# sólo
# quiere
# estar
# contigo
# y
# conocerte
# .
#
#
# Me
# puedes
# ayudar
# por
# favor
# a
# limpiar
# el
# cuarto
# que
# vienen
# mis
# papás
# .
# Muchas
# gracias
# .
#
#
# Papi
# ,
# me
# puedes
# ayudar
# por
# favor
# haciendo
# un
# árbol
# genealógico
# que
# no
# conocí
# a
# mis
# bisabuelos
# .
#
#
# Madre
# ,
# me
# puedes
# ayudar
# por
# favor
# con
# la
# receta
# de
# las
# galletas
# .
#
#
#
# Oye
# ,
# ¿
# qué
# te
# gustaría
# hacer
# el
# día
# de
# tu
# cumpleaños
# ?
# Cuéntame
# .
#
#
# Hey
# qué
# pena
# .
# ¡
# Eres
# familiar
# del
# novio
# o
# de
# la
# novia
# ?
#
#
# ¿
# Y
# cuántas
# mascotas
# tienes
# ?
#
#
# ¿
# Ay
# este
# también
# es
# tu
# perro
# ?
# ¿
# Tienes
# dos
# mascotas
# ?
#
#
# Mamá
# ,
# pero
# es
# que
# no
# escuchaste
# ,
# mirá
# me
# dieron
# una
# oferta
# de
# trabajo
# .
# Estoy
# muy
# contenta
# .
# ¿
# Por
# qué
# no
# me
# dices
# pues
# nada
# sobre
# eso
# ?
#
#
# Pero
# primero
# investiga
# bien
# lo
# que
# yo
# te
# propuse
# para
# que
# me
# puedas
# decir
# algo
# o
# sea
# para
# poder
# hacer
# lo
# tuyo
# ,
# primero
# investiga
# primero
# lo
# que
# yo
# te
# propuse
# .
#
#
#
# ¿
# Pero
# por
# qué
# tanto
# ...
# por
# qué
# ?
# ¿
# Por
# qué
# no
# caminas
# por
# qué
# no
# encuentras
# otra
# forma
# para
# caminar
# ?
# ¿
# Por
# qué
# tienes
# que
# caminar
# así
# ?
#
#
# ¿
# Pero
# por
# qué
# has
# cambiado
# tanto
# ?
# Antes
# escuchabas
# todos
# mis
# problemas
# y
# ahora
# no
# me
# quieres
# esuchar
# .
#
#
# ¿
# Pero
# por
# qué
# le
# gritas
# a
# mi
# perro
# ?
# Mirá
# que
# él
# no
# te
# va
# a
# hacer
# nada
# ,
# simplemente
# te
# va
# a
# como
# saludar
# o
# algo
# ,
# pero
# no
# es
# que
# te
# vaya
# a
# hacer
# nada
# te
# vaya
# a
# morder
# .
# ¿
# Por
# qué
# tienes
# que
# gritar
# a
# mi
# perro
# ?
#
#
# Por
# qué
# no
# me
# ayudas
# a
# limpiar
# mirá
# que
# va
# a
# venir
# visita
# ?
# Y
# entonces
# cómo
# así
# no
# te
# da
# pena
# que
# vengan
# mis
# papás
# y
# todo
# desordenado
# .
# Hay
# que
# poner
# más
# orden
# .
#
#
# Como
# es
# te
# ocurre
# que
# no
# tomas
# las
# pastillas
# ¿
# entonces
# cómo
# te
# quieres
# aliviar
# ?
# Así
# no
# puede
# ser
# porque
# si
# no
# toma
# medicamento
# ,
# ¿
# cómo
# vas
# a
# seguir
# adelante
# ?
# ¿
# Cómo
# te
# quieres
# curar
# ?
#
#
# Mira
# es
# que
# esa
# música
# no
# me
# gusta
# .
# Cámbiame
# la
# música
# que
# es
# que
# mirá
# todo
# el
# mundo
# está
# aburrido
# .
#
#
# Debes
# de
# pasarme
# la
# pelota
# porque
# si
# no
# ,
# ¿
# entonces
# cómo
# vamos
# a
# jugar
# ?
# Aquí
# no
# podemos
# jugar
# descoordinados
# .
# Tenemos
# que
# hacernos
# todos
# que
# todos
# juguemos
# de
# equipo
# .
#
#
# Mira
# ayúdame
# con
# eso
# porque
# yo
# quiero
# hacer
# ...
# papá
# ayudame
# a
# hacer
# el
# árbol
# genealógico
# porque
# es
# que
# yo
# quiero
# que
# ...
# conservar
# toda
# la
# familia
# .
# Entonces
# para
# que
# me
# colabores
# por
# favor
# porque
# yo
# sola
# no
# puedo
# .
# Me
# es
# imposible
# .
# Tú
# tienes
# más
# conocimiento
# ,
# es
# una
# persona
# ya
# de
# edad
# .
# Ya
# tiene
# más
# conocimiento
# entonces
# me
# puedes
# colaborar
# con
# los
# datos
# de
# la
# familia
# .
#
#
# Mamá
# ayúdame
# a
# preparar
# las
# galletas
# porque
# la
# amiga
# mía
# quiere
# esas
# galletas
# .
# ...
# Si
# no
# me
# puedes
# decir
# la
# receta
# ,
# ayúdame
# a
# preparar
# las
# galletas
# para
# que
# me
# queden
# bien
# ricas
# .
#
#
# ¿
# Y
# entonces
# que
# ?
# ¿
# qué
# podemos
# hacer
# ?
# Dime
# pues
# a
# ver
# .
# ¿
# Que
# si
# vamos
# a
# acampar
# o
# qué
# puedo
# hacer
# pues
# ?
# Porque
# no
# me
# has
# dicho
# una
# conclusión
# o
# nada
# .
# ¿
# Enctonces
#
# cómo
# hacemos
# ?
# ¿
# vamos
# a
# acampar
# o
# qué
# ?
#
#
# Por
# favor
# dime
# tu
# nombre
# que
# es
# que
# se
# me
# olvidó
# .
# Aquí
# he
# estado
# tan
# ocupada
# que
# estaba
# acá
# que
# se
# me
# olvidó
# tu
# nombre
# .
# Por
# favor
# dime
# tu
# nombre
# .
#
#
# Te
# he
# dicho
# que
# por
# favor
# no
# me
# cambies
# de
# punto
# las
# cosas
# .
#
#
# Realmente
# no
# entiendo
# por
# qué
# no
# me
# puedes
# pagar
# aún
# si
# te
# han
# visto
# en
# lugares
# donde
# se
# necesita
# pagar
# mucho
# dinero
# .
# No
# entiendo
# por
# que
# no
# me
# has
# pagado
# aún
# .
# Quiero
# que
# me
# expliques
# y
# que
# me
# regreses
# mi
# dinero
# que
# lo
# necesito
# .
#
#
# Necesito
# que
# me
# colabores
# porque
# este
# es
# un
# espacio
# de
# las
# dos
# y
# tienes
# que
# comprometerte
# igual
# que
# yo
# .
#
#
# Recuerda
# que
# esos
# medicamentos
# son
# por
# tu
# bien
# .
# Si
# no
# las
# tomas
# ,
# vas
# a
# estar
# todos
# los
# días
# más
# enferma
# .
# Entonces
# realmente
# es
# tu
# responsabilidad
# .
# Tienes
# que
# cambiar
# la
# música
# porque
# se
# nos
# está
# aburriendo
# los
# amigos
# .
# Me
# extraña
# que
# esta
# música
# que
# estás
# poniendo
# no
# es
# la
# que
# te
# gusta
# ni
# es
# la
# que
# hemos
# compartido
# .
# Fíjate
# a
# ver
# cómo
# podemos
# cambiar
# y
# mejorar
# .
#
#
# Quisiera
# robarte
# un
# poco
# de
# tiempo
# para
# hablar
# de
# los
# nombres
# de
# nuestros
# antepasados
# .
# ¿
# Será
# que
# me
# puedes
# colaborar
# ?
#
#
# ¿
# Recuredas
# las
# galletas
# que
# preparaste
# en
# diciembre
# pasado
# ?
# Quisiera
# que
# me
# recordaras
# la
# receta
# .
# Si
# te
# acuerdas
# ,
# por
# favor
# me
# la
# anotas
# acá
# en
# este
# papel
# .
#
#
# Qué
# pena
# he
# hablado
# mucho
# y
# no
# te
# he
# preguntado
# a
# ti
# que
# te
# gustaría
# .
# Discúlpame
# .
#
#
# Quisiera
# saber
# cuándo
# te
# queda
# fácil
# reunirte
# .
# Por
# favor
# ,
# me
# lo
# comunicas
# que
# yo
# estaré
# dispuesta
# .
#
#
# Por
# favor
# me
# recuerda
# su
# nombre
# .
#
#
# Cuéntame
# por
# qué
# persona
# del
# matrimonio
# viniste
# .
# Que
# hemos
# conversado
# mucho
# pero
# no
# te
# había
# preguntado
# .
# Ya
# que
# somos
# del
# mismo
# sitio
# pues
# que
# nacimos
# en
# la
# misma
# parte
# .
#
#
# O
# sea
# me
# dices
# que
# no
# tienes
# dinero
# y
# luego
# sales
# con
# eso
# .
# deberías
# más
# responsbale
# con
# tus
# cosas
# .
#
#
# Para
# que
# me
# citas
# tan
# frecuentemente
# …
# si
# no
# vas
# a
# venir
#
#
# oye
# deberías
# …
# .
#
#
#
# oye
# pa
# ,
# mira
# .
# Acá
# podemos
# poner
# estas
# cajas
# y
# acá
# podemos
# poner
# otras
# cajas
# .
#
#
# Me
# parece
# importante
# que
# respetes
# a
# mi
# perro
# .
#
#
#
# Oye
# ,
# no
# estás
# juganndo
# sola
# .
#
#
#
# Oye
# pa
# …
# sería
# que
# podrías
# ayudarme
# con
# toda
# la
# información
# ?
#
#
# Oye
# ¿
# no
# sabés
# cuándo
# nos
# vamos
# a
# encontrar
# para
# trabajar
# en
# los
# proyectos
# ?
#
#
# Hay
# oye
# ,
# vienes
# por
# el
# novio
# o
# por
# la
# novia
# ?
#
#
# Papá
# no
# muevas
# mis
# pertenencias
# de
# dónde
# yo
# las
# dejo
# .
#
#
# Mamá
# pon
# más
# atención
# a
# lo
# que
# yo
# te
# estoy
# diciendo
# .
#
#
# Págame
# el
# dinero
# .
# Si
# tienes
# para
# ir
# a
# comer
# sushi
# y
# para
# ir
# a
# bailar
# a
# la
# discoteca
# .
# Entonces
# antes
# de
# ir
# allá
# ,
# págame
# primero
# a
# mí
# .
# Y
# después
# con
# lo
# que
# si
# te
# queda
# algo
# ,
# diviértete
# con
# lo
# que
# te
# queda
# .
# Pero
# primero
# me
# pagas
# a
# mí
# lo
# que
# me
# debes
# .
#
#
# Ten
# cuidado
# ,
# mira
# que
# me
# estás
# empujando
# y
# estás
# empujando
# a
# mis
# amigos
# .
# Pon
# mas
# cuidado
# ,
# pon
# mas
# cuidado
# al
# caminar
# .
#
#
# Papá
# pon
# cuidado
# mira
# que
# son
# cajas
# delicadas
# .
# Son
# cosas
# delicadas
# .
# Son
# …
# mejor
# dicho
# ,
# todo
# lo
# que
# es
# delicado
# ,
# no
# las
# tires
# por
# favor
# .
#
#
# Mamá
# ...
# esúchame
# ,
# de
# pronto
# por
# tu
# edad
# ,
# ya
# no
# me
# tienes
# paciencia
# .
# Ya
# no
# eres
# como
# antes
# que
# me
# escuchabas
# que
# nos
# sentábamos
# a
# hablar
# de
# todo
# ,
# nos
# reíamos
# y
# todo
# .
# Ya
# no
# es
# lo
# mismo
# ,
# por
# favor
# escúchame
# .
#
#
#
# Si
# no
# te
# gusta
# mi
# perro
# ,
# entonces
# no
# vuelvas
# a
# mi
# casa
# y
# ya
# .
#
#
# Por
# favor
# ,
# me
# colaboras
# en
# mi
# casa
# que
# vienen
# mis
# papás
# .
# Yo
# estoy
# muy
# ocupada
# en
# mi
# trabajo
# .
# Si
# no
# ...
# tampoco
# tienes
# tiempo
# ,
# por
# favor
# consigamos
# una
# persona
# que
# nos
# ayude
# con
# la
# limpieza
# de
# nuestro
# hogar
# .
#
#
# Por
# favor
# tómate
# las
# pastillas
# que
# es
# por
# tu
# bien
# ,
# es
# por
# tu
# salud
# .
# No
# las
# botes
# ,
# no
# las
# tires
# a
# la
# basura
# .
# Mira
# que
# tu
# salud
# ,
# estás
# muy
# delicada
# de
# salud
# y
# necesitas
# tomarte
# las
# pastillas
# para
# poderte
# mantener
# bien
# .
#
#
# Por
# favor
# DJ
# cambia
# la
# música
# ,
# esta
# música
# está
# muy
# maluca
# .
# No
# estamos
# divertiendo
# ,
# no
# estamos
# pasando
# bien
# .
# Por
# favor
# ,
# cambia
# la
# musica
# o
# pon
# otro
# DJ
# para
# que
# ponga
# música
# mejor
# ,
# nos
# ponga
# a
# bailar
# mejor
# .
#
#
# Por
# favor
# no
# te
# dejes
# robar
# la
# pelota
# .
# Pásamela
# a
# mí
# .
# Es
# que
# el
# juego
# es
# de
# varias
# ,
# no
# es
# de
# una
# sola
# por
# favor
# .
# Pásame
# la
# pelota
# que
# yo
# tambien
# quiero
# jugar
# .
# Quiero
# divertirme
# .
#
#
# Por
# favor
# papá
# ,
# cuéntame
# que
# o
# sea
# que
# fue
# de
# mis
# bisabuelos
# de
# mis
# antespasados
# .
# Nunca
# los
# conocí
# .
# Entonces
# quiero
# que
# me
# cuentes
# como
# fue
# mi
# familia
# ,
# cómo
# fueron
# mis
# abuelos
# ,
# mis
# bisabuelos
# ,
# sí
# .
# Yo
# quiero
# saber
# más
# .
#
#
# A
# mí
# me
# gusta
# acampar
# ,
# me
# gusta
# acampar
# ,
# disfrutar
# el
# cumpleaños
# con
# río
# .
# ¿
# Te
# gustaría
# venir
# conmigo
# o
# que
# te
# gustaria
# pues
# que
# te
# gustaría
# compartir
# ?
# Si
# no
# quieres
# venir
# conmigo
# a
# acampar
# ,
# entonces
# ya
# dime
# que
# quieres
# hacer
# y
# lo
# hacemos
# .
#
#
# Cuando
# tú
# digas
# ,
# nos
# reuniremos
# .
#
#
# Por
# favor
# me
# acuerdas
# cómo
# te
# llamas
# .
#
#
# ¿
# Tienes
# un
# perro
# o
# tiene
# dos
# ?
#
#
# Mami
# pero
# es
# que
# yo
# tengo
# una
# vida
# independiente
# y
# usted
# es
# otra
# .
# Entonces
# es
# bueno
# que
# me
# respetes
# mis
# ideas
# .
#
#
# ¿
# Por
# qué
# le
# gritas
# ?
# Lo
# asusta
# .
# ¡
# A
# mí
# no
# me
# gusta
# que
# le
# grites
# a
# mi
# perrro
# !
#
#
# oíme
# pero
# te
# tenés
# que
# tomar
# las
# pastillas
# ...
# las
# tomás
# porque
# la
# perjudicada
# eres
# vos
#
#
# Mami
# por
# qué
# no
# me
# ayudas
# con
# esto
# ,
# yo
# voy
# a
# preparar
# unas
# galletas
# pero
# en
# este
# momento
# se
# me
# olvidó
# la
# receta
# .
# ¿
# Entonces
# a
# ver
# si
# me
# puedes
# colaborar
# con
# esto
# ?
#
#
# Por
# favor
# ,
# me
# ayudas
# con
# la
# dirección
# de
# este
# hotel
# que
# se
# me
# olvidó
# .
# No
# recuerdo
# por
# dónde
# vine
# ni
# por
# dónde
# voy
# a
# ir
# .
#
#
# ¿
# Estás
# esperando
# a
# tu
# novia
# ?
# Ah
# bueno
# ,
# muy
# bueno
# haber
# charlado
# un
# ratico
# .
# Usted
# está
# esperando
# a
# la
# novia
# bueno
# .
# Qué
# tan
# bueno
# que
# estés
# aquí
# .
#
#
# Hola
# ,
# dime
# ¿
# por
# quién
# te
# invitó
# ?
#
#
# Hola
# ,
# qué
# pena
# contigo
# decirte
# .
# Pero
# no
# sé
# si
# fue
# que
# estabas
# como
# muy
# apurado
# ,
# pero
# recureda
# que
# te
# había
# dicho
# que
# no
# puedo
# comer
# berenjena
# .
# Ya
# te
# lo
# había
# advertido
# .
# Qué
# pena
# contigo
# .
# Por
# favor
# me
# lo
# retiras
# .
#
#
# Hola
# ,
# qué
# pena
# contigo
# decirte
# .
# Pero
# no
# sé
# si
# fue
# que
# estabas
# como
# muy
# apurado
# ,
# pero
# recuerda
# que
# te
# había
# dicho
# que
# no
# puedo
# comer
# berenjena
# .
# Ya
# te
# lo
# había
# advertido
# .
# Qué
# pena
# contigo
# .
# Por
# favor
# me
# lo
# retiras
# .
#
#
# Ay
# papá
# ,
# tu
# sabes
# que
# me
# gusta
# que
# todo
# este
# organizado
# .
# Y
# dentro
# de
# estas
# cajas
# ,
# hay
# cosas
# delicadas
# .
# Por
# favor
# ponlas
# organizadas
# .
# No
# me
# ven
# -
# desbarates
# todas
# .
# Recuerda
# que
# es
# un
# trasteo
# .
#
#
# Ay
# mamá
# tú
# yo
# yo
# nos
# hemos
# entendido
# mucho
# .
# Y
# es
# rico
# que
# yo
# pueda
# contarte
# las
# cosas
# .
# Pero
# es
# que
# te
# estás
# volviendo
# muy
# regañona
# y
# cansona
# .
# Entonces
# nooo
# ,
# bájele
# un
# poquito
# el
# tono
# mami
# .
#
#
# Vea
# amigo
# ,
# si
# de
# pronto
# es
# que
# a
# ti
# no
# te
# gustan
# los
# perros
# ,
# dale
# yo
# no
# tengo
# ningun
# problema
# .
# Cuando
# tú
# vengas
# ,
# entonces
# yo
# guardo
# mi
# perro
# en
# otro
# lugar
# para
# que
# no
# te
# moleste
# pero
# tampoco
# me
# gusta
# que
# lo
# desprecies
# .
#
#
# Ay
# hola
# ,
# ¿
# será
# que
# tú
# me
# puedes
# ayudar
# un
# poquito
# con
# estos
# papeles
# para
# yo
# poder
# timbrar
# en
# el
# tercer
# piso
# ?
# ¿
# O
# tú
# me
# puedes
# pinchar
# el
# tercer
# piso
# sí
# ?
# Por
# favor
# ,
# gracias
# .
#
#
# Bueno
# ¿
# tú
# que
# quieres
# ?
# ¿
# aliviarte
# estar
# regular
# de
# salud
# ,
# que
# esos
# achaques
# que
# tienes
# te
# molesten
# todo
# el
# día
# en
# todo
# el
# momento
# o
# tener
# de
# pronto
# una
# mejor
# calidad
# de
# vida
# ?
# Si
# quieres
# una
# mejor
# calidad
# de
# vida
# ,
# debes
# de
# tomarte
# las
# pastillas
# .
# Tómalelas
# con
# tranquilidad
# y
# verá
# que
# .
# Todos
# los
# días
# vas
# a
# aceptar
# que
# eso
# es
# lo
# que
# tienes
# que
# hacer
# para
# mejorarte
# de
# salud
# .
# Ok
# ,
# yo
# todos
# los
# días
# voy
# a
# estimularte
# para
# que
# lo
# hagas
# .
#
#
# Hey
# DJ
# ,
# yo
# quiero
# esa
# canción
# que
# me
# encanta
# ,
# .
# Ay
# hermano
# cámbiale
# un
# poquito
# esa
# música
# que
# estamos
# como
# desanimados
# y
# la
# fiesta
# se
# va
# a
# acabar
# .
# No
# ,
# dale
# .
# Cambia
# la
# música
# .
# Yo
# quiero
# que
# me
# pongas
# una
# canción
# por
# ejemplo
# _
# _
# _
# _
# _
# _
# _
# _
# _
# .
# Para
# que
# nos
# enrumbemos
#
#
# Hey
# pásame
# pues
# la
# pelota
# que
# yo
# también
# estoy
# en
# el
# equipo
# .
# Pásamela
# .
#
#
# Ay
# papá
# qué
# rico
# ,
# imagináte
# que
# quiero
#
# hacer
# el
# árbol
# genealógicao
# de
# la
# familia
# .
# Y
# yo
# sé
# que
# usted
# tiene
# una
# memoria
# espectactular
# .
# Por
# ahí
# derecho
# me
# cuentas
# historias
# Quiero
# saeber
# como
# todo
# quíenes
# eran
# mis
# tatarabuelos
# ,
# abuelos
# .
# Para
# poder
# hacer
# la
# tus
# de
# hecho
# me
# cuentas
# tus
# historias
# fascinantes
# que
# tienes
# .
#
#
# Ay
# mami
# ¿
# se
# acuerda
# de
# las
# galletas
# que
# hicimos
# el
# año
# pasado
# en
# diciembre
# ?
# Ay
# dame
# la
# receta
# ,
# que
# estas
# quieres
# hacer
# de
# esas
# galletas
# .
#
#
# Ay
# qué
# pena
# contigo
# ,
# he
# hablado
# todo
# el
# tiempo
# .
# No
# te
# he
# dejado
# hablar
# a
# ti
# .
# ¿
# Y
# qué
# te
# gustaría
# hacer
# a
# ti
# en
# el
# día
# de
# tu
# cumpleaños
# ?
#
#
# Bueno
# querida
# ,
# ¿
# entonces
# qué
# ?
# Nos
# vuelve
# a
# tocar
# trabajar
# juntas
# .
# Entonces
# dime
# cómo
# hacemos
# .
# ¿
# Yo
# hago
# una
# parte
# y
# luego
# tu
# y
# nos
# reunimos
# ...
# las
# dos
# partes
# y
# lo
# compartimos
# ?
# ¿
# O
# nos
# encontramos
# y
# trabajamos
#
# a
# la
# vez
# ?
# Dime
# cómo
# hacemos
# .
# ¿
# Qué
# propones
# tú
# ?
#
#
# Hágame
# el
# favor
# y
# aprieta
# el
# tres
# .
#
#
# Chico
# ,
# será
# que
# me
# puedes
# cambiar
# el
# plato
# ?
# Sino
# que
# te
# había
# dicho
# que
# no
# podía
# consumir
# berenjena
# .
#
#
# Chica
# ,
# será
# que
# te
# puedes
# mover
# que
# aquí
# estamos
# ,
# pues
# ,
# como
# todos
# juntos
# ,
# para
# que
# no
# nos
# estorbes
# o
# algo
# .
#
#
# Oye
# ,
# será
# que
# podemos
# organizar
# un
# poquito
# esta
# casa
# que
# está
# …
# que
# mañana
# vienen
# mis
# papás
# y
# maluco
# que
# la
# vean
# en
# este
# estado
# .
#
#
# Hola
# ,
# si
# sabes
# que
# ?
# Pues
# ,
# ya
# te
# había
# notado
# que
# botas
# las
# pastillas
# y
# sabes
# que
# son
# para
# que
# te
# sientas
# mejor
# .
# Pues
# ,
# como
# consejo
# para
# que
# no
# las
# sigás
# botando
# .
#
#
# Amigo
# ,
# será
# que
# puedes
# poner
# esta
# canción
# que
# habías
# puesto
# en
# el
# otro
# set
# que
# tuviste
# la
# semana
# pasada
# .
# Porque
# la
# verdad
# hoy
# estás
# como
# un
# poquito
# desatinado
# con
# la
# música
# que
# estás
# poniendo
# .
#
#
# Hola
# ,
# será
# que
# me
# puedes
# por
# favor
# decir
# cómo
# llegar
# al
# hotel
# Inter
# que
# es
# donde
# me
# estoy
# quedando
# y
# la
# verdad
# no
# me
# acuerdo
# bien
# cómo
# llegué
# .
#
#
# Oye
# ,
# y
# por
# cierto
# ,
# tú
# estás
# aquí
# con
# la
# novia
# o
# el
# novio
# que
# no
# veo
# casi
# ?
# Se
# me
# había
# olvidado
# preguntarte
# .
#
#
# Profe
# ,
# acuérdate
# que
# usted
# me
# dijo
# que
# escogiera
# ese
# tema
# y
# no
# el
# tema
# que
# yo
# pretendía
# seguir
# .
#
#
# Mujer
# ,
# debes
# tomarte
# esas
# pastillas
# juiciosa
# porque
# sino
# tendrás
# algo
# ,
# una
# enfermedad
# peor
# .
# Señora
# ,
# tómate
# las
# pastillas
# porfa
# que
# es
# por
# tu
# bien
# .
# Quizás
# después
# tendrás
# un
# problema
# aún
# mayor
# .
#
#
# ¿
# No
# me
# preguntas
# sino
# eso
# ?
#
#
# No
# pongas
# eso
# tan
# desordenado
# .
#
#
# No
# te
# metas
# tanto
# en
# mi
# vida
# .
#
#
# Espera
# por
# favor
# .
#
#
# Pásala
# .
#
#
# ¿
# Qué
# te
# gustaría
# hacer
# a
# ti
# ?
#
#
# Madre
# ,
# usted
# por
# qué
# me
# ignora
# tanto
# en
# las
# cuestiones
# y
# las
# desiciones
# ?
# Por
# favor
# ,
# tenga
# más
# cuidado
# en
# lo
# que
# digas
# .
# Ok
# ?
#
#
# Madre
# ,
# quiero
# que
# te
# preocupes
# por
# tu
# salud
# .
# Voy
# a
# estar
# más
# pendiente
# de
# que
# te
# tomes
# tus
# medicamentos
# .
# Voy
# a
# estar
# detrás
# de
# vos
# para
# que
# te
# los
# tomes
# ,
# ok
# ?
#
#
# Padre
# ,
# si
# sabes
# toda
# esa
# información
# de
# tus
# bisabuelos
# y
# abuelos
# y
# todo
# eso
# ,
# por
# qué
# no
# nos
# das
# la
# información
# exacta
# quienes
# son
# para
# poder
# saber
# quién
# es
# nuestra
# familia
# ?
#
#
# Madre
# ,
# por
# qué
# no
# me
# colabora
# con
# la
# receta
# que
# tú
# sabes
# de
# las
# galletas
# ?
# Si
# te
# acuerdas
# ?
# O
# búsquelas
# donde
# esté
# guardada
# tus
# recetas
# para
# poder
# colaborarnos
# para
# hacer
# las
# recetas
# de
# galleticas
# ,
# ok
# ?
#
#
# Amiga
# ,
# por
# qué
# no
# nos
# reunimos
# en
# el
# espacio
# que
# tú
# te
# queda
# …
# que
# usted
# piense
# que
# te
# quede
# al
# espacio
# pa
# podernos
# reunir
# y
# hacer
# ese
# trabajo
# ,
# ok
# ?
#
#
# Madre
# ,
# se
# me
# olvidó
# tu
# nombre
# pero
# tu
# sabes
# que
# estamos
# en
# una
# situación
# de
# trabajo
# muy
# muy
# delicada
# .
# Por
# favor
# me
# recuerda
# tu
# nombre
# ?
#
#
# Papá
# ,
# no
# vuelvas
# a
# coger
# mis
# cosas
# de
# donde
# las
# tengo
# .
#
#
# No
# me
# interesa
# el
# tema
# que
# tu
# quieres
# .
#
#
# Sabes
# ,
# el
# tiempo
# mío
# también
# vale
# .
#
#
# Por
# favor
# ,
# me
# puedes
# cambiar
# el
# pedido
# que
# no
# puedo
# comer
# de
# esto
# .
#
#
# Hey
# papá
# ,
# por
# qué
# me
# cogiste
# el
# bolso
# ?
# No
# te
# he
# dicho
# que
# no
# me
# lo
# coloques
# ,
# que
# no
# lo
# cojas
# por
# favor
# ?
#
#
# Hola
# ,
# por
# favor
# ,
# no
# nos
# estorbes
# .
#
#
# Por
# favor
# ,
# recuerda
# que
# vienen
# nuestros
# padres
# y
# tenemos
# esta
# casa
# como
# un
# chiquero
# .
#
#
# Hey
# hermano
# ,
# póngame
# esta
# canción
# que
# esa
# si
# es
# de
# la
# que
# nos
# gusta
# a
# nosotros
# .
#
#
# Hola
# mamá
# ,
# por
# favor
# ,
# por
# qué
# no
# me
# recuerdas
# como
# es
# que
# se
# preparan
# ehhh
# …
# las
# galletas
# .
#
#
# Eh
# hola
# ,
# buenas
# tardes
# .
# Por
# favor
# ,
# me
# indicas
# dónde
# queda
# mi
# hotel
# .
#
#
# Por
# favor
# ,
# deja
# mis
# cosas
# en
# el
# lugar
# donde
# las
# dejo
# que
# así
# es
# más
# fácil
# encontrarlas
# .
#
#
# Por
# favor
# ,
# acuérdate
# que
# me
# debes
# de
# pagar
# la
# plata
# .
# Acuérdate
# que
# necesito
# pagar
# la
# renta
# ,
# necesito
# pagar
# muchas
# deudas
# .
# Entonces
# por
# favor
# ,
# devuélvame
# ,
# pues
# ,
# el
# dinero
# que
# me
# debes
# .
# Por
# favor
# ,
# recuerda
# el
# dinero
# que
# me
# debes
# ,
# necesito
# ,
# te
# doy
# un
# plazo
# ,
# para
# que
# me
# lo
# pagues
# ,
# porque
# recuerda
# que
# yo
# necesito
# también
# pagar
# mis
# deudas
# y
# mi
# renta
# .
#
#
# A
# mi
# no
# me
# parece
# que
# me
# hayas
# hecho
# caer
# mal
# ante
# mi
# jefe
# .
# Si
# me
# ibas
# a
# hacer
# un
# favor
# ,
# me
# debieras
# habermelo
# hecho
# sin
# tener
# que
# decirle
# nada
# al
# jefe
# .
# Si
# o
# qué
# ?
#
#
# Si
# no
# tienes
# otro
# plato
# para
# ofrecerme
# ,
# dígame
# con
# claridad
# y
# yo
# me
# retiro
# .
#
#
# Pero
# papá
# ,
# no
# te
# das
# cuenta
# de
# que
# las
# cosas
# son
# delicadas
# ?
# Si
# es
# que
# estás
# muy
# cansado
# y
# no
# quieres
# ayudarnos
# por
# favor
# déjanos
# que
# nosotros
# hacemos
# el
# trasteo
# y
# tú
# te
# sientas
# .
#
#
# Pues
# ,
# mamá
# yo
# sé
# que
# tú
# estás
# en
# una
# edad
# ,
# pues
# ,
# que
# ya
# no
# me
# tienes
# tanta
# paciencia
# .
# Mamá
# ,
# tú
# que
# siempre
# me
# escuchabas
# y
# ahora
# qué
# te
# pasa
# .
# Por
# qué
# es
# que
# ya
# no
# me
# escuchas
# ?
# Dime
# ,
# es
# que
# ahoras
# estás
# enferma
# ?
#
#
# Pues
# mira
# ,
# estoy
# en
# mi
# casa
# ,
# si
# no
# te
# gusta
# mi
# perro
# .
# Por
# favor
# ,
# retírate
# que
# estoy
# en
# mi
# casa
# .
# Pero
# por
# favor
# no
# me
# gusta
# que
# le
# grites
# a
# mi
# perro
# .
#
#
# Por
# favor
# ,
# si
# no
# tienes
# tiempo
# tu
# tampoco
# de
# colaborar
# en
# la
# casa
# ,
# búscate
# a
# alguien
# también
# que
# nos
# colabore
# con
# la
# limpieza
# .
#
#
# Por
# favor
# mira
# que
# eso
# es
# para
# tu
# bien
# .
# Tómatelas
# .
# Por
# favor
# ,
# tómate
# las
# pastillas
# que
# mira
# o
# es
# que
# ya
# no
# quieres
# estar
# con
# nosotros
# ?
# Tómate
# las
# pastas
# que
# eso
# es
# por
# tu
# bien
# .
#
#
# Por
# favor
# DJ
# ,
# cambia
# la
# música
# ,
# si
# queremos
# pasar
# un
# rato
# agradable
# ,
# cambia
# la
# música
# .
# Que
# es
# que
# esa
# música
# a
# mis
# amigos
# los
# está
# aburriendo
# .
#
#
# El
# juego
# es
# en
# equipo
# .
# Por
# favor
# ,
# no
# te
# apoderes
# de
# la
# pelota
# .
# Pasa
# el
# balón
# para
# que
# todos
# juguemos
# .
# Porque
# todas
# queremos
# divertirnos
# .
#
#
# Cuéntame
# papá
# ,
# yo
# quisiera
# saber
# todo
# ,
# todo
# de
# mis
# antepasados
# para
# saber
# de
# qué
# familia
# vengo
# .
#
#
# Ay
# mamá
# ,
# por
# favor
# recuérdame
# la
# receta
# de
# las
# galletas
# que
# nos
# gustó
# tanto
# .
# A
# ver
# si
# este
# año
# las
# podemos
# preparar
# otra
# vez
# .
#
#
# Amigo
# ,
# sabes
# qué
# ?
# Dime
# ,
# dame
# una
# pista
# lo
# que
# más
# te
# gusta
# que
# yo
# quisiera
# que
# disfrutaras
# …
# yo
# quisiera
# darte
# una
# sorpresa
# en
# el
# cumpleaños
# .
# Pero
# no
# sé
# que
# te
# gusta
# .
# Así
# pues
# que
# …
# dime
# que
# te
# gusta
# y
# ahí
# entre
# los
# amigos
# modificaríamos
# el
# gusto
# de
# él
# .
#
#
# Ayúdame
# por
# favor
# a
# llegar
# al
# hotel
# que
# me
# despisté
# .
# Por
# favor
# ,
# señor
# agente
# me
# ayudas
# a
# llegar
# al
# hotel
# que
# es
# que
# estoy
# perdido
# .
#
#
# Señora
# por
# favor
# ,
# me
# anota
# su
# nombre
# aquí
# .
# Me
# recuerdas
# tu
# nombre
# y
# si
# es
# posible
# me
# lo
# anotas
# por
# ahí
# para
# yo
# estarlo
# recordando
# .
#
#
# Cuéntame
# ,
# ¿
# tienes
# uno
# o
# dos
# perros
# ?
# Porque
# mira
# ese
# perro
# te
# mira
# muy
# cariñoso
# .
#
#
# Cuéntame
# ,
# ¿
# tienes
# uno
# o
# dos
# perros
# ?
# Porque
# mira
# ese
# perro
# te
# mira
# muy
# cariñoso
# .
#
#
# Por
# qué
# me
# cojes
# mis
# cosas
# ,
# si
# siempre
# me
# las
# haces
# embolatar
# .
#
#
# Me
# parece
# el
# colmo
# que
# me
# hagas
# esperar
# ,
# sabiendo
# que
# teníamos
# una
# cita
# .
#
#
# Madre
# ,
# yo
# te
# he
# dicho
# varias
# veces
# que
# no
# me
# hables
# de
# esa
# forma
# .
#
#
# Tú
# sabes
# que
# eso
# es
# por
# tu
# bien
# .
# Tienes
# que
# tormarte
# los
# medicamentos
# porque
# eso
# te
# va
# a
# hacer
# sentir
# mejor
# .
#
#
# Me
# gustaría
# que
# tú
# me
# eligieras
# la
# canción
# para
# yo
# ponertela
# para
# que
# te
# sintieras
# agusto
# cuando
# estamos
# juntos
# .
#
#
# Hey
# parce
# ,
# por
# favor
# pásame
# la
# pelota
# también
# .
# Yo
# también
# estoy
# jugando
# .
# Mirá
# que
# quiero
# jugar
# .
#
#
# Ma
# ,
# recuérdame
# cómo
# es
# que
# haces
# esas
# galletas
# tan
# deliciosas
# que
# es
# para
# hacérselas
# a
# mis
# compañeritos
# .
#
#
# Cuando
# quieras
# …
# no
# te
# preocupes
# por
# eso
# …
# .
#
#
#
# Hey
# ,
# me
# puedes
# explicar
# dónde
# queda
# esta
# dirección
# por
# favor
# ?
#
#
# Pero
# papá
# ,
# no
# me
# escondas
# el
# bolso
# .
#
#
# Pero
# mamá
# ,
# me
# dieron
# un
# excelente
# empleo
# y
# tu
# hablando
# pendejadas
# .
#
#
# Oye
# muchacha
# ,
# tú
# por
# qué
# eres
# tan
# metida
# y
# dices
# lo
# que
# no
# debes
# decir
# .
#
#
# Oye
# ,
# mesero
# ,
# yo
# no
# le
# dije
# que
# no
# quería
# berenjena
# .
# Por
# qué
# me
# la
# trajo
# ?
#
#
# Oye
# parce
# ,
# deje
# el
# afán
# .
# No
# nos
# estorbe
# .
#
#
# Hombre
# parce
# ,
# a
# usted
# le
# gustan
# los
# gatos
# y
# a
# mí
# los
# perros
# .
# Hágame
# el
# favor
# y
# me
# respeta
# a
# mi
# perrito
# .
#
#
# Oye
# parcerín
# ,
# mire
# esa
# música
# y
# usted
# que
# pone
# música
# tan
# sabrosa
# siempre
# y
# ahora
# porque
# pone
# esas
# cosas
# tan
# malucas
# .
# Por
# favor
# ,
# pónganos
# a
# bailar
# .
#
#
# Ole
# ,
# ole
# ,
# pásame
# la
# pelota
# que
# te
# la
# quitan
# .
# A
# ver
# ,
# juguemos
# ,
# vamos
# a
# encestar
# la
# pelota
# .
# Pásamela
# .
#
#
# Oye
# cucho
# ,
# cuéntame
# la
# historia
# de
# la
# familia
# .
# Cuál
# fue
# tu
# tatarabuelo
# ,
# tu
# abuelo
# ,
# tu
# bisabuelo
# y
# cuál
# es
# …
# De
# dónde
# venimos
# ?
# Cuál
# es
# el
# árbol
# genealógico
# de
# nosotros
# .
# Por
# qué
# no
# nos
# sentamos
# y
# lo
# armamos
# .
#
#
# Mama
# ,
# dime
# cómo
# haces
# estas
# galletas
# tan
# sabrosas
# que
# la
# gente
# aquí
# quiere
# saber
# cómo
# las
# fábricas
# .
# Cuáles
# son
# los
# ingredientes
# ?
# Y
# a
# qué
# temperatura
# las
# haces
# ?
# Por
# qué
# están
# muy
# ricas
# .
#
#
# Digame
# compa
# ,
# qué
# quieres
# hacer
# para
# el
# cumpleaños
# ?
# Vamos
# al
# río
# o
# qué
# quieres
# hacer
# ?
# Dígame
# ,
# qué
# prefiere
# ?
#
#
# Oye
# señora
# ,
# me
# vuelve
# y
# me
# repite
# el
# nombre
# si
# fuera
# tan
# amable
# .
# Muchas
# gracias
# .
#
#
# Mamá
# ,
# quiero
# que
# me
# des
# un
# espacio
# para
# que
# hablemos
# de
# algunas
# cosas
# que
# tengo
# pendiente
# contigo
# porque
# noto
# que
# has
# cambiado
# mucho
# conmigo
# y
# te
# he
# extrañado
# .
#
#
# Por
# favor
# ,
# te
# quiero
# aclarar
# que
# no
# me
# gusta
# que
# le
# grites
# a
# mi
# perro
# ,
# que
# los
# animales
# también
# merecen
# que
# uno
# los
# respete
# y
# los
# trate
# bien
# .
# Porque
# él
# está
# acostumbrado
# a
# un
# trato
# diferente
# .
#
#
# Vea
# hija
# ,
# por
# favor
# ,
# vienen
# nuestros
# papás
# y
# la
# casa
# está
# muy
# desorganizada
# y
# yo
# estoy
# muy
# ocupada
# .
# Por
# favor
# ,
# ayúdame
# que
# además
# yo
# estoy
# muy
# cansada
# .
#
#
# Por
# favor
# ,
# les
# puedes
# comentar
# a
# las
# personas
# que
# como
# somos
# mucho
# con
# gustos
# distintos
# ,
# si
# es
# posible
# que
# podamos
# un
# momentico
# suspender
# la
# música
# que
# vienen
# y
# dar
# la
# oportunidad
# que
# otros
# disfruten
# con
# otra
# .
#
#
# Mami
# ,
# mami
# ,
# me
# puedes
# colaborar
# ?
# Nos
# vamos
# a
# reunir
# con
# las
# amigas
# y
# de
# todo
# y
# acuérdate
# de
# los
# pasteles
# y
# las
# galletas
# que
# hicicmos
# para
# ellos
# y
# ahora
# quieren
# repetirlas
# y
# yo
# no
# me
# acuerdo
# .
# Me
# puedes
# dar
# la
# fórmula
# nuevamente
# ?
# Quiero
# que
# ellas
# se
# sientan
# bien
# ,
# porque
# están
# aspirando
# a
# volver
# a
# degustar
# esas
# galletas
# tan
# ricas
# .
#
#
# Próximamente
# ,
# voy
# a
# cumplir
# años
# y
# me
# gustaría
# hacer
# un
# paseo
# y
# estar
# cerca
# por
# los
# lados
# de
# un
# río
# o
# algo
# .
# Tú
# me
# acompañas
# ?
# O
# tienes
# otra
# propuesta
# mejor
# ?
# Qué
# te
# gustaría
# hacer
# y
# qué
# inconveniente
# tenemos
# de
# celebrar
# ese
# cumpleaños
# juntos
# con
# una
# actividad
# que
# a
# ti
# te
# guste
# también
# .

# %% [markdown]
# ### usted file

# %%
usted = open("Files/ustedunique2.txt", mode='r', encoding='utf-8')
textusted = usted.read()
usted.close()

# %%
doc2 = nlp(textusted)
for token in doc2:
    print(token.text)
# Out:
# Ma
# ,
# pero
# usted
# sí
# es
# regañona
# .
# A
# toda
# hora
# diciéndole
# a
# uno
# qué
# tiene
# que
# hacer
# .
# Déjeme
# que
# yo
# estoy
# aprendiendo
# .
#
#
# Amor
# ,
# venga
# ayúdeme
# porque
# necesito
# recoger
# todo
# esto
# rápido
# antes
# de
# que
# lleguen
# mis
# papás
# .
# Recoja
# las
# botellas
# y
# ayúdeme
# a
# limpiar
# .
#
#
# Bueno
# mi
# señora
# ,
# vamos
# a
# tomarnos
#
# la
# pastilla
# hoy
# porque
# eso
# la
# va
# a
# aliviar
# .
# No
# me
# haga
# trampa
# .
#
#
# Chica
# nueva
# páseme
# la
# pelota
# que
# yo
# te
# la
# devuevlo
# .
#
#
#
# Bueno
# mamá
# ayúdeme
# a
# preparar
# esas
# galletas
# deliciosas
# para
# navidad
# .
#
#
#
# Ma
# ,
# por
# favor
# si
# yo
# confío
# en
# ti
# ,
# te
# cuento
# mis
# cosas
# ,
# es
# para
# que
# me
# aconseje
# ,
# no
# para
# que
# estés
# todo
# impaciente
# ...
# por
# todo
# .
#
#
#
# Hola
# la
# verdad
# es
# que
# soy
# un
# poco
# nerviosa
# con
# todo
# lo
# que
# me
# tengo
# que
# aprender
# y
# el
# trabajo
# y
# estoy
# muy
# ansisoa
# y
# qué
# pena
# se
# me
# ha
# olvidado
# tu
# nombre
# .
# ¿
# Me
# puede
# repetir
# tu
# nombre
# por
# favor
# ?
#
#
# ¿
# Podría
# recordarme
# su
# nombre
# ?
#
#
# Ah
# ma
# ,
# yo
# le
# quería
# contar
# una
# cosa
# pero
# usted
# como
# que
# está
# interesada
# en
# otras
# cosas
# .
#
#
# Para
# qué
# me
# hace
# venir
# tan
# temprano
# si
# nunca
# va
# a
# llegar
# .
#
#
#
# Ma
# yo
# le
# cuento
# las
# cosas
# para
# que
# me
# aconseje
# no
# para
# que
# me
# mande
# .
#
#
#
# ¿
# Qué
# pasa
# señora
# ?
# Tómele
# las
# pastillas
# por
# favor
# que
# es
# que
# no
# son
# para
# mí
# .
# Son
# para
# usted
# y
# es
# para
# que
# ustede
# se
# alivie
# .
#
#
#
# Buenas
# tardes
# señora
# ,
# es
# que
# la
# verdad
# no
# me
# parece
# que
# usted
# bote
# las
# pastillas
# porque
# es
# algo
# para
# mejorar
# su
# salud
# .
#
#
# Qué
# pena
# con
# usted
# .
# En
# verdad
# muero
# de
# la
# vergüenza
# .
# Es
# que
# se
# me
# olvidó
# usted
# cómo
# se
# llamaba
# .
# Qué
# pena
# en
# verdad
# .
#
#
# Si
# quiere
# preguntar
# como
# estoy
# ,
# y
# eso
# solamente
# le
# importa
# la
# plata
# .
#
#
# Qué
# mal
# venio
# .
# No
# pues
# que
# es
# una
# falta
# de
# respeto
# .
# ¿
# Cómo
# va
# a
# llegar
# hasta
# ahora
# ?
#
#
# No
# me
# tiene
# que
# decir
# todo
# el
# tiempo
# lo
# que
# tengo
# que
# hacer
# .
#
#
# Doña
# Licia
# ,
# no
# me
# diga
# mentiras
# .
# Debe
# tomarse
# sus
# pastillas
# por
# su
# bien
# .
#
#
# Señora
# ,
# ¿
# me
# recuerda
# su
# nombre
# por
# favor
# ?
#
#
# O
# sea
# que
# apenas
# se
# preocupa
# por
# lo
# material
# y
# no
# por
# lo
# yo
# quiero
# contarla
# ...
#
#
# Señora
# tenga
# más
# educación
# ,
# ¡
# no
# me
# empuje
# !
# Que
# todos
# vamos
# a
# escuchar
# el
# concierto
# .
# Entonces
# no
# me
# empuje
# Tenga
# un
# poquito
# más
# de
# cuidado
# conmigo
# .
#
#
# Por
# favor
# señora
# ayúdeme
# a
# recordar
# que
# hemos
# estado
# hablando
# mucho
# todo
# el
# día
# pero
# no
# me
# acuredo
# de
# las
# primeras
# palabras
# que
# usted
# me
# dijo
# .
#
#
# Mhh
# por
# favor
# señora
# ,
# tome
# su
# medicamente
# .
# Mira
# que
# son
# recomendados
# por
# el
# médico
# y
# si
# no
# te
# los
# tomas
# te
# puedes
# morir
# .
#
#
# Ehh
# si
# quiere
# lo
# podemos
# hacer
# el
# viernes
# ,
# no
# ?
# Pues
# ,
# a
# mí
# me
# queda
# libre
# porque
# no
# tengo
# nada
# que
# hacer
# y
# ya
# no
# tengo
# clases
# a
# esa
# hora
# .
#
#
# Qué
# desconsiderada
# !
# Nunca
# se
# preocupa
# por
# uno
# y
# no
# más
# le
# pregunta
# a
# uno
# las
# cosas
# que
# le
# interesan
# que
# …
# le
# interesan
# monetariamente
# y
# ya
# .
# Así
# no
# debería
# de
# ser
# .
#
#
# Que
# por
# qué
# ,
# pues
# por
# qué
# me
# hacés
# eso
# ?
# Ya
# ves
# que
# estoy
# en
# finales
# y
# …
# y
# no
# tengo
# tiempo
# y
# me
# pones
# a
# …
# a
# ir
# hasta
# el
# otro
# lado
# del
# campus
# y
# bien
# temprano
# .
# Pues
# y
# a
# parte
# de
# eso
# me
# toca
# esperate
# dos
# horas
# .
# Vos
# sabé
# que
# eso
# es
# un
# momento
# donde
# yo
# debería
# estar
# estudiando
# y
# usted
# debería
# estar
# preocupado
# por
# ...
# por
# cosas
# como
# el
# ...
# el
# final
# .
# Pues
# deberías
# de
# tener
# más
# consideración
# con
# mi
# tiempo
# y
# no
# deberías
# de
# jugar
# así
# .
#
#
# Pues
# que
# respete
# .
# No
# ve
# que
# estamos
# acá
# todos
# ..
# Nosotros
# .
# Cómo
# va
# a
# estrujarnos
# y
# a
# pasarnos
# por
# el
# medio
# ?
#
#
# Usted
# si
# es
# bobo
# ,
# hubiera
# dicho
# que
# usted
# no
# me
# había
# dejado
# ver
# su
# examen
# y
# simplemente
# yo
# estaba
# mirando
# así
# por
# encimita
# .
# Pa
# qué
# le
# reconoció
# ,
# le
# admitió
# todas
# esas
# cosas
# ?
#
#
# Ehh
# consejera
# ,
# me
# parece
# que
# es
# una
# falta
# de
# respeto
# que
# usted
# me
# cite
# a
# esta
# hora
# y
# no
# aparezca
# .
# Usted
# cree
# que
# yo
# no
# tengo
# nada
# más
# para
# hacer
# o
# que
# mi
# tiempo
# es
# gratis
# .
# Ehh
# la
# próxima
# vez
# sea
# más
# puntual
# en
# lo
# que
# dice
# .
#
#
# Hey
# sí
# .
# La
# verdad
# ,
# yo
# ,
# yo
# me
# quedo
# callado
# güevón
# .
# Yo
# no
# diría
# nada
# .
# O
# si
# mucho
# qué
# le
# diría
# parce
# ?
# Parce
# yo
# no
# le
# digo
# nada
# ,
# si
# no
# cabe
# la
# gente
# es
# normal
# que
# se
# metan
# .
# Hey
# respete
# ,
# no
# se
# meta
# por
# acá
# .
#
#
# Má
# ,
# qué
# te
# pasa
# que
# estás
# tan
# rara
# últimamente
# ?
# Yo
# le
# hablo
# y
# usted
# como
# que
# ,
# como
# que
# no
# escucha
# .
# Es
# como
# con
# ganas
# de
# dar
# órdenes
# .
# Qué
# tiene
# ?
# Sí
# ,
# dígame
# qué
# le
# pasa
# porque
# a
# mí
# no
# me
# gusta
# tampoco
# que
# usted
# esté
# en
# esa
# ,
# en
# esa
# forma
# de
# ser
# conmigo
# .
#
#
# Hey
# parce
# ,
# ayudame
# a
# limpiar
# .
# De
# verdad
# que
# me
# da
# pena
# con
# mis
# papás
# que
# ellos
# son
# muy
# ordenados
# y
# que
# esto
# aquí
# está
# todo
# vuelto
# nada
# .
# Ayudame
# ,
# yo
# tengo
# que
# estudiar
# ,
# si
# quiere
# después
# yo
# le
# hago
# un
# favor
# o
# luego
# yo
# limpio
# pero
# colaborame
# por
# favor
# .
#
#
# Señora
# ,
# a
# usted
# le
# mandaron
# esas
# pastillas
# para
# que
# esté
# mejor
# de
# salud
# .
# Mejor
# tómeselas
# para
# que
# no
# se
# ponga
# peor
# .
#
#
# Má
# ,
# usted
# por
# qué
# siempre
# tiene
# que
# estar
# diciéndome
# lo
# peor
# que
# puede
# pasar
# en
# vez
# de
# …
# apoyarme
# en
# las
# cosas
# buenas
# ?
#
#
# Má
# ,
# por
# favor
# pero
# escúcheme
# y
# ya
# no
# me
# regañe
# tanto
# .
#
#
# Mi
# señora
# venga
# ,
# no
# bote
# las
# pastillas
# .
# Tómeselas
# que
# eso
# le
# hace
# y
# usted
# las
# necesita
# .
#
#
# Hola
# ma
# ,
# me
# va
# a
# enseñar
# porfa
# cómo
# se
# hacen
# las
# galletas
# que
# tanto
# me
# gustan
# ?
#
#
# Má
# ,
# usted
# si
# le
# importa
# lo
# que
# yo
# sienta
# ?
#
#
# Hey
# ,
# qué
# le
# pasa
# ?
# Respete
# !
#
#
# Señora
# ,
# tómeselas
# .
# Hágalo
# que
# es
# por
# su
# bien
# .
#
#
# Por
# favor
# por
# que
# no
# me
# cumplió
# la
# cita
# ?
# Yo
# vivo
# muy
# ocupado
# .
#
#
# Niña
# ,
# sea
# prudente
# porque
# puede
# aporriar
# a
# otra
# persona
# y
# ocurre
# un
# accidente
# más
# grave
# .
#
#
# Mami
# ,
# por
# qué
# cambias
# tanto
# ?
# Sí
# ?
# Primero
# tenía
# paciencia
# y
# esperabas
# y
# quería
# que
# conversábamos
# .
#
#
# Señora
# ,
# puede
# entender
# más
# .
# Me
# puede
# explicar
# .
#
#
# Papá
# ,
# ¿
# por
# qué
# me
# mueve
# las
# cosas
# de
# donde
# las
# pongo
# ?
#
#
# Mesero
# ,
# yo
# no
# le
# pedí
# esto
# hermano
# .
# No
# le
# dije
# pues
# que
# no
# puedo
# comer
# berenjena
# .
# Traigame
# otra
# cosa
# por
# favor
# .
#
#
# E
# ave
# maria
# pa
# ,
# no
# le
# enseñaron
# …
# si
# no
# a
# usted
# hombre
# .
# Dejemos
# todo
# organizado
# .
#
#
# Hey
# no
# papá
# ,
# usted
# está
# viviendo
# en
# mi
# casa
# .
# Si
# no
# le
# gusta
# el
# perro
# ,
# chao
# .
#
#
# Caballero
# ,
# ¿
# cómo
# está
# ?
# Muchísimas
# gracias
# por
# ayudarme
# .
# ¿
# Me
# puede
# apretar
# el
# boton
# del
# quinto
# piso
# si
# es
# tan
# amable
# .
#
#
# Bueno
# Papá
# ,
# ya
# es
# hora
# de
# que
# me
# cuente
# sobre
# el
# pasado
# de
# la
# familia
# .
#
#
# Bueno
# yo
# ya
# le
# dije
# …
# para
# mi
# cumpleaños
# .
# ¿
# A
# usted
# qué
# le
# gustaría
# hacer
# ?
#
#
# Pa
# por
# qué
# me
# puso
# la
# libreta
# ahí
# si
# me
# tengo
# que
# ir
# rápido
# .
# No
# me
# mueva
# las
# cosas
# de
# dónde
# las
# tengo
# si
# me
# hace
# el
# favor
# .
#
#
# Por
# favor
# me
# ayuda
# a
# organizar
# las
# cajas
# de
# manera
# organizada
# .
#
#
#
# Señor
# ,
# ¿
# cómo
# está
# ?
# ¿
# me
# podría
# colaborar
# con
# esto
# llevándome
# esto
# hasta
# cierto
# piso
# por
# favor
# ?
#
#
# Buenas
# ¿
# cómo
# está
# ?
# Es
# que
# mirá
# yo
# no
# soy
# de
# por
# acá
# y
# me
# perdí
# .
# Entonces
# era
# para
# ver
# si
# me
# ayudaras
# a
# llegar
# a
# esta
# dirección
# .
#
#
# Buenas
# tardes
# señor
# ,
# será
# que
# usted
# me
# podría
# hacer
# un
# favor
# ,
# y
# se
# lo
# agradecería
# demasiada
#
#
# No
# me
# coja
# las
# cosas
# .
#
#
# ¿
# Puede
# marcar
# porfa
# el
# número
# tres
# ?
#
#
# Pa
# me
# va
# a
# ayudar
# con
# una
# tarea
# .
#
#
# Papá
# mira
# que
# las
# cajas
# están
# marcadas
# para
# que
# vaya
# colocando
# cada
# una
# en
# su
# lugar
# .
#
#
# Señor
# ,
# muchas
# gracias
# .
# ¿
# Será
# que
# me
# puede
# marcar
# el
# piso
# nueve
# ?
#
#
# Senor
# agente
# ,
# ¿
# será
# que
# me
# puede
# ayudar
# a
# llegar
# a
# este
# hotel
# ?
#
#
# Por
# favor
# no
# lo
# vuelvas
# a
# coger
# .
# Por
# favor
# no
# me
# mueva
# las
# cosas
# .
#
#
# Que
# no
# sea
# descarado
# ,
# que
# primero
# pague
# mi
# plata
# y
# después
# disponga
# de
# lo
# suyo
# pero
# no
# de
# lo
# mío
# .
#
#
# Por
# qué
# no
# tomó
# primero
# en
# cuenta
# lo
# que
# yo
# le
# dije
# antes
# de
# decirme
# que
# hiciera
# el
# proyecto
# como
# quería
# .
# Entonces
# que
# no
# me
# vuelva
# a
# decir
# que
# haga
# proyectos
# si
# no
# le
# gusta
# como
# yo
# se
# lo
# propuse
# .
#
#
# Si
# usted
# no
# tenía
# paciencia
# para
# atenderme
# ,
# yo
# le
# advertí
# que
# yo
# no
# podía
# comer
# berenjena
# .
# ¿
# Entonces
# por
# qué
# me
# trae
# berenjena
# si
# a
# mí
# me
# hace
# daño
# ?
# Así
# no
# se
# atiende
# al
# cliente
# .
#
# No
# me
# sirva
# nada
# entonces
# y
# listo
# .
#
#
# Pero
# mira
# que
# si
# no
# te
# tomas
# la
# drogra
# ,
# te
# vas
# a
# enfermar
# .
# No
# finja
# delante
# de
# mí
# porque
# no
# voy
# a
# estar
# todo
# el
# tiempo
# contigo
# .
#
#
# Señor
# por
# favor
# ponga
# música
# para
# que
# todos
# lo
# pasemos
# bien
# .
# A
# unos
# les
# gusta
# el
# reggaeton
# a
# otras
# les
# gusta
# la
# ranchera
# y
# a
# otra
# le
# gusta
# la
# de
# valle
# .
# Entonces
# colócate
# un
# disco
# para
# que
# nos
# dé
# gusto
# a
# todos
# ,
# para
# no
# aburrirnos
# .
# Colócame
# un
# disco
# que
# me
# guste
# a
# mí
# .
# Colócame
# nadie
# es
# eterno
# en
# el
# mundo
# y
# lo
# pasamos
# bien
# .
#
#
# Parce
# ,
# me
# parece
# mal
# que
# esté
# gastando
# la
# plata
# sabiendo
# que
# me
# debe
# mucho
# dinero
# .
#
#
# Que
# no
# me
# va
# a
# alcanzar
# el
# tiempo
# .
# Si
# me
# puede
# ayudar
# ,
# le
# agradecería
# mucho
# .
# Intento
# #
# Que
# varia
# vece
# le
# he
# dicho
# que
# no
# la
# mueva
# y
# siempre
# es
# igual
# .
# Que
# debería
# respetar
# más
# mis
# cosas
# .
#
#
# Qué
# desconsiderado
# !
# Sí
# tiene
# plata
# pa
# comer
# y
# salir
# ,
# pero
# no
# tiene
# plata
# pa
# pagale
# a
# uno
# .
# Qué
# conchudo
# .
#
#
# Yo
# le
# digo
# al
# mesero
# que
# …
# que
# pues
# que
# no
# respetó
# ,
# que
# por
# qué
# no
# respetó
# que
# a
# mí
# no
# me
# gustan
# las
# berenjenas
# .
# Pues
# …
# si
# va
# a
# hacer
# el
# trabajo
# ,
# hágalo
# bien
# y
# …
# y
# si
# está
# impaciente
# pues
# …
# pues
# no
# es
# culpa
# mía
# .
# Yo
# simplemente
# vengo
# a
# comer
# y
# espero
# que
# me
# atiendan
# de
# la
# mejor
# manera
# .
#
#
# Hey
# no
# ,
# si
# ,
# si
# yo
# respeto
# ,
# si
# yo
# respeto
# tus
# dos
# mascotas
# ,
# porque
# no
# ,
# porque
# no
# puede
# respetar
# a
# la
# mía
# .
#
# Está
# bien
# ,
# él
# es
# así
# ,
# por
# qué
# no
# lo
# deja
# ser
# cómo
# es
# .
# Si
# el
# perro
# quiere
# saludalo
# ,
# déjalo
# saludar
# .
# Además
# ,
# no
# sé
# si
# a
# él
# le
# moleste
# o
# no.
# Pero
# igual
# ,
# esta
# es
# la
# habitación
# de
# loh
# dos
# y
# así
# son
# las
# cosas
# y
# si
# vos
# me
# dijiste
# que
# ..
# que
# te
# gustaban
# los
# perros
# ,
# entonces
# ,
# no
# hay
# razón
# como
# para
# que
# le
# grités
# al
# mío
# .
# Cómo
# así
# ?
# tiene
# es
# que
# respetar
# lo
# mío
# también
# .
# Y
# al
# perro
# no
# le
# volvás
# a
# gritar
# ...
# que
# dijo
# pues
# ?
#
#
# Pá
# ,
# yo
# a
# usted
# le
# he
# dicho
# que
# las
# cosas
# no
# me
# las
# mueva
# de
# lugar
# y
# me
# las
# deje
# donde
# yo
# las
# pongo
# .
# No
# …
# déjelas
# donde
# están
# .
#
#
# Profe
# ,
# yo
# considero
# que
# usted
# debería
# ser
# más
# consecuente
# .
# Si
# usted
# me
# dijo
# en
# un
# principio
# ,
# me
# sugirió
# que
# hablara
# de
# este
# tema
# ,
# no
# entiendo
# porque
# ahora
# decirme
# que
# no
# le
# interesó
# viendo
# que
# desde
# un
# principio
# usted
# fue
# el
# que
# ,
# el
# que
# lo
# propuso
# .
# Entonces
# me
# parece
# que
# está
# siendo
# muy
# inconsecuente
# en
# la
# forma
# de
# evaluar
# y
# de
# comentar
# el
# trabajo
# que
# le
# acabo
# de
# hacer
# .
#
#
# Mesero
# ,
# yo
# a
# usted
# le
# dije
# muy
# claramente
# que
# yo
# no
# podía
# consumir
# berenjena
# .
# Y
# desde
# que
# usted
# vino
# aquí
# a
# pedir
# las
# ordenes
# ,
# los
# platos
# usted
# estaba
# muy
# impaciente
# .
# Ehh
# qué
# le
# digo
# güevón
# ?
# Mentiras
# que
# no.
# Yo
# no
# le
# digo
# nada
# .
# Yo
# me
# quedo
# callado
# y
# no
# me
# como
# la
# berenjena
# .
#
#
# Pá
# ,
# no
# tire
# las
# cosas
# por
# ahí
# .
# Póngalas
# en
# una
# manera
# más
# organizada
# .
# Por
# ejemplo
# en
# este
# rinconcito
# .
#
#
# Hey
# parce
# ,
# mirá
# que
# la
# gente
# no
# le
# gusta
# esa
# música
# .
# Poné
# ,
# ponete
# otro
# tema
# .
# Y
# si
# me
# dice
# que
# no
# ,
# pues
# yo
# le
# digo
# o
# la
# otra
# es
# llegar
# y
# con
# plata
# .
# Llego
# y
# le
# paso
# plata
# hey
# ponete
# este
# tema
# .
#
#
# Pá
# ,
# imaginate
# que
# tengo
# una
# tarea
# de
# historia
# en
# la
# que
# me
# toca
# decir
# el
# árbol
# genealógico
# .
# Entonces
# ,
# necesito
# que
# me
# ayudé
# a
# hacerla
# .
# Usted
# se
# acuerda
# de
# los
# nombres
# de
# los
# antepasados
# y
# eso
# ?
#
#
# Amigo
# disculpe
# ,
# será
# que
# me
# puede
# ayudar
# .
# Es
# que
# estoy
# en
# el
# hotel
# tal
# y
# estoy
# perdido
# .
# Por
# dónde
# es
# ese
# hotel
# más
# o
# menos
# ?
#
#
# Profe
# ,
# yo
# a
# usted
# le
# dije
# sobre
# el
# tema
# .
# Uste
# me
# puso
# uno
# que
# a
# mi
# no
# me
# gusta
# .
# Y
# ya
# ,
# eso
# fue
# todo
# lo
# que
# pude
# hacer
# .
#
#
# Pá
# ,
# ¿
# usted
# por
# qué
# siempre
# me
# tiene
# que
# esconder
# las
# cosas
# donde
# no
# las
# encuentro
# ?
#
#
# Señor
# ,
# usted
# no
# me
# prestó
# atención
# .
# Si
# usted
# quiere
# trabajar
# ,
# pues
# hágalo
# bien
# ,
# no
# ?
#
#
# Disculpe
# ,
# será
# que
# me
# puedes
# ayudar
# a
# marcar
# el
# botón
# ?
#
#
# Disculpe
# señor
# ,
# usted
# sabe
# cómo
# puedo
# llegar
# a
# este
# lugar
# ?
#
#
# Papá
# ,
# usted
# para
# qué
# pone
# la
# mochila
# donde
# no
# es
# ?
#
#
# Profe
# ,
# recuerde
# que
# esa
# fue
# su
# idea
# .
#
#
# señor
# ,
# recuerde
# que
# era
# sin
# berenjenas
# .
#
#
# Señor
# ,
# me
# puede
# ayudar
# pisando
# el
# tres
# ?
# Gracias
# .
#
#
# Señor
# ,
# buenas
# .
# Usted
# me
# puede
# colaborar
# por
# favor
# con
# esta
# dirección
# .
#
#
# Ayúdeme
# .
#
#
# Necesito
# que
# me
# pague
# rápido
# .
# He
# sabido
# que
# tienes
# plata
# .
#
#
# Mesero
# ,
# usted
# no
# me
# atendión
# bien
# .
# Yo
# quería
# comer
# pero
# no
# con
# ciertas
# yerbas
# .
#
#
# Profe
# pero
# si
# yo
# quería
# escoger
# otro
# tema
# ,
# ¿
# usted
# por
# qué
# me
# sugirió
# ese
# ?
#
#
# Mesero
# ,
# discuple
# por
# favor
# .
# Yo
# le
# había
# dicho
# que
# no
# puedo
# comer
# berenjena
# .
# Por
# favor
# ,
# me
# lo
# retira
# .
# Gracias
# .
#
#
# Si
# quiere
# ,
# pida
# permiso
#
#
# ¿
# Ma
# ,
# usted
# por
# qué
# es
# así
# ?
#
#
# Disculpe
# señor
# me
# podría
# apretar
# el
# botón
# para
# el
# tercer
# piso
# ,
# graicas
# .
#
#
# Señora
# ,
# tómese
# las
# pastillas
# ya
# que
# es
# por
# su
# bien
# .
#
#
# Desculpe
# señor
# ,
# usted
# me
# puede
# indicar
# cómo
# puedo
# llegar
# al
# hotel
# X
# ?
#
#
# ¿
# Usted
# está
# aquí
# para
# el
# novio
# o
# la
# novia
# ?
#
#
# ¿
# usted
# sólo
# tiene
# dos
# perros
# o
# aquí
# sólo
# está
# con
# uno
# ?
#
#
# Disculpe
# ¿
# por
# favor
# puede
# retirar
# el
# pedazo
# de
# berenjena
# que
# puso
# en
# el
# plato
# ?
#
#
# ¡
# Bien
# pueda
# chica
# !
#
#
# ¿
# Señor
# me
# ayuda
# por
# favor
# con
# el
# piso
# número
# tal
# ?
#
#
# Mi
# señora
# mire
# usted
# se
# tiene
# que
# tomar
# las
# pastillas
# .
# Sea
# juiciosa
# tómeselas
# .
# Por
# favor
# que
# es
# por
# su
# salud
# .
#
#
# Señor
# ,
# ¿
# usted
# me
# puede
# hacer
# el
# favor
# de
# indicarme
# hacia
# adónde
# me
# debo
# dirigir
# para
# llegar
# al
# hotel
# ?
#
#
# Señora
# ,
# ¿
# usted
# me
# puede
# recordar
# cómo
# es
# su
# nombre
# ?
#
#
# Papi
# por
# favor
# no
# me
# mueva
# la
# maleta
# del
# sitio
# .
#
#
#
# Señor
# mesero
# por
# favor
# me
# retira
# este
# plato
# con
# berenjena
# que
# no
# lo
# puedo
# comer
# .
#
#
# Disculpa
# ,
# pero
# debe
# de
# respetar
# el
# espacio
# de
# todos
# .
#
#
# Ay
# por
# favor
# ayúdeme
# .
#
#
# Conscienticese
# tomando
# esas
# pastillas
# puede
# mejorar
# su
# calidad
# de
# vida
# y
# de
# salud
# .
#
#
# Hey
# chica
# ,
# rote
# la
# pelota
# para
# que
# todos
# juguemos
# .
#
#
# Señor
# policia
# ,
# ¿
# usted
# me
# podría
# indicar
# dónde
# queda
# tal
# hotel
# .
# ¿
# Muchas
# gracias
# que
# estoy
# perdida
# .
#
#
# Disculpe
# ,
# de
# todas
# maneras
# tiene
# razón
# que
# yo
# no
# aporté
# para
# lo
# que
# ella
# me
# colaboró
# .
#
#
# Por
# favor
# colabore
# y
# nos
# deje
# el
# espacio
# que
# nos
# corresponda
# .
# Muchas
# gracias
# ,
# con
# permiso
# .
#
#
# Por
# favor
# ,
# mire
# que
# yo
# también
# estoy
# en
# el
# ...
# para
# participar
# que
# podemos
# interactuar
# las
# dos
# por
# favor
# juguemos
# juntas
# que
# haga
# parte
# del
# equipo
# que
# yo
# también
# soy
# parte
# del
# equipo
# .
# Gracias
# .
#
#
# Ay
# por
# favor
# señora
# disculpe
# ,
# usted
# me
# dio
# el
# nombre
# cuando
# nos
# presentamos
# pero
# se
# me
# ha
# pasado
# .
# ¿
# Me
# lo
# repite
# por
# favor
# ?
#
#
# Por
# favor
# me
# colabora
# para
# tocar
# el
# piso
# que
# es
# que
# estoy
# muy
# atareada
# .
# Tengo
# muchas
# cosas
# acá
# .
# Tengo
# muhcas
# cosas
# y
# no
# alcanzo
# a
# tocar
# el
# botón
# .
#
#
# Como
# es
# te
# ocurre
# que
# no
# tomas
# las
# pastillas
# ¿
# entonces
# cómo
# te
# quieres
# aliviar
# ?
# Así
# no
# puede
# ser
# porque
# si
# no
# toma
# medicamento
# ,
# ¿
# cómo
# vas
# a
# seguir
# adelante
# ?
# ¿
# Cómo
# te
# quieres
# curar
# ?
#
#
# Mira
# ayúdame
# con
# eso
# porque
# yo
# quiero
# hacer
# ...
# papá
# ayudame
# a
# hacer
# el
# árbol
# genealógico
# porque
# es
# que
# yo
# quiero
# que
# ...
# conservar
# toda
# la
# familia
# .
# Entonces
# para
# que
# me
# colabores
# por
# favor
# porque
# yo
# sola
# no
# puedo
# .
# Me
# es
# imposible
# .
# Tú
# tienes
# más
# conocimiento
# ,
# es
# una
# persona
# ya
# de
# edad
# .
# Ya
# tiene
# más
# conocimiento
# entonces
# me
# puedes
# colaborar
# con
# los
# datos
# de
# la
# familia
# .
#
#
# Señor
# por
# favor
# dígame
# la
# dirección
# de
# ese
# hotel
# porque
# es
# que
# me
# perdí
# .
#
# Sinceramente
# me
# perdí
# entonces
# ¿
# cómo
# hago
# ?
# Por
# favor
# colaboreme
# para
# yo
# poder
# llegar
# el
# hotel
# .
#
#
# Me
# extraña
# porque
# yo
# realmente
# quería
# escoger
# el
# tema
# que
# yo
# sugerí
# .
# Pero
# no
# sé
# que
# razón
# tendría
# usted
# en
# casi
# imponerme
# el
# tema
# suyo
# y
# por
# respeto
# a
# usted
# lo
# hice
# .
# Entonces
# me
# extraña
# ahora
# que
# lo
# dice
# .
#
#
# No
# me
# parece
# justo
# este
# tipo
# de
# procedimiento
# que
# usted
# cuente
# con
# mi
# tiempo
# y
# que
# me
# haga
# venir
# hasta
# acá
# y
# no
# esté
# .
# Quiero
# que
# me
# dé
# una
# explicación
# .
#
#
# Vamos
# a
# salir
# perdiendo
# porque
# usted
# no
# está
# pasando
# bien
# el
# balón
# .
#
# Entones
# pongámosnos
# las
# pilas
# a
# pasarlo
# más
# rápido
# .
#
#
# ¿
# Será
# que
# usted
# me
# puede
# ayudar
# con
# una
# dirección
# que
# creo
# que
# estoy
# perdida
# ?
# Estoy
# un
# poco
# angustiada
# porque
# no
# soy
# de
# acá
# .
# Tengo
# teléfonos
# .
# ¿
# Cómo
# me
# podría
# ayudar
# ?
#
#
# Pero
# si
# fue
# usted
# que
# me
# dio
# el
# tema
# ,
# ¿
# por
# qué
# ahora
# dice
# que
# no
# le
# gusta
# ?
#
#
# Por
# que
# mi
# plato
# tiene
# eso
# ahí
# .
# Creo
# que
# fui
# muy
# clara
# con
# usted
# .
#
#
# Señor
# ,
# ¿
# por
# favor
# cuando
# llegue
# al
# próximo
# piso
# ,
# o
# sea
#
# al
# tercer
# piso
# ,
# por
# favor
# Usted
# sería
# tan
# amable
# de
# apretar
# el
# botón
# del
# acensor
# para
# subir
# al
# tercer
# piso
# ?
#
#
# Por
# favor
# señor
# agente
# ,
# sería
# tan
# amable
# de
# guiarme
# hasta
# donde
# hasta
# el
# hotel
# ,
# que
# me
# entretuve
# tanto
# ,
# es
# que
# no
# me
# acuerdo
# en
# verdad
# por
# donde
#
# porque
# Bogotá
# es
# muy
#
# grande
# .
# Me
# perdí
# ,
#
# estoy
# perdido
# ,
# por
# favor
# ¿
# usted
# sería
# tan
# amable
# de
# encaminarme
# por
# dónde
# puedo
# llegar
# al
# hotel
# ?
#
#
# ¿
# usted
# por
# qué
# está
# aquí
# en
# la
# boda
# ?
#
#
# ¿
# Tienes
# un
# perro
# o
# tiene
# dos
# ?
#
#
# Muévase
# .
#
#
#
# usted
# no
# me
# dijo
# pues
# que
# me
# iba
# a
# pagar
# .
# ¿
# Entonces
# cuándo
# me
# va
# a
# pagar
# pues
# ?
#
#
# Me
# parece
# muy
# mal
# hecho
# que
# me
# haya
# citado
# y
# no
# estar
# en
# el
# presente
#
#
# Muy
# mal
# hecho
# que
# usted
# me
# haya
# traido
# esto
# porque
# a
# mí
# no
# me
# gusta
# eso
# y
# usted
# es
# el
# paciente
# para
# atender
# los
# clientes
# .
#
#
#
# Es
# que
# usted
# no
# ve
# ,
# ¿
# por
# qué
# tan
# mal
# educada
# ?
#
#
# Oiga
# pa
# ¿
# usted
# por
# qué
# tiene
# que
# moverlas
# para
# donde
# no
# es
# ?
# Es
# mejor
# organizaditas
#
# más
# fácil
# organizar
# este
# trasteo
#
#
# Mami
# pero
# es
# que
# yo
# tengo
# una
# vida
# independiente
# y
# usted
# es
# otra
# .
# Entonces
# es
# bueno
# que
# me
# respetes
# mis
# ideas
# .
#
#
# ponéte
# las
# pilas
# ,
# ya
# llegaron
# ellos
# ponéte
# las
# pilas
# para
# que
# no
# vean
# esas
# botellas
# de
# cerveza
# ahí
# .
# Hágale
# ,
# hágale
# .
#
#
# Ay
# oiga
# cómo
# le
# parece
# que
# en
# este
# momento
# no
# recuerdo
# cómo
# es
# que
# usted
# se
# llama
# .
# ¿
# usted
# me
# repite
# su
# nomre
# por
# favor
# ?
#
#
# ¿
# Estás
# esperando
# a
# tu
# novia
# ?
# Ah
# bueno
# ,
# muy
# bueno
# haber
# charlado
# un
# ratico
# .
# Usted
# está
# esperando
# a
# la
# novia
# bueno
# .
# Qué
# tan
# bueno
# que
# estés
# aquí
# .
#
#
# Ay
# papi
# yo
# le
# dije
# a
# usted
# que
# no
# me
# moviera
# el
# bolso
# .
#
#
#
# A
# usted
# lo
# único
# que
# le
# intresea
# es
# la
# tarjeta
# de
# crédito
# ,
# no
# le
# interesa
# que
# yo
# asisto
# pues
# .
#
#
# Ah
# María
# usted
# le
# dijo
# que
# no
# iba
# a
# decir
# nada
# a
# mi
# jefe
# y
# le
# dijo
# otra
# cosa
# que
# no
# era
# totalmente
# verdad
# .
#
#
# Jefe
# pero
# usted
# me
# dijo
# a
# mí
# que
# llevara
# este
# tema
# y
# no
# me
# dijo
# -
# no
# le
# pareció
# sabiendo
# que
# yo
# ya
# había
# escogido
# otro
# ya
# .
#
#
#
# Usted
# quería
# hablar
# conmigo
# pero
# la
# estuve
# esperando
# dos
# horas
# y
# no
# llegó
# .
# ¿
# Entonces
# qué
# podemos
# hacer
# ahí
# ?
#
#
# Señor
# ,
# yo
# le
# dije
# a
# usted
# que
# no
# podía
# comer
# berenjena
# ,
# ¿
# por
# qué
# me
# trajo
# lo
# que
# yo
# no
# le
# pedí
# ?
#
#
# Señora
# ,
# tenga
# mucho
# cuidado
# mire
# …
# .
#
#
#
# Usted
# no
# tiene
# por
# qué
# venir
# a
# gritarle
# a
# los
# perritos
# .
# hágame
# el
# favor
# y
# respete
# ,
# y
# si
# no
# le
# gusta
# entonces
# se
# queda
# callado
# .
#
#
# Hermana
# ,
# venga
# y
# me
# ayuda
# a
# limpiar
# que
# vienen
# mis
# papas
# .
# Hágame
# el
# favor
# ,
# usted
# es
# la
# que
# hace
# el
# desorden
# completo
# .
#
#
# Señor
# ,
# ¿
# usted
# es
# tan
# amable
# y
# apreta
# el
# botón
# para
# el
# tercer
# piso
# ?
#
#
# Señora
# ,
# por
# favor
# no
# bote
# las
# pastas
# .
# Tiene
# que
# tomárselas
# .
# SI
# no
# ,
# no
# se
# puede
# aliviar
# .
#
#
# Señora
# ,
# señora
# por
# favor
# páseme
# la
# pelota
# ¿
# Usted
# por
# qué
# se
# queda
# con
# ella
# ?
#
#
# Papá
# por
# favor
# cuénteme
# todo
# lo
# todo
# lo
# que
# cómo
# se
# llamaban
# los
# abuelos
# los
# bisabuelos
# .
#
#
# Amigo
# ,
# ¿
# qué
# es
# lo
# que
# usted
# quiere
# hacer
# ?
#
#
# Colega
# ,
# le
# pido
# el
# favor
# que
# me
# diga
# qué
# días
# podemos
# reunir
# para
# que
# empecemos
# a
# trabajar
# .
#
#
# Señor
# ,
# le
# pregunto
# .
# ¿
# Dónde
# queda
# esta
# dirección
# ?
# ¿
# Usted
# me
# puede
# decir
# ?
#
#
# Señora
# ,
# ¿
# usted
# me
# hace
# el
# favor
# y
# me
# recuerda
# su
# nombre
# que
# no
# me
# acuerdo
# cómo
# se
# llama
# ?
#
#
# Señora
# ,
# oigame
# ,
# ¿
# este
# perro
# es
# suyo
# ?
# ¿
# O
# cuántos
# perros
# tiene
# ?
#
#
# Ah
# papá
# ,
# yo
# te
# he
# dicho
# que
# no
# me
# mueva
# las
# cosas
# del
# sitio
# dónde
# yo
# las
# pongo
# .
#
#
# No
# hermano
# ,
# hágale
# pagueme
# la
# plata
# .
# ¿
# Cómo
# así
# ?
# Entonces
# yendose
# a
# otras
# partas
# pues
# y
# gastándose
# la
# plata
# .
# Pagueme
# la
# plata
# primero
# .
#
#
# Qué
# hubo
# mija
# .
# Está
# bien
# que
# llegue
# para
# ubicarse
# bien
# ...
# Pero
# no
# me
# retire
# aquí
# al
# lado
# de
# mis
# amigos
# .
#
#
# Ay
# mamá
# tú
# yo
# yo
# nos
# hemos
# entendido
# mucho
# .
# Y
# es
# rico
# que
# yo
# pueda
# contarte
# las
# cosas
# .
# Pero
# es
# que
# te
# estás
# volviendo
# muy
# regañona
# y
# cansona
# .
# Entonces
# nooo
# ,
# bájele
# un
# poquito
# el
# tono
# mami
# .
#
#
# Vea
# amigo
# ,
# si
# de
# pronto
# es
# que
# a
# ti
# no
# te
# gustan
# los
# perros
# ,
# dale
# yo
# no
# tengo
# ningun
# problema
# .
# Cuando
# tú
# vengas
# ,
# entonces
# yo
# guardo
# mi
# perro
# en
# otro
# lugar
# para
# que
# no
# te
# moleste
# pero
# tampoco
# me
# gusta
# que
# lo
# desprecies
# .
#
#
# Ay
# mi
# hermana
# venga
# ,
# muévase
# a
# ver
# que
# vienen
# mis
# papás
# y
# nos
# ven
# esto
# y
# usted
# sabe
# la
# cantaleta
# que
# nos
# echan
# .
# Hágale
# pues
# pilas
# .
# Dígame
# usted
# qué
# hace
# que
# yo
# hago
# otra
# cosa
# y
# así
# nos
# repartimos
# los
# oficios
# .
#
#
# Ay
# papá
# qué
# rico
# ,
# imagináte
# que
# quiero
#
# hacer
# el
# árbol
# genealógicao
# de
# la
# familia
# .
# Y
# yo
# sé
# que
# usted
# tiene
# una
# memoria
# espectactular
# .
# Por
# ahí
# derecho
# me
# cuentas
# historias
# Quiero
# saeber
# como
# todo
# quíenes
# eran
# mis
# tatarabuelos
# ,
# abuelos
# .
# Para
# poder
# hacer
# la
# tus
# de
# hecho
# me
# cuentas
# tus
# historias
# fascinantes
# que
# tienes
# .
#
#
# Ay
# mami
# ¿
# se
# acuerda
# de
# las
# galletas
# que
# hicimos
# el
# año
# pasado
# en
# diciembre
# ?
# Ay
# dame
# la
# receta
# ,
# que
# estas
# quieres
# hacer
# de
# esas
# galletas
# .
#
#
# Hola
# ,
# buenas
# noches
# señor
# ¿
# cómo
# está
# ?
# .
# Imagínese
# que
# estoy
# aquí
# de
# paseo
# .
# Y
# caminé
# y
# caminé
# y
# caminé
# tanto
# que
# estoy
# como
# medio
# perdida
# .
# Usted
# ,
# ¿
# por
# favor
# me
# ayuda
# a
# ubicarme
# ?
# O
# cómo
# me
# desplazo
# .
# Es
# que
# tengo
# que
# coger
# como
# para
# llegar
# al
# hotel
# donde
# yo
# estoy
# hospedada
# .
#
#
#
# Ay
# Hola
# ,
# todo
# lo
# usted
# me
# ha
# enseñado
# ,
# y
# todo
# el
# tiempo
# que
# hemos
# estdos
# juntos
# pues
# escuchandole
# las
# intrucciones
#
# imagínese
# se
# me
# ha
# olvidado
# cuál
# es
# que
# es
# su
# nombre
# .
# Que
# pena
# con
# usted
# .
# Y
# yo
# que
# tengo
# el
# oficio
# de
# cambiarselos
# ...
# ¿Cuál
# es
# que
# es
# tu
# nombre
# ?
#
#
# Qué
# perro
# tan
# lindo
# que
# tiene
# usted
# .
# ¿
# Y
# ese
#
# también
# es
# suyo
# ?
# ¿
# O
# se
# le
# arrimó
# ?
#
#
# No
# ,
# que
# me
# hizo
# quedar
# mal
# con
# mi
# jefe
# .
# Me
# hizo
# quedar
# mal
# con
# mi
# jefe
# .
#
#
# Usted
# cree
# que
# solamente
# tengo
# tiempo
# para
# esperala
# ?
#
#
# Pa
# dónde
# va
# usted
# ?
#
#
# Que
# me
# tenga
# paciencia
# .
# Amá
# téngame
# paciencia
# .
#
#
# Hágame
# el
# favor
# y
# aprieta
# el
# tres
# .
#
#
# Señora
# ,
# por
# favor
# tómese
# las
# pastillitas
# .
# Me
# voy
# a
# tomar
# la
# mía
# .
#
#
# Por
# favor
# ,
# ponga
# la
# música
# que
# nosotros
# queremos
# .
#
#
# Acuérdese
# que
# todos
# jugamos
# juntos
# .
#
#
# Mamá
# ,
# me
# da
# porfa
# la
# receta
# de
# las
# galletas
# .
#
#
# Usted
# me
# podría
# colaborar
# para
# llegar
# al
# hotel
# ?
#
#
# Señora
# ,
# me
# repite
# su
# nombre
# por
# favor
# ?
#
#
# Disculpe
# ,
# puede
# oprimir
# el
# botón
# para
# el
# tercer
# piso
# por
# favor
# ?
#
#
# Profe
# ,
# acuérdate
# que
# usted
# me
# dijo
# que
# escogiera
# ese
# tema
# y
# no
# el
# tema
# que
# yo
# pretendía
# seguir
# .
#
#
# Por
# favor
# padre
# ,
# usted
# sabe
# que
# esas
# no
# se
# puede
# mover
# los
# artículos
# donde
# están
# para
# uno
# poderlos
# encontrar
# .
#
#
# Madre
# ,
# tiene
# que
# estar
# pendiente
# de
# las
# cuestiones
# que
# uno
# le
# habla
# para
# que
# no
# interprete
# las
# cosas
# mal
# .
#
#
# Ahh
# pero
# es
# que
# son
# cuestiones
# entregadas
# ,
# sentimientos
# entregados
# .
# Por
# lo
# cuales
# no
# podemos
# meternos
# en
# la
# vida
# de
# los
# demás
# .
# Usted
# no
# debería
# haberle
# dicho
# eso
# a
# mi
# jefe
# .
#
#
# Por
# favor
# ,
# me
# hace
# el
# favor
# y
# me
# cambia
# el
# plato
# que
# no
# me
# gusta
# esa
# clase
# de
# plato
# .
# Porque
# me
# da
# alergia
# comer
# esa
# clase
# de
# comida
# .
# Ok
# ?
# Por
# favor
# ,
# me
# la
# puede
# cambiar
# ?
#
#
# Por
# favor
# ,
# me
# puede
# respetar
# un
# poquito
# que
# no
# nos
# podemos
# comparar
# .
# Por
# lo
# tanto
# ,
# usted
# por
# su
# parte
# y
# yo
# por
# mi
# parte
# .
#
#
# Padre
# ,
# eso
# me
# ofusca
# tanto
# tanta
# desorganización
# .
# Por
# lo
# tanto
# ,
# quiero
# decirte
# con
# todo
# cariño
# que
# deje
# las
# cosas
# así
# que
# yo
# más
# tarde
# las
# organizo
# .
# Ok
# ?
#
#
# Madre
# ,
# usted
# por
# qué
# me
# ignora
# tanto
# en
# las
# cuestiones
# y
# las
# desiciones
# ?
# Por
# favor
# ,
# tenga
# más
# cuidado
# en
# lo
# que
# digas
# .
# Ok
# ?
#
#
# Por
# favor
# ,
# entonces
# dejemos
# las
# cuestiones
# así
# .
# Usted
# por
# su
# lado
# y
# yo
# por
# mi
# lado
# y
# no
# quiero
# que
# se
# vuelva
# a
# meter
# con
# mis
# perros
# y
# yo
# con
# sus
# perros
# .
#
#
# Hermana
# ,
# por
# favor
# ,
# tenemos
# que
# organicemos
# todo
# como
# debe
# ser
# en
# la
# casa
# ,
# limpia
# ,
# ordenada
# y
# pa
# que
# la
# gente
# vea
# que
# la
# casa
# la
# encontremos
# …
# Mis
# padres
# encuentren
# la
# casa
# bien
# organizada
# .
# Por
# favor
# ,
# que
# sea
# más
# decente
# en
# las
# cuestiones
# del
# aseo
# .
#
#
# Caballero
# ,
# por
# favor
# ,
# me
# puede
# colaborar
# que
# estoy
# ofuscado
# con
# toda
# esta
# cantidad
# de
# papeles
# ?
# Me
# colabora
# con
# el
# botón
# del
# ascensor
# para
# poder
# yo
# circular
# normalmente
# ,
# que
# la
# gente
# no
# se
# moleste
# ,
# ok
# ?
#
#
# Amigo
# ,
# por
# favor
# ,
# colóquenos
# a
# gusto
# la
# canción
# que
# a
# nosotros
# nos
# gusta
# ,
# no
# al
# gusto
# de
# usted
# .
# Por
# eso
# le
# estamos
# pagando
# .
# Ok
# ?
#
#
# Madre
# ,
# por
# qué
# no
# me
# colabora
# con
# la
# receta
# que
# tú
# sabes
# de
# las
# galletas
# ?
# Si
# te
# acuerdas
# ?
# O
# búsquelas
# donde
# esté
# guardada
# tus
# recetas
# para
# poder
# colaborarnos
# para
# hacer
# las
# recetas
# de
# galleticas
# ,
# ok
# ?
#
#
# Amigo
# ,
# por
# qué
# no
# nos
# vamos
# para
# una
# finquita
# a
# relajarnos
# ,
# tomarnos
# unos
# traguitos
# o
# usted
# qué
# piensa
# que
# debemos
# de
# hacer
# ?
# Pues
# ,
# a
# mí
# me
# gustaría
# una
# finquita
# pa
# pasar
# bien
# bueno
# .
# Ese
# me
# gustaría
# que
# sea
# el
# regalo
# más
# grande
# .
# Ok
# ?
#
#
# Amiga
# ,
# por
# qué
# no
# nos
# reunimos
# en
# el
# espacio
# que
# tú
# te
# queda
# …
# que
# usted
# piense
# que
# te
# quede
# al
# espacio
# pa
# podernos
# reunir
# y
# hacer
# ese
# trabajo
# ,
# ok
# ?
#
#
# Por
# favor
# ,
# señor
# agente
# ,
# usted
# me
# puede
# colaborar
# para
# yo
# ubicarme
# a
# mi
# sitio
# de
# llegada
# que
# es
# que
# no
# me
# acuerdo
# dónde
# estoy
# ubicado
# o
# mirar
# a
# quién
# llamamos
# para
# poder
# ubicarme
# ...
# al
# hotel
# .
#
#
# Madre
# ,
# se
# me
# olvidó
# tu
# nombre
# pero
# tu
# sabes
# que
# estamos
# en
# una
# situación
# de
# trabajo
# muy
# muy
# delicada
# .
# Por
# favor
# me
# recuerda
# tu
# nombre
# ?
#
#
# Amigo
# ,
# estamos
# dialogando
# hace
# rato
# pero
# sinceramente
# no
# me
# acuerdo
# usted
# a
# qué
# vino
# .
# Por
# el
# novio
# o
# por
# la
# novia
# ?
#
#
# Amiga
# ,
# cuántos
# perros
# tiene
# ?
# Uno
# o
# dos
# perros
# ?
# Porque
# los
# perros
# tiene
# que
# estar
# ahí
# pendiente
# de
# los
# perros
# para
# que
# no
# se
# envolaten
# .
# Entonces
# tenemos
# que
# estar
# pendiente
# de
# los
# perros
# para
# que
# no
# se
# nos
# envolaten
# y
# tener
# bozales
# para
# los
# perros
# para
# que
# no
# nos
# tengamos
# un
# problema
# con
# los
# vecinos
# y
# los
# ciudadanos
# alrededor
# ,
# ok
# ?
#
#
# Hey
# ,
# no
# se
# preocupe
# tanto
# por
# mis
# cosas
# .
#
#
# Ehhh
# mija
# ,
# muy
# gorda
# ,
# no
# cabe
# ?
#
#
# Por
# favor
# papá
# ,
# no
# tire
# las
# cajas
# .
#
#
# Si
# a
# usted
# no
# le
# gusta
# mi
# perro
# ,
# ni
# modo
# de
# que
# vuelva
# .
#
#
# Mire
# ,
# vea
# ,
# por
# su
# salud
# ,
# por
# su
# salud
# ,
# por
# su
# bienestar
# es
# mejor
# que
# se
# tome
# las
# pastillas
# .
# No
# las
# bote
# .
#
#
# Hey
# ,
# acuérdese
# que
# estamos
# jugando
# en
# equipo
# .
# No
# estamos
# jugando
# de
# a
# uno
# .
#
#
# Venga
# corazón
# ,
# cuál
# es
# que
# es
# su
# nombre
# ?
#
#
# Amigo
# ,
# usted
# es
# familiar
# del
# novio
# o
# de
# la
# novia
# ?
#
#
# Jefa
# ,
# no
# era
# tan
# urgente
# lo
# que
# teníamos
# que
# hablar
# ?
# Recuerde
# que
# …
# .
#
#
#
# Por
# favor
# ,
# papá
# ,
# me
# deja
# las
# cajas
# en
# un
# lugar
# donde
# yo
# las
# pueda
# identificar
# .
#
#
# Ehh
# señor
# ,
# por
# favor
# ,
# me
# oprime
# el
# botón
# del
# piso
# donde
# me
# bajo
# .
# Gracias
# .
#
#
# Señora
# ,
# recuerde
# que
# esas
# pastillas
# son
# para
# su
# salud
# ,
# así
# que
# por
# favor
# ,
# no
# las
# bote
# .
# Tómeselas
# .
#
#
# Hey
# por
# favor
# ,
# páseme
# el
# balón
# .
#
#
# Hey
# papá
# ,
# porque
# no
# me
# cuenta
# sobre
# mi
# familia
# ?
#
#
# Por
# favor
# ,
# acuérdate
# que
# me
# debes
# de
# pagar
# la
# plata
# .
# Acuérdate
# que
# necesito
# pagar
# la
# renta
# ,
# necesito
# pagar
# muchas
# deudas
# .
# Entonces
# por
# favor
# ,
# devuélvame
# ,
# pues
# ,
# el
# dinero
# que
# me
# debes
# .
# Por
# favor
# ,
# recuerda
# el
# dinero
# que
# me
# debes
# ,
# necesito
# ,
# te
# doy
# un
# plazo
# ,
# para
# que
# me
# lo
# pagues
# ,
# porque
# recuerda
# que
# yo
# necesito
# también
# pagar
# mis
# deudas
# y
# mi
# renta
# .
#
#
# Usted
# debiera
# de
# haber
# hecho
# el
# proyecto
# que
# el
# jefe
# le
# dijo
# ,
# más
# no
# lo
# que
# ella
# pensaba
# .
# Debería
# escoger
# otro
# tema
# ,
# sentémonos
# juntos
# e
# investiguemos
# haber
# el
# tema
# que
# más
# nos
# convenga
# o
# más
# nos
# guste
# .
#
#
# Por
# favor
# ,
# dígame
# lo
# tan
# urgente
# qué
# es
# .
# Por
# favor
# ,
# dígame
# la
# causa
# ,
# razón
# o
# circunstancia
# por
# qué
# me
# hizo
# esperar
# tanto
# y
# no
# llegó
# ,
# no
# llegó
# .
#
#
# Si
# no
# tienes
# otro
# plato
# para
# ofrecerme
# ,
# dígame
# con
# claridad
# y
# yo
# me
# retiro
# .
#
#
# Tranquilo
# ,
# no
# se
# preocupe
# que
# si
# no
# alcanza
# el
# ascensor
# yo
# le
# colaboro
# para
# ayudarle
# …
# como
# vienen
# tan
# encartado
# ,
# entonces
# para
# ayudarlo
# para
# el
# tercer
# piso
# .
#
#
# Señora
# por
# favor
# ,
# me
# anota
# su
# nombre
# aquí
# .
# Me
# recuerdas
# tu
# nombre
# y
# si
# es
# posible
# me
# lo
# anotas
# por
# ahí
# para
# yo
# estarlo
# recordando
# .
#
#
# Yo
# estoy
# aquí
# por
# los
# dos
# ,
# y
# usted
# por
# quién
# está
# ?
#
#
# Señor
# me
# siento
# mal
# ,
# será
# que
# puede
# ayudarme
# .
#
#
# Oiga
# parce
# ,
# usted
# cuándo
# me
# va
# a
# pagar
# y
# gastándose
# la
# plata
# en
# pendejadas
# .
#
#
# Mire
# jefe
# ,
# yo
# pude
# haberlo
# hecho
# mejor
# con
# mis
# propias
# ideas
# ,
# pero
# usted
# me
# impuso
# las
# suyas
# .
#
#
# Mire
# jefa
# ,
# estuve
# esperándola
# dos
# horas
# y
# usted
# no
# llegó
# .
# Qué
# pasa
# ?
#
#
# Oye
# parce
# ,
# deje
# el
# afán
# .
# No
# nos
# estorbe
# .
#
#
# Papá
# ,
# ponga
# más
# orden
# .
# No
# me
# embolate
# las
# cosas
# .
# Ponga
# las
# cajas
# en
# su
# sitio
# .
#
#
# Mamá
# ,
# fíjese
# lo
# que
# le
# digo
# .
# Eso
# no
# es
# .
# Piense
# en
# mí
# .
# No
# piense
# en
# usted
# .
#
#
# Hombre
# parce
# ,
# a
# usted
# le
# gustan
# los
# gatos
# y
# a
# mí
# los
# perros
# .
# Hágame
# el
# favor
# y
# me
# respeta
# a
# mi
# perrito
# .
#
#
# Hermana
# ,
# mire
# la
# casa
# como
# está
# de
# desordenada
# .
# Ya
# vienen
# los
# cuchos
# y
# usted
# con
# esas
# botellas
# por
# ahí
# regadas
# .
# Qué
# pena
# .
# Ea
# ve
# maría
# ,
# pongámonos
# las
# pilas
# .
#
#
# Señor
# ,
# hágame
# el
# favor
# .
# Apriete
# el
# timbre
# que
# voy
# de
# afán
# .
# Muchas
# gracias
# señor
# .
#
#
# Señora
# ,
# no
# se
# engañe
# .
# Tómese
# los
# remedios
# .
# Mire
# que
# le
# hace
# falta
# .
# Tómeme
# el
# consejo
# .
# Es
# para
# su
# salud
# y
# su
# bienestar
# .
#
#
# Oye
# parcerín
# ,
# mire
# esa
# música
# y
# usted
# que
# pone
# música
# tan
# sabrosa
# siempre
# y
# ahora
# porque
# pone
# esas
# cosas
# tan
# malucas
# .
# Por
# favor
# ,
# pónganos
# a
# bailar
# .
#
#
# Digame
# compa
# ,
# qué
# quieres
# hacer
# para
# el
# cumpleaños
# ?
# Vamos
# al
# río
# o
# qué
# quieres
# hacer
# ?
# Dígame
# ,
# qué
# prefiere
# ?
#
#
# Colega
# ,
# dígame
# ,
# estos
# trabajos
# que
# tenemos
# que
# hacer
# ,
# cómo
# empezamos
# ?
# Por
# dónde
# iniciamos
# ?
# Qué
# trayecto
# hacemos
# para
# terminar
# este
# trabajo
# ?
# Organicemos
# el
# proyecto
# mijito
# .
#
#
# Señor
# agente
# ,
# dígame
# cómo
# me
# dirijo
# a
# esta
# dirección
# ?
# Fuera
# tan
# amable
# .
#
#
# Oye
# señora
# ,
# me
# vuelve
# y
# me
# repite
# el
# nombre
# si
# fuera
# tan
# amable
# .
# Muchas
# gracias
# .
#
#
# Mire
# ,
# señor
# dígame
# ,
# usted
# está
# de
# parte
# de
# la
# novia
# o
# de
# parte
# del
# novio
# ?
#
#
# Señora
# ,
# cuál
# es
# su
# perro
# ?
# Mire
# que
# lindo
# .
# Es
# este
# ?
#
#
# Papá
# ,
# te
# he
# dicho
# que
# no
# me
# mueva
# las
# cosas
# del
# punto
# donde
# yo
# las
# dejo
# .
#
#
# Vea
# ,
# así
# es
# la
# vida
# .
# Uno
# le
# corre
# a
# la
# gente
# y
# ellos
# no
# se
# preocupan
# por
# responder
# .
#
#
# Por
# favor
# ,
# tenga
# más
# cuidado
# porque
# puede
# aporriar
# a
# las
# personas
# que
# están
# ahí
# .
#
#
# Vea
# hija
# ,
# por
# favor
# ,
# vienen
# nuestros
# papás
# y
# la
# casa
# está
# muy
# desorganizada
# y
# yo
# estoy
# muy
# ocupada
# .
# Por
# favor
# ,
# ayúdame
# que
# además
# yo
# estoy
# muy
# cansada
# .
#
#
# Por
# favor
# señor
# ,
# me
# ayuda
# .
#
#
# Señora
# ,
# usted
# es
# nueva
# .
# Yo
# soy
# fulano
# de
# tal
# y
#
# también
# quiero
# jugar
# en
# el
# equipo
# ,
# entonces
# por
# favor
# nos
# pasamos
# la
# pelota
# una
# a
# otra
# .
#
#
# Señor
# agente
# ,
# yo
# soy
# paisa
# ,
# no
# conozco
# esta
# tierra
# .
# Cómo
# hago
# para
# llegar
# allá
# ?
# Usted
# en
# qué
# me
# puede
# colaborar
# o
# me
# indica
# la
# dirección
# para
# yo
# tomar
# un
# taxi
# y
# darle
# la
# orientación
# al
# taxista
# para
# que
# me
# lleve
# allá
# .
#
#
# Ay
# señora
# ,
# qué
# pena
# con
# usted
# ?
# Todo
# el
# día
# aquí
# ayudándome
# y
# se
# me
# olvida
# su
# nombre
# .
# Cómo
# es
# que
# usted
# se
# llama
# ?
# Me
# excusa
# .
#
#
# Ay
# señor
# ,
# hemos
# hablado
# tanto
# rato
# de
# tantas
# cosas
# y
# hasta
# de
# lo
# que
# ocurre
# en
# Santa
# Elena
# .
# Pero
# no
# se
# me
# ha
# ocurrido
# preguntarle
# ,
# usted
# es
# familiar
# del
# novio
# o
# de
# la
# novia
# ?

# %% [markdown]
# ### vos file

# %%
vos = open("Files/vosunique2.txt", mode='r', encoding='utf-8')
textvos = vos.read()
vos.close()
print(textvos[:300], "...")
# Out:
# No, vos sí sos muy falsa, me enterraste el puñal por la espalda.
# Mujer, poné un poquito más de cuidado, que nos están empujando.
#
# Qué pena ¿cómo es que te llamás? Se me olvidó. Tengo mala memoria.
# Parce mirá cómo tenés esta casa. Ayudame a limpiar que ya llegan mis papás por favor.
# Ey es que mirá te ...

# %%
doc3 = nlp(textvos)
for token in doc3:
    print(token.text)
# Out:
# No
# ,
# vos
# sí
# sos
# muy
# falsa
# ,
# me
# enterraste
# el
# puñal
# por
# la
# espalda
# .
#
#
# Mujer
# ,
# poné
# un
# poquito
# más
# de
# cuidado
# ,
# que
# nos
# están
# empujando
# .
#
#
#
# Qué
# pena
# ¿
# cómo
# es
# que
# te
# llamás
# ?
# Se
# me
# olvidó
# .
# Tengo
# mala
# memoria
# .
#
#
# Parce
# mirá
# cómo
# tenés
# esta
# casa
# .
# Ayudame
# a
# limpiar
# que
# ya
# llegan
# mis
# papás
# por
# favor
# .
#
#
# Ey
# es
# que
# mirá
# te
# están
# robando
# la
# pelota
# y
# casi
# no
# estás
# pasando
# ,
# estamos
# en
# un
# equipo
# .
# Por
# favor
# pasá
# .
#
#
#
# Ayudáme
# porfa
# que
# mirá
# que
# mis
# papás
# vienen
# mañana
# y
# el
# desorden
# en
# que
# estamos
# no
# les
# va
# a
# gustar
# .
#
#
#
# Hey
# ayudame
# a
# limpiar
# un
# poquito
# que
# vienen
# mis
# papás
# .
#
#
# Ey
# ¿
# pero
# cuántos
# perros
# es
# que
# tenés
# ?
#
#
# Pero
# ,
# ¿
# cómo
# vas
# a
# contarle
# todo
# ?
# ¿
# No
# ves
# que
# no
# nos
# había
# visto
# ?
# Pues
# ,
# me
# parece
# mal
# que
# me
# hayás
# traicionado
# .
#
#
# Ehh
# parce
# ,
# ayudame
# a
# limpiar
# la
# casa
# que
# vienen
# mis
# papás
# .
# Por
# favor
# ,
# si
# no
# que
# es
# que
# me
# parece
# que
# está
# muy
# sucio
# y
# las
# cervezas
# están
# tiradas
# por
# todo
# el
# piso
# .
#
#
# Hey
# pasame
# el
# balón
# .
# No
# ves
# que
# estamos
# perdiendo
# .
# Pasame
# el
# balón
# de
# una
# ,
# de
# una
# !
#
#
# Que
# por
# qué
# ,
# pues
# por
# qué
# me
# hacés
# eso
# ?
# Ya
# ves
# que
# estoy
# en
# finales
# y
# …
# y
# no
# tengo
# tiempo
# y
# me
# pones
# a
# …
# a
# ir
# hasta
# el
# otro
# lado
# del
# campus
# y
# bien
# temprano
# .
# Pues
# y
# a
# parte
# de
# eso
# me
# toca
# esperate
# dos
# horas
# .
# Vos
# sabé
# que
# eso
# es
# un
# momento
# donde
# yo
# debería
# estar
# estudiando
# y
# usted
# debería
# estar
# preocupado
# por
# ...
# por
# cosas
# como
# el
# ...
# el
# final
# .
# Pues
# deberías
# de
# tener
# más
# consideración
# con
# mi
# tiempo
# y
# no
# deberías
# de
# jugar
# así
# .
#
#
# Hey
# mami
# ,
# no
# me
# está
# gustando
# el
# trato
# que
# me
# estás
# dando
# .
# No
# me
# gusta
# que
# ,
# no
# me
# gusta
# que
# ya
# no
# te
# puedo
# contar
# mis
# cosas
# abiertamente
# porque
# ya
# me
# criticás
# y
# a
# toda
# hora
# me
# querés
# mandar
# de
# lo
# que
# …
# de
# lo
# ,
# de
# lo
# que
# se
# te
# dé
# la
# gana
# .
# Pues
# ,
# así
# no
# debería
# de
# ser
# .
# Yo
# considero
# que
# deberería
# ser
# como
# siempre
# ha
# sido
# .
# Debería
# ser
# la
# madre
# que
# ...
# que
# yo
# siempre
# he
# conocido
# .
# La
# madre
# atenta
# y
# la
# que
# le
# puedo
# contar
# mis
# cosas
# pero
# si
# seguís
# así
# no
# te
# voy
# a
# contar
# nada
# .
# Y
# más
# bien
# voy
# a
# darte
# otro
# trato
# .
# Pues
# ,
# porque
# así
# no
# es
# .
#
#
# Es
# para
# ver
# si
# me
# podés
# ayudar
# que
# mañana
# vienen
# mis
# papás
# .
# Y
# mirá
# esas
# botellas
# que
# tenés
# en
# el
# piso
# .
# Y
# …
# y
# pues
# ellos
# son
# organizados
# y
# me
# da
# como
# pena
# con
# ellos
# .
# A
# parte
# de
# eso
# ,
# mirá
# los
# platos
# y
# mirá
# como
# está
# de
# desorganizado
# .
# Entonces
# ,
# pues
# para
# ver
# si
# me
# podés
# ayudar
# inmediatamente
# para
# que
# ...
# para
# que
# no
# vean
# esto
# ,
# que
# si
# me
# da
# mucha
# pena
# con
# mis
# papás
# .
# Qué
# van
# a
# decir
# de
# mí
# ?
#
#
# Hey
# señora
# ,
# pues
# que
# pena
# contigo
# ser
# tan
# entrometido
# en
# tus
# asuntos
# pero
# he
# notado
# que
# has
# botado
# tus
# pastillas
# varias
# veces
# y
# pues
# la
# verdad
# no
# estás
# muy
# bien
# de
# salud
# .
# Deberías
# replantear
# botar
# esas
# pastillas
# .
# Eso
# …
# pues
# mirá
# que
# eso
# es
# por
# tu
# bien
# .
# Vos
# verás
# y
# todo
# ,
# pero
# ...
# pero
# pues
# con
# las
# salud
# no
# se
# puede
# jugar
# .
# Deberías
# ,
# debería
# de
# tomartelas
# muy
# en
# serio
# .
# Y
# ...
# y
# espero
# ,
# pues
# espero
# no
# volvete
# a
# ver
# porque
# ,
# porque
# de
# lo
# contrario
# voy
# a
# avisar
# porque
# es
# que
# es
# jugar
# con
# tu
# salud
# .
#
#
# Hey
# chica
# pasale
# la
# pasale
# la
# pelota
# al
# jugador
# .
# Mirá
# que
# …
# mirá
# que
# te
# la
# están
# robando
# muy
# fácil
# y
# estás
# muy
# individual
# .
# Pues
# …
# juguemos
# más
# en
# grupo
# para
# que
# nos
# vaya
# mejor
# .
# Vamo
# a
# ponele
# moral
# pues
# .
#
#
# Hey
# compañero
# ,
# qué
# ,
# qué
# día
# podés
# reunir
# ,
# pues
# para
# que
# nos
# reunamos
# vos
# y
# yo
# ?
# Qué
# ,
# qué
# decidís
# ?
# Qué
# día
# te
# queda
# fácil
# o
# qué
# ?
#
#
# Eh
# vení
# ,
# qué
# pena
# !
# La
# verdad
# ,
# se
# me
# olvidó
# cómo
# es
# que
# es
# tu
# nombre
# .
# Me
# lo
# podés
# recordar
# ?
#
#
# Hey
# parce
# ,
# ayudame
# a
# limpiar
# .
# De
# verdad
# que
# me
# da
# pena
# con
# mis
# papás
# que
# ellos
# son
# muy
# ordenados
# y
# que
# esto
# aquí
# está
# todo
# vuelto
# nada
# .
# Ayudame
# ,
# yo
# tengo
# que
# estudiar
# ,
# si
# quiere
# después
# yo
# le
# hago
# un
# favor
# o
# luego
# yo
# limpio
# pero
# colaborame
# por
# favor
# .
#
#
# Hey
# pasame
# la
# pelota
# .
# Mirá
# que
# a
# cada
# rato
# te
# la
# están
# quitando
# .
#
#
# Má
# ,
# vos
# te
# acordás
# como
# era
# que
# hacíamos
# esas
# galletas
# de
# la
# vez
# pasada
# que
# eran
# todas
# ricas
# .
# Me
# ayudás
# por
# fa
# a
# recordar
# cómo
# se
# hacían
# que
# quiero
# hacer
# unas
# .
#
#
# Oye
# ,
# rápido
# ayudame
# vos
# a
# organizar
# esto
# .
# Vienen
# mis
# padres
# .
#
#
# Má
# ,
# ¿
# es
# en
# serio
# que
# no
# te
# importa
# esto
# ?
# No
# ,
# no
# jodás
# .
#
#
# No
# volvás
# a
# decirme
# que
# nos
# reunamos
# tan
# temprano
# .
# La
# próxima
# vos
# vas
# a
# mi
# casa
# .
#
#
# Má
# ,
# yo
# ya
# estoy
# muy
# grande
# .
# Yo
# ya
# sé
# que
# hacer
# .
# Antes
# te
# estoy
# contando
# para
# que
# entendás
# lo
# que
# te
# digo
# y
# pa
# que
# sepás
# mi
# situación
# .
# Nada
# más
# .
# Yo
# ya
# sé
# que
# hacer
# .
#
#
# Vení
# ayudame
# que
# mañana
# viene
# mi
# familia
# .
# Vamos
# a
# dejar
# una
# buena
# impresión
# no
# sé
# .
# Ayudame
# vos
# y
# botá
# esas
# botellas
# que
# tenías
# por
# ahí
# tiradas
# .
#
#
# Madre
# ,
# por
# favor
# tomate
# vos
# las
# pastillas
# .
# Mirá
# que
# es
# por
# tu
# bien
# .
# Haber
# tomémosla
# con
# esta
# rica
# agua
# .
#
#
# Má
# ,
# ayudame
# vos
# a
# hacer
# unas
# galletas
# para
# mis
# amigos
# .
# Las
# que
# haciamos
# en
# las
# antiguas
# vacaciones
# .
# Si
# te
# acordás
# .
#
#
# Listo
# ,
# entonces
# cómo
# hacemos
# para
# la
# tarea
# .
# Nos
# reunimos
# como
# siempre
# o
# qué
# .
# O
# ¿
# qué
# días
# tenés
# libres
# ?
#
#
# Vení
# ,
# por
# favor
# colaborame
# vos
# con
# todo
# lo
# que
# tenemos
# que
# hacer
# porque
# igual
# estoy
# muy
# ocupado
# .
#
#
# Pasame
# vos
# la
# pelota
# porfa
# pa
# ver
# si
# ganamos
# .
#
#
# Vení
# ,
# cuando
# nos
# vamos
# a
# reunir
# ?
# Decime
# vos
# tu
# agenda
# para
# que
# podamos
# acordar
# algo
# y
# …
# .
#
#
#
# Ahh
# parce
# ,
# qué
# pena
# con
# vos
# .
#
#
# Vení
# ,
# me
# podrías
# colaborar
# recogiendo
# esas
# botellas
# ?
#
#
# Hey
# ,
# tenés
# que
# pasarla
# más
# .
#
#
# ¿
# No
# tenés
# plata
# para
# pagar
# pero
# sípara
# farrear
# ?
#
#
# DJ
# ,
# ponéte
# una
# que
# nos
# ponga
# a
# bailar
# a
# todos
# ,
# ponéte
# una
# de
# J
# Álvarez
# .
#
#
# Ve
# y
# a
# todas
# estas
# .
# ¿
# Vos
# sos
# amigo
# de
# el
# novio
# o
# la
# novia
# ?
#
#
# No
# parce
# sí
# sos
# conchudo
# .
# Decís
# que
# no
# tenés
# plata
# y
# gastandote
# la
# plata
# en
# otras
# cosas
# .
#
#
#
# No
# parce
# si
# a
# vos
# te
# dije
# que
# no
# puedo
# comer
# berenjenas
# y
# me
# pusiste
# a
# comer
# berenjena
# .
#
#
#
# Mirá
# no
# le
# volvás
# a
# gritar
# al
# perro
# .
# Que
# a
# mí
# me
# dijiste
# que
# te
# gustan
# los
# perros
# y
# el
# perro
# es
# muy
# calmado
# .
# No
# le
# iba
# a
# hacer
# nada
# a
# tu
# amigo
# .
#
#
# Ey
# parce
# ,
# poné
# música
# más
# movible
# ,
# mejor
# ,
# un
# reggaetoncito
# .
#
#
# Pa
# es
# que
# tenemos
# una
# tarea
# en
# el
# colegio
# relacionado
# con
# los
# antepasados
# de
# nuestra
# famila
# .
# Me
# vas
# a
# colaborar
# por
# favor
# ,
# que
# yo
# sé
# que
# vos
# sabés
# .
#
#
# Parce
# ¿
# y
# a
# vos
# qué
# te
# gustaría
# ?
# planteá
# ideas
# a
# ver
# qué
# hacemos
# .
#
#
# Buenas
# ¿
# cómo
# está
# ?
# Es
# que
# mirá
# yo
# no
# soy
# de
# por
# acá
# y
# me
# perdí
# .
# Entonces
# era
# para
# ver
# si
# me
# ayudaras
# a
# llegar
# a
# esta
# dirección
# .
#
#
# ¿
# Parce
# a
# vos
# quién
# te
# invitó
# ?
#
#
# Pa
# mirá
# que
# me
# pusistes
# otra
# vez
# la
# mochila
# allá
# y
# estoy
# llegando
# tarde
# por
# tu
# culpa
# .
#
#
#
# Pa
# ,
# hacéme
# porfis
# un
# favor
# .
# Pues
# es
# que
# mira
# ,
# las
# cajas
# están
# súper
# desorganizadas
# y
# no
# me
# estás
# ayudando
# casi
# .
#
#
# Hey
# pero
# sí
# sos
# conchudo
# sabiendo
# que
# necesito
# mi
# plata
# y
# por
# allá
# comiendo
# sushi
# .
#
#
# Por
# favor
# ,
# ¿
# hoy
# que
# te
# pasó
# ?
# Siempre
# ponés
# música
# muy
# buena
# .
#
#
# Señor
# por
# favor
# ponga
# música
# para
# que
# todos
# lo
# pasemos
# bien
# .
# A
# unos
# les
# gusta
# el
# reggaeton
# a
# otras
# les
# gusta
# la
# ranchera
# y
# a
# otra
# le
# gusta
# la
# de
# valle
# .
# Entonces
# colócate
# un
# disco
# para
# que
# nos
# dé
# gusto
# a
# todos
# ,
# para
# no
# aburrirnos
# .
# Colócame
# un
# disco
# que
# me
# guste
# a
# mí
# .
# Colócame
# nadie
# es
# eterno
# en
# el
# mundo
# y
# lo
# pasamos
# bien
# .
#
#
# Parce
# ,
# colocá
# esta
# canción
# .
# Es
# que
# mirá
# que
# en
# ese
# repertorio
# no
# metiste
# ese
# y
# me
# parece
# que
# …
# y
# a
# todos
# mis
# parceros
# nos
# gusta
# mucho
# esa
# canción
# .
#
#
# Que
# él
# fue
# el
# que
# me
# lo
# puso
# .
# Pues
# ,
# cómo
# me
# vas
# a
# decir
# que
# no
# te
# gustó
# el
# trabajo
# ,
# no
# te
# gusto
# el
# tema
# ?
# Si
# vos
# fuiste
# el
# que
# me
# lo
# di
# ..
# El
# que
# me
# lo
# diste
# cuando
# yo
# quería
# otro
# tema
# .
# Pues
# la
# verdad
# yo
# pienso
# que
# deberías
# tener
# más
# consideración
# con
# el
# trabajo
# .
#
#
# Hey
# papi
# por
# qué
# estás
# haciendo
# eso
# ome
# ?
# Si
# ,
# si
# pues
# …
# por
# qué
# no
# nos
# pasamos
# organizadamente
# que
# ,
# que
# necesidad
# hay
# de
# tirar
# las
# cajas
# por
# todo
# lado
# .
# Y
# pá
# deberías
# ,
# deberías
# volver
# a
# …
# a
# organizar
# todo
# lo
# que
# tiraste
# y
# empecemos
# de
# nuevo
# .
# Pues
# ,
# cómo
# vas
# a
# tirar
# las
# cosas
# así
# .
# Si
# ,
# nosotros
# ,
# mirá
# ,
# mirá
# ese
# esfuerzo
# que
# estamos
# haciendo
# por
# organizar
# las
# cosas
# y
# que
# todo
# quede
# bien
# .
#
#
# Hey
# no
# ,
# si
# ,
# si
# yo
# respeto
# ,
# si
# yo
# respeto
# tus
# dos
# mascotas
# ,
# porque
# no
# ,
# porque
# no
# puede
# respetar
# a
# la
# mía
# .
#
# Está
# bien
# ,
# él
# es
# así
# ,
# por
# qué
# no
# lo
# deja
# ser
# cómo
# es
# .
# Si
# el
# perro
# quiere
# saludalo
# ,
# déjalo
# saludar
# .
# Además
# ,
# no
# sé
# si
# a
# él
# le
# moleste
# o
# no.
# Pero
# igual
# ,
# esta
# es
# la
# habitación
# de
# loh
# dos
# y
# así
# son
# las
# cosas
# y
# si
# vos
# me
# dijiste
# que
# ..
# que
# te
# gustaban
# los
# perros
# ,
# entonces
# ,
# no
# hay
# razón
# como
# para
# que
# le
# grités
# al
# mío
# .
# Cómo
# así
# ?
# tiene
# es
# que
# respetar
# lo
# mío
# también
# .
# Y
# al
# perro
# no
# le
# volvás
# a
# gritar
# ...
# que
# dijo
# pues
# ?
#
#
# Oye
# ,
# es
# pa
# ver
# si
# me
# podés
# ayudar
# con
# una
# tarea
# que
# …
# que
# la
# necesito
# pa
# esta
# semana
# .
# Entonces
# …
# Es
# para
# ver
# si
# …
# la
# tarea
# consiste
# en
# que
# tengo
# que
# hacer
# un
# árbol
# genealógico
# ,
# entonces
# necesito
# toda
# la
# información
# sobre
# mis
# bisabuelos
# .
# Pues
# ,
# sobretodo
# mis
# antepasados
# y
# pues
# vos
# sabés
# que
# ...
# que
# yo
# no
# sé
# mucho
# sobre
# ellos
# .
# Entonces
# es
# para
# ver
# si
# me
# podés
# ayudar
# y
# nos
# sentamos
# a
# organizalo
# en
# un
# momentico
# .
# Eso
# me
# imagino
# que
# no
# se
# demora
# nada
# .
#
#
# Pá
# ,
# es
# para
# ver
# si
# me
# podés
# ayudar
# haciendo
# unas
# galletas
# pa
# regalar
# a
# mis
# amigos
# .
# Las
# verdad
# no
# ,
# no
# sé
# cómo
# se
# preparan
# .
# Y
# pues
# ya
# que
# acabaste
# de
# llegar
# …
# pues
# …
# espero
# que
# me
# puedas
# ayudar
# .
# La
# verdad
# me
# siento
# muy
# embalado
# con
# eso
# .
#
#
# Hey
# vení
# ,
# acá
# hablando
# de
# lo
# mío
# .
# A
# vos
# que
# te
# gustaría
# hacer
# ome
# ?
# Pues
# ,
# a
# vos
# que
# te
# gustaría
# de
# cumpleaños
# ?
#
#
# Hey
# señor
# policía
# es
# para
# ver
# si
# ,
# si
# me
# podés
# ayudar
# .
# La
# verdad
# estoy
# perdido
# .
# No
# sé
# ,
# no
# sé
# donde
# estoy
# parado
# ni
# nada
# .
# No
# soy
# de
# esta
# ciudad
# .
# Pues
# ,
# yo
# soy
# de
# Antioquia
# .
# Es
# para
# ver
# si
# me
# podés
# colaborar
# .
# Entonces
# ,
# yo
# estoy
# hospedado
# en
# el
# hotel
# …
# Cómo
# se
# llama
# ?
# Entonces
# ,
# de
# casualidad
# sabés
# cómo
# llegar
# ?
#
#
# Hey
# te
# pregunto
# ,
# vos
# qué
# ome
# ?
# No
# me
# has
# contado
# ,
# veniste
# por
# el
# novio
# o
# por
# la
# novia
# ?
#
#
# Parce
# ,
# no
# me
# gusta
# que
# le
# grités
# a
# mi
# perro
# .
# Si
# te
# incomoda
# algo
# de
# lo
# que
# él
# hace
# ,
# me
# decís
# y
# yo
# soy
# el
# que
# lo
# reprendo
# pero
# vos
# no
# tenés
# que
# estale
# diciendo
# cosas
# a
# mi
# perro
# .
#
#
# Amigo
# ,
# me
# podés
# colaborar
# y
# podés
# marcar
# el
# tercer
# piso
# por
# favor
# .
#
#
# Hey
# parce
# ,
# mirá
# que
# la
# gente
# no
# le
# gusta
# esa
# música
# .
# Poné
# ,
# ponete
# otro
# tema
# .
# Y
# si
# me
# dice
# que
# no
# ,
# pues
# yo
# le
# digo
# o
# la
# otra
# es
# llegar
# y
# con
# plata
# .
# Llego
# y
# le
# paso
# plata
# hey
# ponete
# este
# tema
# .
#
#
# Pá
# ,
# imaginate
# que
# tengo
# una
# tarea
# de
# historia
# en
# la
# que
# me
# toca
# decir
# el
# árbol
# genealógico
# .
# Entonces
# ,
# necesito
# que
# me
# ayudé
# a
# hacerla
# .
# Usted
# se
# acuerda
# de
# los
# nombres
# de
# los
# antepasados
# y
# eso
# ?
#
#
# Parce
# ,
# o
# qué
# ,
# vos
# qué
# pensás
# ?
# Qué
# te
# gustaría
# ser
# mejor
# ?
# O
# qué
# ,
# cómo
# te
# parece
# la
# idea
# que
# te
# acabé
# de
# decir
# ?
#
#
# Ve
# y
# a
# todas
# estas
# ,
# vos
# sos
# amigo
# de
# …
# de
# la
# novia
# o
# del
# novio
# ?
# O
# familiar
# o
# de
# quién
# ?
#
#
# Papá
# ,
# necesito
# tu
# ayuda
# .
# Necesito
# hacer
# un
# árbol
# genealógico
# .
# Ayudame
# vos
# por
# favor
# .
#
#
# Pá
# ,
# no
# me
# movás
# más
# mi
# mochila
# .
# Dejámela
# ahí
# quieta
# por
# favor
# .
#
#
# Parce
# ,
# no
# jodás
# .
# Pagame
# vos
# eso
# más
# bien
# .
# Sino
# nunca
# te
# vuelvo
# a
# prestar
# .
# Yo
# no
# sé
# .
# Dejá
# de
# joder
# .
#
#
# Parce
# ,
# qué
# pena
# con
# vos
# ,
# pero
# yo
# dije
# que
# no
# podía
# comer
# berenjena
# .
# ¿
# Me
# lo
# puedes
# cambiar
# por
# otro
# sin
# berenjena
# ?
#
#
# Parce
# ,
# no
# pues
# que
# te
# gustaban
# los
# perros
# .
# Tampoco
# le
# grités
# a
# mi
# perro
# .
# Ya
# .
#
#
# Parce
# ,
# cambiá
# de
# género
# .
# Mirá
# ,
# poneme
# vos
# esta
# canción
# por
# fa
# .
#
#
# Y
# ¿
# vos
# que
# vas
# a
# hacer
# en
# tu
# fiesta
# ?
# Contame
# vos
# .
#
#
# Hola
# ,
# neecito
# saber
# cómo
# llegar
# a
# …
# No
# recuerdo
# …
# mirá
# este
# es
# el
# nombre
# .
#
#
# Parce
# ,
# interesante
# .
# Bueno
# ,
# ahora
# contame
# ,
# ¿
# estás
# por
# el
# novio
# o
# por
# la
# novia
# ?
#
#
# Hey
# marica
# ,
# ¿
# entonces
# hay
# plata
# pa
# sushi
# ?
# Tenés
# plata
# pa
# todo
# pero
# menos
# pa
# pagarme
# ?
# Yo
# necesito
# la
# plata
# .
#
#
# Vení
# ,
# por
# favor
# no
# volvás
# hacer
# eso
# que
# no
# me
# gusta
# y
# …
# si
# queremos
# convivir
# bien
# ,
# no
# lo
# hagás
# porfa
# .
#
#
# Oiste
# ome
# ,
# que
# pasó
# hoy
# ?
# Por
# qué
# no
# estás
# poniendo
# las
# canciones
# de
# siempre
# ?
# Poneme
# vos
# esta
# .
#
#
# Pa
# ,
# me
# podés
# dar
# un
# resumen
# breve
# del
# árbol
# genealógico
# de
# la
# familia
# ?
#
#
# Oiste
# ,
# entonces
# vos
# estás
# aquí
# por
# quién
# ?
# Por
# la
# novia
# o
# por
# el
# novio
# ?
#
#
# Parce
# ,
# acordate
# que
# tenés
# una
# deuda
# conmigo
# .
#
#
# Parce
# ,
# no
# le
# grités
# a
# mi
# perro
# que
# no
# me
# gusta
# .
#
#
# Amigo
# ,
# me
# podés
# colaborar
# poniendo
# esta
# canción
# ?
# Gracias
# .
#
#
# Pa
# ,
# me
# podés
# ayudar
# con
# una
# tarea
# de
# historia
# ?
# Tengo
# que
# hacer
# un
# árbol
# genealógico
# .
# Necesito
# los
# nombres
# de
# toda
# la
# familia
# .
#
#
# Parce
# ,
# y
# a
# todas
# estas
# ,
# a
# vos
# qué
# te
# gustaría
# hacer
# en
# tu
# cumpleaños
# ?
#
#
# Bueno
# ,
# y
# vos
# sos
# amigo
# de
# la
# novia
# o
# del
# novio
# ?
#
#
# Hey
# cómo
# así
# que
# no
# tenés
# pa
# pagarme
# lo
# que
# te
# presté
# ,
# pero
# sí
# tenés
# pa
# comer
# sushi
# ?
#
#
# Hey
# pero
# vos
# por
# qué
# le
# gritás
# a
# mi
# perro
# ?
# No
# le
# grités
# .
#
#
# Pa
# ,
# ¿
# vos
# de
# casualidad
# sabés
# los
# nombres
# de
# mis
# bisabuelos
# ?
#
#
# Ma
# ,
# vos
# sabés
# como
# se
# prepara
# esas
# galletas
# que
# …
# .
#
#
#
# Parce
# ,
# ¿
# y
# a
# vos
# que
# te
# gustaría
# hacer
# ?
#
#
# ¿
# A
# vos
# cuándo
# te
# queda
# bien
# reunirnos
# esta
# semana
# ?
#
#
# Madre
# ,
# ¡
# escuchame
# de
# vez
# en
# cuando
# porfa
# !
#
#
# Ve
# por
# favor
# ,
# no
# le
# volvás
# a
# gritar
# a
# mi
# perro
# .
#
#
# Ve
# ,
# hacéme
# un
# fa
# .
# Es
# que
# mis
# papás
# van
# a
# venir
# y
# yo
# necesito
# organizar
# este
# apartamento
# que
# está
# vuelto
# chiquero
# …
# .
#
#
#
# Amigo
# cambiá
# etsa
# música
# !
# Mirá
# que
# la
# gente
# se
# está
# aburriendo
# .
#
#
# Pa
# ,
# vení
# contáme
# la
# historia
# de
# nuestra
# familia
# .
# Es
# que
# necesito
# hacer
# una
# tarea
# de
# la
# universidad
# .
#
#
# Vení
# ,
# ¿
# a
# vos
# te
# gustaría
# ir
# a
# acampar
# ?
# ¿
# A
# mí
# me
# gustaría
# .
# ¿
# Vos
# que
# pensás
# ?
#
#
# Hey
# Dj
# poneme
# esta
# canción
# para
# que
# nos
# animemos
# pues
# .
#
#
# Mamá
# ,
# pero
# es
# que
# no
# escuchaste
# ,
# mirá
# me
# dieron
# una
# oferta
# de
# trabajo
# .
# Estoy
# muy
# contenta
# .
# ¿
# Por
# qué
# no
# me
# dices
# pues
# nada
# sobre
# eso
# ?
#
#
# Ay
# pero
# por
# qué
# lo
# hiciste
# ?
# Por
# qué
# no
# me
# dijiste
# a
# mí
# primero
# para
# que
# no
# me
# hagás
# quedar
# mal
# con
# mi
# jefe
# ?
#
#
# Papá
# es
# que
# cómo
# se
# te
# ocurre
# mirá
# primero
# hay
# que
# organizarlas
# de
# pronto
# colocarlas
# ...
# la
# cocina
# hasta
# la
# sala
# …
# .la
# sala
# todo
# esto
# ...
# organizado
# porque
# así
# ya
# tan
# desorganizado
# no
# vamos
# a
# llegar
# a
# ningún
# acuerdo
# .
# Todo
# esto
# va
# a
# ser
# un
# desorden
# .
#
#
# ¿
# Pero
# por
# qué
# le
# gritas
# a
# mi
# perro
# ?
# Mirá
# que
# él
# no
# te
# va
# a
# hacer
# nada
# ,
# simplemente
# te
# va
# a
# como
# saludar
# o
# algo
# ,
# pero
# no
# es
# que
# te
# vaya
# a
# hacer
# nada
# te
# vaya
# a
# morder
# .
# ¿
# Por
# qué
# tienes
# que
# gritar
# a
# mi
# perro
# ?
#
#
# Por
# qué
# no
# me
# ayudas
# a
# limpiar
# mirá
# que
# va
# a
# venir
# visita
# ?
# Y
# entonces
# cómo
# así
# no
# te
# da
# pena
# que
# vengan
# mis
# papás
# y
# todo
# desordenado
# .
# Hay
# que
# poner
# más
# orden
# .
#
#
# Mira
# es
# que
# esa
# música
# no
# me
# gusta
# .
# Cámbiame
# la
# música
# que
# es
# que
# mirá
# todo
# el
# mundo
# está
# aburrido
# .
#
#
# Mira
# ayúdame
# con
# eso
# porque
# yo
# quiero
# hacer
# ...
# papá
# ayudame
# a
# hacer
# el
# árbol
# genealógico
# porque
# es
# que
# yo
# quiero
# que
# ...
# conservar
# toda
# la
# familia
# .
# Entonces
# para
# que
# me
# colabores
# por
# favor
# porque
# yo
# sola
# no
# puedo
# .
# Me
# es
# imposible
# .
# Tú
# tienes
# más
# conocimiento
# ,
# es
# una
# persona
# ya
# de
# edad
# .
# Ya
# tiene
# más
# conocimiento
# entonces
# me
# puedes
# colaborar
# con
# los
# datos
# de
# la
# familia
# .
#
#
# ¿
# Por
# qué
# estás
# acá
# ?
# Estás
# invitado
# por
# la
# novia
# o
# estás
# invitado
# por
# el
# novio
# contáme
# pues
# …
# .
#
#
#
# Oye
# ¿
# no
# sabés
# cuándo
# nos
# vamos
# a
# encontrar
# para
# trabajar
# en
# los
# proyectos
# ?
#
#
# ponéte
# las
# pilas
# ,
# ya
# llegaron
# ellos
# ponéte
# las
# pilas
# para
# que
# no
# vean
# esas
# botellas
# de
# cerveza
# ahí
# .
# Hágale
# ,
# hágale
# .
#
#
# oíme
# pero
# te
# tenés
# que
# tomar
# las
# pastillas
# ...
# las
# tomás
# porque
# la
# perjudicada
# eres
# vos
#
#
# Pasame
# pues
# la
# pelota
# que
# estamos
# todos
# jugando
# .
# Estamos
# en
# un
# equipo
# .
# Hay
# que
# jugar
# en
# un
# equipo
# .
#
#
# Por
# favor
# ,
# estás
# poniendo
# música
# muy
# mala
# .
# Cambiá
# eso
# ,
# poné
# una
# bien
# buena
# .
#
#
# Ah
# vos
# sí
# sos
# faltona
# ,
# yo
# pensé
# que
# me
# ibas
# a
# ayudar
# de
# una
# manera
# tranquila
# sin
# tener
# que
# aventarme
#
#
# Ay
# papá
# qué
# rico
# ,
# imagináte
# que
# quiero
#
# hacer
# el
# árbol
# genealógicao
# de
# la
# familia
# .
# Y
# yo
# sé
# que
# usted
# tiene
# una
# memoria
# espectactular
# .
# Por
# ahí
# derecho
# me
# cuentas
# historias
# Quiero
# saeber
# como
# todo
# quíenes
# eran
# mis
# tatarabuelos
# ,
# abuelos
# .
# Para
# poder
# hacer
# la
# tus
# de
# hecho
# me
# cuentas
# tus
# historias
# fascinantes
# que
# tienes
# .
#
#
# Hola
# ,
# ¿
# oíme
# y
# vos
# qué
# ?
# ¿
# vos
# viniste
# aquí
# vos
# sos
# familar
# amigo
# del
# novio
# o
# de
# la
# novia
# ?
# Todo
# el
# rato
# que
# llevamos
# hablando
# y
# ni
# siquiera
# sabemos
#
#
# Y
# así
# no
# tenés
# con
# qué
# pagarme
# ?
#
#
# Respetá
# al
# perrito
# ombe
# !
#
#
# Ayudame
# a
# limpiar
# que
# viene
# mi
# papá
# y
# mi
# mamá
# .
#
#
# Entonces
# ,
# vos
# estás
# rumbiando
# y
#
# pasándola
# bueno
# mientras
# yo
# estoy
# acá
# esperando
# a
# que
# vos
# me
# pagués
# .
# Pues
# ,
# me
# parece
# muy
# conchudo
# de
# tu
# parte
# .
#
#
# Vení
# ,
# vos
# cómo
# se
# ocurre
# decirle
# eso
# a
# la
# profesora
# y
# no
# sacar
# una
# excusa
# o
# algo
# ,
# pues
# ,
# pa
# que
# no
# me
# pillara
# ?
#
#
# Profe
# ,
# pero
# no
# fuiste
# vos
# el
# que
# me
# recomendó
# ese
# tema
# para
# hacer
# la
# investigación
# .
# Sino
# hubiera
# podido
# desarrollar
# un
# tema
# que
# sea
# más
# acorde
# a
# lo
# que
# quería
# .
#
#
# A
# parte
# de
# que
# me
# hacés
# venir
# cuando
# no
# era
# ,
# pues
# ,
# me
# dejás
# plantado
# .
# Me
# parece
# muy
# mal
# hecho
# de
# tu
# parte
# .
#
#
# Pá
# ,
# podemos
# controlar
# ,
# pues
# ,
# pa
# que
# no
# desorganicen
# todo
# lo
# que
# ya
# tenemos
# organizado
# .
# Pues
# ,
# mirá
# que
# están
# muy
# impacientes
# .
#
#
# Ma
# ,
# pero
# a
# vos
# que
# te
# está
# pasando
# o
# algo
# si
# antes
# eras
# de
# esas
# personas
# con
# la
# que
# se
# hablaba
# y
# mirá
# que
# ahora
# estás
# como
# toda
# mandona
# .
#
#
# Vení
# ,
# pero
# ,
# pues
# ,
# tus
# gatos
# tampoco
# es
# que
# sean
# muy
# amigables
# aquí
# en
# la
# casa
# .
# Entonces
# ,
# por
# que
# le
# gritás
# al
# perro
# .
#
#
# Hola
# ,
# si
# sabes
# que
# ?
# Pues
# ,
# ya
# te
# había
# notado
# que
# botas
# las
# pastillas
# y
# sabes
# que
# son
# para
# que
# te
# sientas
# mejor
# .
# Pues
# ,
# como
# consejo
# para
# que
# no
# las
# sigás
# botando
# .
#
#
# Hola
# ,
# mirá
# para
# que
# logremos
# ganar
# o
# por
# lo
# menos
# no
# perder
# tan
# alto
# ,
# porque
# no
# nos
# pasamos
# un
# poco
# más
# la
# pelota
# para
# ver
# si
# en
# equipo
# logramos
# sobrepasar
# .
#
#
# Pa
# ,
# mirá
# ,
# lo
# que
# pasa
# es
# que
# necesitaba
# hacer
# un
# trabajo
# para
# la
# universidad
# y
# pa
# ver
# si
# me
# podés
# ayudar
# que
# tengo
# que
# mover
# ?
# un
# árbol
# genealógico
# porque
# ...
#
#
# Vení
# ,
# pero
# a
# vos
# ,
# pues
# ,
# que
# te
# gustaría
# hacer
# ?
# Porque
# no
# te
# veo
# que
# estás
# diciendo
# nada
# o
# algo
# con
# respecto
# a
# la
# salida
# a
# acampar
# .
#
#
# Vení
# ,
# tratemos
# de
# empezar
# porfa
# este
# trabajo
# lo
# más
# ,
# pues
# ,
# lo
# más
# rápido
# posible
# para
# que
# luego
# no
# nos
# coja
# el
# día
# con
# …
# pues
# ,
# con
# él
# ?
# Para
# que
# logremos
# adelantar
# algo
# y
# si
# tenemos
# dudas
# ,
# preguntar
# .
#
#
# Oiste
# ,
# que
# pena
# con
# vos
# .
# Lo
# que
# pasa
# es
# que
# no
# me
# acuerdo
# tu
# nombre
# .
# Será
# que
# me
# lo
# podé
# repetir
# ?
#
#
# Pá
# ,
# vos
# sabés
# que
# a
# mí
# no
# me
# gusta
# que
# me
# cambien
# las
# cosas
# de
# lugar
# .
# Y
# por
# esa
# razón
# ,
# es
# que
# a
# veces
# llego
# tarde
# a
# muchas
# partes
# .
#
#
# Ma
# ,
# me
# acabaron
# de
# hacer
# una
# oferta
# genial
# y
# vos
# solo
# te
# preocupás
# por
# aspectos
# banales
# .
#
#
# Parce
# ,
# para
# comer
# y
# rumbiar
# si
# tenés
# dinero
# pero
# para
# responder
# por
# algo
# no.
#
#
# Sí
# ,
# la
# verdad
# no
# estudié
# ,
# así
# que
# disculpáme
# ahí
# por
# esa
# .
#
#
# Hola
# señor
# ,
# mirá
# el
# plato
# tiene
# berenjenas
# .
# Recuerda
# que
# yo
# lo
# pedí
# sin
# berenjenas
# por
# fa
# .
#
#
# Hey
# nena
# ,
# qué
# te
# pasa
# ?
# Respetá
# primero
# ,
# pedí
# permiso
# .
#
#
# Ma
# ,
# mirá
# que
# a
# veces
# tengo
# unos
# problemas
# serios
# y
# me
# gustaría
# contártelos
# para
# que
# vos
# me
# dieses
# un
# consejo
# al
# respecto
# .
#
#
# Parce
# ,
# mirá
# el
# perro
# es
# mío
# .
# Pues
# ,
# esta
# es
# mi
# casa
# y
# vos
# tenés
# que
# respetar
# a
# mi
# mascota
# .
#
#
# DJ
# vení
# ,
# podés
# poner
# esta
# canción
# pa
# ver
# si
# esta
# fiesta
# se
# prende
# .
#
#
# Ma
# ,
# me
# podés
# decir
# cuáles
# son
# las
# galletas
# que
# hiciste
# la
# otra
# vez
# que
# se
# las
# quiero
# hacer
# a
# una
# amiga
# .
#
#
# Parce
# ,
# y
# vos
# estás
# aquí
# por
# el
# novio
# o
# por
# la
# novia
# ?
#
#
# Madre
# ,
# quiero
# que
# te
# preocupes
# por
# tu
# salud
# .
# Voy
# a
# estar
# más
# pendiente
# de
# que
# te
# tomes
# tus
# medicamentos
# .
# Voy
# a
# estar
# detrás
# de
# vos
# para
# que
# te
# los
# tomes
# ,
# ok
# ?
#
#
# Para
# eso
# si
# tenés
# ,
# pero
# pa
# pagarme
# lo
# mío
# si
# no.
# Dejá
# de
# ser
# conchudo
# !
#
#
# Hey
# papá
# ,
# hablame
# vos
# de
# toda
# tu
# familia
# .
# Cómo
# se
# llamaban
# ?
# Cuántos
# eran
# ?
#
#
# Qué
# rico
# ir
# a
# acampar
# ?
# A
# vos
# te
# gustaría
# estar
# con
# nosotros
# ?
#
#
# Hola
# ,
# bueno
# ,
# el
# hecho
# de
# que
# tengás
# gatos
# no
# quiere
# decir
# que
# no
# te
# gusten
# los
# perros
# y
# aquí
# en
# mi
# casa
# a
# mi
# me
# gustan
# los
# perros
# .
#
#
# Hey
# ,
# y
# a
# vos
# qué
# te
# gustaría
# para
# el
# día
# de
# tu
# cumpleaños
# ?
# Qué
# te
# gustaría
# hacer
# ?
#
#
# Hola
# ,
# sos
# amigo
# del
# novio
# o
# de
# la
# novia
# ?
#
#
# Hey
# parce
# ,
# por
# favor
# pásame
# la
# pelota
# también
# .
# Yo
# también
# estoy
# jugando
# .
# Mirá
# que
# quiero
# jugar
# .

# %% [markdown]
# ### Comparing lexical similarities

# %%
docs = ( (doc1),
        (doc2),
        (doc3) )

for x in range(len(docs)):
    for y in range(len(docs)):
        print(x, y, docs[x].similarity(docs[y]))
# Out:
# 0 0 1.0
# 0 1 0.9987102553219561
# 0 2 0.9993876308339964
# 1 0 0.9987102553219561
# 1 1 1.0
# 1 2 0.9985039291144205
# 2 0 0.9993876308339964
# 2 1 0.9985039291144205
# 2 2 1.0

# %% [markdown]
# ### Tokenization - Not necessary

# %% [markdown]
# doc = nlp(u'Human ambition is the key to staying ahead of automation.')
# for token in doc:
#     print(token.text)

# %% [markdown]
# ### Part-of-Speech Tagging

# %% [markdown]
# We can tokenize and part of speech tag the individual tokens using the following code:

# %%
#doc = nlp(u'Má, te estoy contando una noticia muy importante y sólo me preguntas si pagué mi tarjeta.')

for token in doc1:
    print("\t".join( (token.text, str(token.idx), token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, str(token.is_alpha), str(token.is_stop) )))
# Out:
# ﻿Má	0	﻿Má	PROPN	PROPN___	nsubj	﻿Xx	False	False
# ,	3	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# te	5	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# estoy	8	estar	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	aux	xxxx	True	True
# contando	14	contar	VERB	VERB__VerbForm=Ger	ROOT	xxxx	True	False
# una	23	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	det	xxx	True	True
# noticia	27	noticiar	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# muy	35	muy	ADV	ADV___	advmod	xxx	True	True
# importante	39	importante	ADJ	ADJ__Number=Sing	amod	xxxx	True	False
# y	50	y	CONJ	CCONJ___	cc	x	True	False
# sólo	52	sólo	ADV	ADV___	advmod	xxxx	True	True
# me	57	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# preguntas	60	preguntar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# si	70	si	SCONJ	SCONJ___	mark	xx	True	True
# pagué	73	pagar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Past|VerbForm=Fin	advcl	xxxx	True	False
# mi	79	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# tarjeta	82	tarjeta	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# .	89	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Qué	91	Qué	DET	DET__PronType=Rel	det	Xxx	True	True
# _	95	_	PROPN	PROPN___	ROOT	_	False	False
# _	96	_	PROPN	PROPN___	flat	_	False	False
# _	97	_	PROPN	PROPN___	flat	_	False	False
# _	98	_	PROPN	PROPN___	flat	_	False	False
# _	99	_	PROPN	PROPN___	flat	_	False	False
# que	101	que	PRON	PRON__PronType=Rel	mark	xxx	True	True
# eres	105	ser	PROPN	PROPN___	acl	xxxx	True	True
# .	109	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	110
# 	SPACE	_SP
# 	False	False
# Ma	111	Ma	PROPN	PROPN___	nsubj	Xx	True	False
# ,	113	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# por	115	por	ADP	ADP__AdpType=Prep	mark	xxx	True	True
# favor	119	favor	NOUN	NOUN___	fixed	xxxx	True	False
# si	125	si	SCONJ	SCONJ___	mark	xx	True	True
# yo	128	yo	PRON	PRON__Case=Nom|Number=Sing|Person=1|PronType=Prs	nsubj	xx	True	True
# confío	131	confiar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# en	138	en	ADP	ADP__AdpType=Prep	case	xx	True	True
# ti	141	ti	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	obl	xx	True	True
# ,	143	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# te	145	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# cuento	148	contar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# mis	155	mi	DET	DET__Number=Plur|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xxx	True	True
# cosas	159	coser	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	True
# ,	164	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# es	166	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xx	True	True
# para	169	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# que	174	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	178	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# aconseje	181	aconsejar	VERB	VERB__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# ,	189	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# no	191	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# para	194	parir	ADP	ADP__AdpType=Prep	case	xxxx	True	True
# que	199	que	SCONJ	SCONJ___	mark	xxx	True	True
# estés	203	estar	PROPN	PROPN___	advcl	xxxx	True	False
# todo	209	todo	DET	DET__Gender=Masc|Number=Sing|PronType=Ind	det	xxxx	True	True
# impaciente	214	impacientar	ADJ	ADJ__Number=Sing	obj	xxxx	True	False
# ...	224	...	PUNCT	PUNCT__PunctType=Comm	punct	...	False	False
# por	227	por	ADP	ADP__AdpType=Prep	ROOT	xxx	True	True
# todo	231	todo	PRON	PRON__Gender=Masc|Number=Sing|PronType=Ind	fixed	xxxx	True	True
# .	235	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
#
# 	236
#
# 	SPACE	_SP
#
# 	False	False
# Amigo	238	Amigo	PROPN	PROPN___	ROOT	Xxxxx	True	False
# ?	243	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# ...	245	...	PUNCT	PUNCT__PunctType=Comm	punct	...	False	False
# Mis	248	Mis	DET	DET__Number=Plur|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	Xxx	True	True
# papás	252	papá	PROPN	PROPN___	nsubj	xxxx	True	False
# y	258	y	CONJ	CCONJ___	cc	x	True	False
# a	260	a	ADP	ADP__AdpType=Prep	case	x	True	False
# ellos	262	ellos	PRON	PRON__Gender=Masc|Number=Plur|Person=3|PronType=Prs	obj	xxxx	True	True
# no	268	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# les	271	les	PRON	PRON__Case=Dat|Number=Plur|Person=3|PronType=Prs	obj	xxx	True	True
# gusta	275	gustar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# el	281	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# desorden	284	desorden	NOUN	NOUN__Gender=Masc|Number=Sing	nsubj	xxxx	True	False
# .	292	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Entonces	294	Entonces	ADV	ADV___	advmod	Xxxxx	True	True
# necesito	303	necesitar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# que	312	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	316	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# ayudes	319	ayudar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# por	326	por	ADP	ADP__AdpType=Prep	mark	xxx	True	True
# favor	330	favor	NOUN	NOUN___	fixed	xxxx	True	False
# a	336	a	ADP	ADP__AdpType=Prep	fixed	x	True	False
# organizar	338	organizar	VERB	VERB__VerbForm=Inf	advcl	xxxx	True	False
# las	348	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# cosas	352	coser	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	True
# rápido	358	rápido	ADJ	ADJ__Gender=Masc|Number=Sing	amod	xxxx	True	False
# .	364	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
#
# 	365
#
# 	SPACE	_SP
#
# 	False	False
# Soy	368	Soy	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	cop	Xxx	True	True
# consciente	372	consciente	ADJ	ADJ__Number=Sing	ROOT	xxxx	True	False
# del	383	del	ADP	ADP__AdpType=Preppron|Gender=Masc|Number=Sing	case	xxx	True	True
# estado	387	estar	NOUN	NOUN__Gender=Masc|Number=Sing	nmod	xxxx	True	True
# de	394	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# salud	397	salud	NOUN	NOUN__Gender=Fem|Number=Sing	nmod	xxxx	True	False
# en	403	en	ADP	ADP__AdpType=Prep	case	xx	True	True
# el	406	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# que	409	que	PRON	PRON__PronType=Rel	obl	xxx	True	True
# tienes	413	tener	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# y	420	y	CONJ	CCONJ___	cc	x	True	False
# me	422	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# gustaría	425	gustar	VERB	VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	conj	xxxx	True	False
# verte	434	verte	NOUN	NOUN__Gender=Masc|Number=Sing	amod	xxxx	True	False
# mejor	440	mejor	ADJ	ADJ__Number=Sing	amod	xxxx	True	True
# ,	445	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# poder	447	poder	AUX	AUX__VerbForm=Inf	aux	xxxx	True	True
# seguir	453	seguir	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# charlando	460	charlar	VERB	VERB__VerbForm=Ger	acl	xxxx	True	False
# ,	469	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# seguir	471	seguir	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# jugando	478	jugar	VERB	VERB__VerbForm=Ger	advcl	xxxx	True	False
# naipes	486	naipe	NOUN	NOUN__Gender=Masc|Number=Plur	obj	xxxx	True	False
# .	492	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# charlamos	494	charlar	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# pues	504	pues	SCONJ	SCONJ___	mark	xxxx	True	True
# entonces	509	entonces	ADV	ADV___	fixed	xxxx	True	True
# para	518	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# que	523	que	SCONJ	SCONJ___	mark	xxx	True	True
# mejores	527	mejorar	ADJ	ADJ__Number=Plur	amod	xxxx	True	False
# tu	535	tu	DET	DET__Number=Sing|Number[psor]=Sing|Person=2|Poss=Yes|PronType=Prs	det	xx	True	True
# salud	538	salud	NOUN	NOUN__Gender=Fem|Number=Sing	advcl	xxxx	True	False
# ,	543	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# me	545	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# gustaría	548	gustar	VERB	VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	advcl	xxxx	True	False
# que	557	que	SCONJ	SCONJ___	mark	xxx	True	True
# te	561	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# tomes	564	tomar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	csubj	xxxx	True	False
# las	570	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# pastillas	574	pastilla	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# y	584	y	CONJ	CCONJ___	cc	x	True	False
# que	586	que	SCONJ	SCONJ___	mark	xxx	True	True
# no	590	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# fingas	593	fingas	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# que	600	que	SCONJ	SCONJ___	mark	xxx	True	True
# las	604	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# botes	608	bote	NOUN	NOUN__Gender=Masc|Number=Plur	obl	xxxx	True	False
# .	613	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# La	615	La	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	Xx	True	True
# verdad	618	verdad	NOUN	NOUN__Gender=Fem|Number=Sing	nsubj	xxxx	True	True
# es	625	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xx	True	True
# muy	628	muy	ADV	ADV___	advmod	xxx	True	True
# importante	632	importante	ADJ	ADJ__Number=Sing	ROOT	xxxx	True	False
# para	643	parir	ADP	ADP__AdpType=Prep	case	xxxx	True	True
# mí	648	mí	PRON	PRON__Number=Sing|Person=1|PrepCase=Pre|PronType=Prs	obl	xx	True	True
# que	651	que	SCONJ	SCONJ___	nsubj	xxx	True	True
# estés	655	estar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	csubj	xxxx	True	False
# bien	661	bien	ADV	ADV___	advmod	xxxx	True	True
# porque	666	porque	SCONJ	SCONJ___	mark	xxxx	True	True
# me	673	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# gustar	676	gustar	VERB	VERB__VerbForm=Inf	advcl	xxxx	True	False
# estar	683	estar	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	True
# contigo	689	contigo	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	obj	xxxx	True	True
# .	696	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	697
# 	SPACE	_SP
# 	False	False
# Ma	698	Ma	PROPN	PROPN___	obl	Xx	True	False
# ,	700	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# hola	702	hola	PROPN	PROPN___	nsubj	xxxx	True	False
# te	707	te	PRON	PRON__Number=Sing|Person=2	obj	xx	True	True
# acuerdas	710	acordar	ADJ	ADJ__Gender=Fem|Number=Plur|VerbForm=Part	ROOT	xxxx	True	False
# de	719	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# las	722	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# galletas	726	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# que	735	que	PRON	PRON__PronType=Rel	obj	xxx	True	True
# preparamos	739	preparar	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# en	750	en	ADP	ADP__AdpType=Prep	case	xx	True	True
# las	753	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# vacaciones	757	vacación	NOUN	NOUN__Gender=Fem|Number=Plur	obl	xxxx	True	False
# pasadas	768	pasar	ADJ	ADJ__Gender=Fem|Number=Plur|VerbForm=Part	amod	xxxx	True	False
# es	776	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	conj	xx	True	True
# que	779	que	SCONJ	SCONJ___	mark	xxx	True	True
# quiero	783	querer	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# volverlas	790	volverlas	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# a	800	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# preparar	802	preparar	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	False
# porque	811	porque	SCONJ	SCONJ___	mark	xxxx	True	True
#  	818	 	SPACE	_SP		 	False	False
# a	819	a	ADP	ADP__AdpType=Prep	case	x	True	False
# mi	821	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# novio	824	novio	NOUN	NOUN__Gender=Masc|Number=Sing	fixed	xxxx	True	False
# le	830	le	PRON	PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs	obj	xx	True	True
# gustaron	833	gustar	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	advcl	xxxx	True	False
# mucho	842	mucho	ADV	ADV___	advmod	xxxx	True	True
# pero	848	pero	CONJ	CCONJ___	cc	xxxx	True	True
# no	853	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# recuerdo	856	recordar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# cómo	865	cómo	PRON	PRON__PronType=Int	nmod	xxxx	True	True
# hacerlas	870	hacerlas	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# ,	878	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# ¿	880	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# me	881	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# puedes	884	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# ayudarme	891	ayudarme	NOUN	NOUN__Gender=Masc|Number=Sing	advcl	xxxx	True	False
# ?	899	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	901
# 	SPACE	_SP
# 	False	False
# Hola	902	Hola	PROPN	PROPN___	nsubj	Xxxx	True	False
# te	907	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	iobj	xx	True	True
# quería	910	querer	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	ROOT	xxxx	True	False
# preguntar	917	preguntar	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# qué	927	qué	DET	DET__PronType=Int	det	xxx	True	True
# día	931	día	NOUN	NOUN__Gender=Masc|Number=Sing	obl	xxx	True	True
# te	935	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# queda	938	quedo	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# fácil	944	fácil	ADJ	ADJ__Number=Sing	amod	xxxx	True	False
# reunirnos	950	reunirnos	ADJ	ADJ__Gender=Masc|Number=Plur	obj	xxxx	True	False
# para	960	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# empezar	965	empezar	VERB	VERB__VerbForm=Inf	acl	xxxx	True	False
# con	973	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# las	977	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# investigaciones	981	investigación	NOUN	NOUN__Gender=Fem|Number=Plur	obl	xxxx	True	False
# de	997	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# química	1000	químico	NOUN	NOUN__Gender=Fem|Number=Sing	nmod	xxxx	True	False
# que	1008	que	PRON	PRON__PronType=Rel	mark	xxx	True	True
# nos	1012	no	PRON	PRON__Number=Plur|Person=1|PronType=Prs	obj	xxx	True	True
# ...	1015	...	PUNCT	PUNCT__PunctType=Comm	punct	...	False	False
# para	1019	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# que	1024	que	SCONJ	SCONJ___	mark	xxx	True	True
# no	1028	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# nos	1031	no	PRON	PRON__Number=Plur|Person=1	obj	xxx	True	True
# dejemos	1035	dejar	AUX	AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# correr	1043	correr	VERB	VERB__VerbForm=Inf	advcl	xxxx	True	False
# del	1050	del	ADP	ADP__AdpType=Preppron|Gender=Masc|Number=Sing	case	xxx	True	True
# tiempo	1054	tiempo	NOUN	NOUN__Gender=Masc|Number=Sing	obl	xxxx	True	True
# y	1061	y	CONJ	CCONJ___	cc	x	True	False
# podamos	1063	poder	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin	conj	xxxx	True	False
# me	1071	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# ...	1074	...	PUNCT	PUNCT__PunctType=Comm	punct	...	False	False
# me	1077	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# avisas	1080	avisar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# o	1087	o	CONJ	CCONJ___	cc	x	True	False
# a	1089	a	ADP	ADP__AdpType=Prep	case	x	True	False
# qué	1091	qué	DET	DET__PronType=Int	det	xxx	True	True
# horas	1095	hora	NOUN	NOUN__Gender=Fem|Number=Plur	obl	xxxx	True	True
#
# 	1101
# 	SPACE	_SP
# 	False	False
# He	1102	He	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	aux	Xx	True	True
# visto	1105	vestir	VERB	VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	conj	xxxx	True	False
# que	1111	que	SCONJ	SCONJ___	mark	xxx	True	True
# te	1115	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# gustan	1118	gustar	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# mucho	1125	mucho	ADV	ADV___	advmod	xxxx	True	True
# los	1131	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# perros	1135	perro	NOUN	NOUN__Gender=Masc|Number=Plur	nsubj	xxxx	True	False
# .	1141	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# ¿	1143	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# cuántos	1144	cuánto	ADJ	ADJ__Gender=Masc|Number=Plur	ROOT	xxxx	True	True
# perros	1152	perro	NOUN	NOUN__Gender=Masc|Number=Plur	amod	xxxx	True	False
# tienes	1159	tener	ADJ	ADJ__Number=Plur	amod	xxxx	True	False
# ?	1165	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1167
# 	SPACE	_SP
# 	False	False
# ¿	1168	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Madre	1169	Madre	PROPN	PROPN___	nsubj	Xxxxx	True	False
# por	1175	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# qué	1179	qué	PRON	PRON__Number=Sing|PronType=Int	obl	xxx	True	True
# no	1183	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# primero	1186	1	ADV	ADV___	amod	xxxx	True	True
# preguntas	1194	preguntar	NOUN	NOUN__Gender=Fem|Number=Plur	amod	xxxx	True	False
# por	1204	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# mí	1208	mí	PRON	PRON__Number=Sing|Person=1|PrepCase=Pre|PronType=Prs	obj	xx	True	True
# ?	1210	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1211
# 	SPACE	_SP
# 	False	False
# Ten	1212	Ten	PROPN	PROPN___	ROOT	Xxx	True	False
# más	1216	más	ADV	ADV___	advmod	xxx	True	True
# cuidado	1220	cuidar	ADJ	ADJ__Gender=Masc|Number=Sing|VerbForm=Part	amod	xxxx	True	False
# .	1227	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1228
# 	SPACE	_SP
# 	False	False
# Madre	1229	Madre	PROPN	PROPN___	ROOT	Xxxxx	True	False
# por	1235	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# favor	1239	favor	NOUN	NOUN__Gender=Masc|Number=Sing	nmod	xxxx	True	False
# préstame	1245	préstame	ADJ	ADJ__Number=Sing	amod	xxxx	True	False
# más	1254	más	ADV	ADV___	advmod	xxx	True	True
# atención	1258	atención	NOUN	NOUN__Gender=Fem|Number=Sing	amod	xxxx	True	False
# .	1266	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1267
# 	SPACE	_SP
# 	False	False
# Por	1268	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# favor	1272	favor	NOUN	NOUN___	ROOT	xxxx	True	False
# ayúdame	1278	ayúdame	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	amod	xxxx	True	False
# a	1286	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# limpiar	1288	limpiar	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# que	1296	que	SCONJ	SCONJ___	mark	xxx	True	True
# viene	1300	venir	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# gente	1306	gente	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# para	1312	parir	ADP	ADP__AdpType=Prep	case	xxxx	True	True
# mi	1317	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# casa	1320	casar	NOUN	NOUN__Gender=Fem|Number=Sing	nmod	xxxx	True	False
# .	1324	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1325
# 	SPACE	_SP
# 	False	False
# Por	1326	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# favor	1330	favor	ADJ	ADJ__Gender=Masc|Number=Sing	ROOT	xxxx	True	False
# tómate	1336	tómate	NOUN	NOUN__Gender=Masc|Number=Sing	flat	xxxx	True	False
# las	1343	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# pastillas	1347	pastilla	NOUN	NOUN__Gender=Fem|Number=Plur	flat	xxxx	True	False
# que	1357	que	PRON	PRON__PronType=Rel	nsubj	xxx	True	True
# son	1361	ser	AUX	AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	cop	xxx	True	True
# bien	1365	bien	ADV	ADV___	acl	xxxx	True	True
# para	1370	parir	ADP	ADP__AdpType=Prep	case	xxxx	True	True
# ti	1375	ti	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	obl	xx	True	True
# .	1377	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1378
# 	SPACE	_SP
# 	False	False
# Madre	1379	Madre	PROPN	PROPN___	nsubj	Xxxxx	True	False
# ,	1384	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# quiero	1386	querer	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# que	1393	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	1397	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	iobj	xx	True	True
# enseñes	1400	enseñar	VERB	VERB__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# a	1408	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# hacer	1410	hacer	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	True
# las	1416	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# galletas	1420	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# especiales	1429	especial	ADJ	ADJ__Number=Plur	amod	xxxx	True	False
# que	1440	que	PRON	PRON__PronType=Rel	nsubj	xxx	True	True
# quiero	1444	querer	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# tener	1451	tener	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	True
# un	1457	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# presente	1460	presentar	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# con	1469	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# mis	1473	mi	DET	DET__Number=Plur|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xxx	True	True
# amigos	1477	amigo	NOUN	NOUN__Gender=Masc|Number=Plur	obl	xxxx	True	False
# .	1483	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1484
# 	SPACE	_SP
# 	False	False
# ¿	1485	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Cuándo	1486	Cuándo	PRON	PRON__PronType=Int	aux	Xxxxx	True	True
# quieres	1493	querer	NOUN	NOUN__Gender=Masc|Number=Plur	ROOT	xxxx	True	False
# que	1501	que	SCONJ	SCONJ___	mark	xxx	True	True
# empecemos	1505	empezar	AUX	AUX__Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# a	1515	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# hacer	1517	hacer	VERB	VERB__VerbForm=Inf	acl	xxxx	True	True
# los	1523	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# trabajos	1527	trabajo	NOUN	NOUN__Gender=Masc|Number=Plur	obj	xxxx	True	False
# para	1536	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# adelantar	1541	adelantar	VERB	VERB__VerbForm=Inf	acl	xxxx	True	False
# ?	1550	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1551
# 	SPACE	_SP
# 	False	False
# ¿	1552	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Solamente	1553	Solamente	ADV	ADV___	advmod	Xxxxx	True	True
# tienes	1563	tener	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# este	1570	este	DET	DET__Gender=Masc|Number=Sing|PronType=Dem	obj	xxxx	True	True
# o	1575	o	CONJ	CCONJ___	cc	x	True	False
# tienes	1577	tener	NOUN	NOUN__Gender=Fem|Number=Plur	conj	xxxx	True	False
# más	1584	más	ADV	ADV___	advmod	xxx	True	True
# ?	1587	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1588
# 	SPACE	_SP
# 	False	False
# Es	1589	Es	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	Xx	True	True
# que	1592	que	SCONJ	SCONJ___	mark	xxx	True	True
# no	1596	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# recuerdo	1599	recordar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# tu	1608	tu	DET	DET__Number=Sing|Number[psor]=Sing|Person=2|Poss=Yes|PronType=Prs	det	xx	True	True
# nombre	1611	nombrar	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# .	1617	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# ¿	1619	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Me	1620	Me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	iobj	Xx	True	True
# lo	1623	el	PRON	PRON__Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs	obj	xx	True	True
# puedes	1626	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# volver	1633	volver	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# a	1640	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# decir	1642	decir	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	True
# por	1648	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# favor	1652	favor	NOUN	NOUN___	obl	xxxx	True	False
# ?	1657	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1658
# 	SPACE	_SP
# 	False	False
# Oye	1659	Oye	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	nsubj	Xxx	True	False
# presta	1663	presto	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# atención	1670	atención	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# ,	1678	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# mira	1680	mirar	VERB	VERB__Mood=Imp|Number=Sing|Person=2|VerbForm=Fin	ROOT	xxxx	True	False
# que	1685	que	SCONJ	SCONJ___	mark	xxx	True	True
# estamos	1689	estar	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# acá	1697	acá	NOUN	NOUN__Number=Sing	ccomp	xxx	True	False
# .	1700	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Todos	1702	Todos	PRON	PRON__Gender=Masc|Number=Plur|PronType=Ind	nsubj	Xxxxx	True	True
# queremos	1708	querer	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	True
# ver	1717	ver	VERB	VERB__VerbForm=Inf	xcomp	xxx	True	True
# .	1720	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1721
# 	SPACE	_SP
# 	False	False
# ¿	1722	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Ma	1723	Ma	NOUN	NOUN___	case	Xx	True	False
# qué	1726	qué	PRON	PRON__Number=Sing|PronType=Int	obj	xxx	True	True
# pasó	1730	pasar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	ROOT	xxxx	True	False
# ?	1734	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# ¿	1736	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Te	1737	Te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	Xx	True	True
# dije	1740	decir	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Past|VerbForm=Fin	ROOT	xxxx	True	False
# algo	1745	algo	PRON	PRON__Number=Sing|PronType=Ind	obj	xxxx	True	True
# que	1750	que	PRON	PRON__PronType=Rel	nsubj	xxx	True	True
# te	1754	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# molesta	1757	molesto	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# o	1765	o	CONJ	CCONJ___	cc	x	True	False
# qué	1767	qué	PRON	PRON__Number=Sing|PronType=Int	obj	xxx	True	True
# pasa	1771	paso	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# contigo	1776	contigo	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	nsubj	xxxx	True	True
# que	1784	que	PRON	PRON__PronType=Rel	nsubj	xxx	True	True
# estás	1788	estar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	cop	xxxx	True	False
# tan	1794	tan	ADV	ADV___	advmod	xxx	True	True
# rara	1798	raro	ADJ	ADJ__Gender=Fem|Number=Sing	acl	xxxx	True	False
# ?	1802	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1803
# 	SPACE	_SP
# 	False	False
# Hey	1804	Hey	PROPN	PROPN___	nsubj	Xxx	True	False
# ,	1807	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# en	1809	en	ADP	ADP__AdpType=Prep	case	xx	True	True
# la	1812	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# próxima	1815	próximo	ADJ	ADJ__Gender=Fem|Number=Sing	obl	xxxx	True	False
# ,	1822	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# me	1824	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# pasas	1827	paso	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# la	1833	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# pelota	1836	pelota	NOUN	NOUN__Gender=Fem|Number=Sing	nsubj	xxxx	True	False
# .	1842	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	1843
# 	SPACE	_SP
# 	False	False
# Mami	1844	Mami	PROPN	PROPN___	nsubj	Xxxx	True	False
# ,	1848	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# te	1850	te	PRON	PRON__Number=Sing|Person=2	obj	xx	True	True
# acuerdas	1853	acordar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# el	1862	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# año	1865	año	NOUN	NOUN__AdvType=Tim	obl	xxx	True	False
# pasado	1869	pasar	ADJ	ADJ__Gender=Masc|Number=Sing|VerbForm=Part	amod	xxxx	True	True
# hicimos	1876	hacer	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# unas	1884	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Plur|PronType=Art	det	xxxx	True	True
# galletas	1889	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# súper	1898	súper	PROPN	PROPN___	amod	xxxx	True	False
# ricas	1904	rico	ADJ	ADJ__Gender=Fem|Number=Plur	amod	xxxx	True	False
# a	1910	a	ADP	ADP__AdpType=Prep	case	x	True	False
# mi	1912	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# mejor	1915	mejor	ADJ	ADJ__Number=Sing	amod	xxxx	True	True
# amiga	1921	amigo	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# .	1926	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# ¿	1928	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Será	1929	Será	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	ROOT	Xxxx	True	True
# que	1934	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	1938	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# ayudarías	1941	ayudar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# otra	1951	otro	DET	DET__Gender=Fem|Number=Sing|PronType=Ind	det	xxxx	True	True
# vez	1956	vez	NOUN	NOUN__Gender=Fem|Number=Sing	obl	xxx	True	True
# a	1960	a	ADP	ADP__AdpType=Prep	case	x	True	False
# hacerselas	1962	hacerselas	NOUN	NOUN__Gender=Fem|Number=Plur	obl	xxxx	True	False
# ?	1972	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	1973
# 	SPACE	_SP
# 	False	False
# Hola	1974	Hola	PROPN	PROPN___	nsubj	Xxxx	True	False
# ,	1978	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# ¿	1980	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# cuándo	1981	cuándo	PRON	PRON__PronType=Int	obl	xxxx	True	True
# tienes	1988	tener	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# tiempo	1995	tiempo	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	True
# para	2002	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# hacer	2007	hacer	VERB	VERB__VerbForm=Inf	acl	xxxx	True	True
# el	2013	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# trabajo	2016	trabajar	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	True
# ?	2023	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	2024
# 	SPACE	_SP
# 	False	False
# ¿	2025	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Y	2026	Y	CONJ	CCONJ___	cc	X	True	False
# este	2028	este	DET	DET__Gender=Masc|Number=Sing|PronType=Dem	det	xxxx	True	True
# perrito	2033	perrito	NOUN	NOUN__Gender=Masc|Number=Sing	conj	xxxx	True	False
# tan	2041	tan	ADV	ADV___	advmod	xxx	True	True
# lindo	2045	lindar	ADJ	ADJ__Gender=Masc|Number=Sing	amod	xxxx	True	False
# ,	2050	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# también	2052	también	ADV	ADV___	advmod	xxxx	True	True
# es	2060	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xx	True	True
# tuyo	2063	tuyo	ADJ	ADJ__Gender=Fem|Number=Sing	ROOT	xxxx	True	True
# o	2068	o	CONJ	CCONJ___	cc	x	True	False
# no	2070	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# lo	2073	el	PRON	PRON__Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs	det	xx	True	True
# conoces	2076	conocer	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# ?	2083	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	2084
# 	SPACE	_SP
# 	False	False
# No	2085	No	ADV	ADV__Polarity=Neg	advmod	Xx	True	True
# puedes	2088	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# hacer	2095	hacer	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	True
# eso	2101	ese	PRON	PRON__Number=Sing|PronType=Dem	obj	xxx	True	True
# .	2104	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Si	2106	Si	SCONJ	SCONJ___	mark	Xx	True	True
# te	2109	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# ven	2112	ver	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	advcl	xxx	True	False
# ,	2115	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# te	2117	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# van	2120	ir	AUX	AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	aux	xxx	True	True
# a	2124	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# regañar	2126	regañar	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	False
# .	2133	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Además	2135	Además	ADV	ADV___	advmod	Xxxxx	True	True
# ,	2141	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# es	2143	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xx	True	True
# por	2146	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# tu	2150	tu	NOUN	NOUN___	det	xx	True	True
# bien	2153	bien	ADV	ADV___	ROOT	xxxx	True	True
# .	2157	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# No	2159	No	ADV	ADV__Polarity=Neg	advmod	Xx	True	True
# te	2162	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	iobj	xx	True	True
# las	2165	los	PRON	PRON__Case=Acc|Gender=Fem|Number=Plur|Person=3|PronType=Prs	obj	xxx	True	True
# están	2169	estar	AUX	AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	aux	xxxx	True	True
# dando	2175	dar	VERB	VERB__VerbForm=Ger	ROOT	xxxx	True	False
# para	2181	parir	ADP	ADP__AdpType=Prep	mark	xxxx	True	True
# que	2186	que	SCONJ	SCONJ___	mark	xxx	True	True
# te	2190	te	PRON	PRON__Number=Sing|Person=2	obj	xx	True	True
# enfermes	2193	enfermar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# más	2202	más	ADV	ADV___	advmod	xxx	True	True
# .	2205	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	2206
# 	SPACE	_SP
# 	False	False
# Ay	2207	Ay	PROPN	PROPN___	nsubj	Xx	True	False
# respeta	2210	respetar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# por	2218	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# favor	2222	favor	NOUN	NOUN__Gender=Masc|Number=Sing	obl	xxxx	True	False
# .	2227	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	2228
# 	SPACE	_SP
# 	False	False
# ¿	2229	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Será	2230	Será	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	ROOT	Xxxx	True	True
# que	2235	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	2239	me	PRON	PRON__Number=Sing|Person=1	iobj	xx	True	True
# puedes	2242	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# ayudar	2249	ayudar	VERB	VERB__VerbForm=Inf	ccomp	xxxx	True	False
# a	2256	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# organizar	2258	organizar	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	False
# un	2268	uno	DET	DET__Gender=Masc|Number=Sing|PronType=Art	advmod	xx	True	True
# poco	2271	poco	ADV	ADV___	fixed	xxxx	True	True
# esta	2276	este	DET	DET__Gender=Fem|Number=Sing|PronType=Dem	det	xxxx	True	True
# casa	2281	casar	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# ?	2285	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	2286
# 	SPACE	_SP
# 	False	False
# Vamos	2287	Vamos	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	ROOT	Xxxxx	True	True
# ,	2292	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# pásala	2294	pásala	PROPN	PROPN___	conj	xxxx	True	False
# .	2300	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	2301
# 	SPACE	_SP
# 	False	False
# Mamá	2302	Mamá	PROPN	PROPN___	nsubj	Xxxx	True	False
# a	2307	a	ADP	ADP__AdpType=Prep	case	x	True	False
# mi	2309	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# amiga	2312	amigo	NOUN	NOUN__Gender=Fem|Number=Sing	nmod	xxxx	True	False
# le	2318	le	PRON	PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs	obj	xx	True	True
# gustan	2321	gustar	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# tus	2328	tu	DET	DET__Number=Plur|Number[psor]=Sing|Person=2|Poss=Yes|PronType=Prs	det	xxx	True	True
# galletas	2332	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# .	2340	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# ¿	2342	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Será	2343	Será	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	ROOT	Xxxx	True	True
# que	2348	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	2352	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# indicas	2355	indicar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# cómo	2363	cómo	PRON	PRON__PronType=Int	obl	xxxx	True	True
# se	2368	se	PRON	PRON___	obj	xx	True	True
# hacen	2371	hacer	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	csubj	xxxx	True	True
# ?	2376	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	2377
# 	SPACE	_SP
# 	False	False
# Debemos	2378	Debemos	AUX	AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	nsubj	Xxxxx	True	False
# reunirnos	2386	reunirnos	ADJ	ADJ__Gender=Masc|Number=Plur	flat	xxxx	True	False
# lo	2396	el	DET	DET__Definite=Def|Number=Sing|PronType=Art	det	xx	True	True
# más	2399	más	ADV	ADV___	advmod	xxx	True	True
# pronto	2403	pronto	ADV	ADV___	advmod	xxxx	True	True
# posible	2410	posible	ADJ	ADJ__Number=Sing	ROOT	xxxx	True	True
# .	2417	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Mira	2419	Mira	NOUN	NOUN___	aux	Xxxx	True	False
# a	2424	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# ver	2426	ver	AUX	AUX__VerbForm=Inf	aux	xxx	True	True
# cuándo	2430	cuándo	PRON	PRON__PronType=Int	ROOT	xxxx	True	True
# y	2437	y	CONJ	CCONJ___	cc	x	True	False
# me	2439	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# avisas	2442	avisar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# .	2448	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	2449
# 	SPACE	_SP
# 	False	False
# ¿	2450	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Por	2451	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# qué	2455	qué	PRON	PRON__Number=Sing|PronType=Int	obl	xxx	True	True
# eres	2459	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# tan	2464	tan	ADV	ADV___	advmod	xxx	True	True
# traicionera	2468	traicionero	ADJ	ADJ__Gender=Fem|Number=Sing	ROOT	xxxx	True	False
# ?	2479	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# ¿	2481	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Por	2482	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# qué	2486	qué	PRON	PRON__Number=Sing|PronType=Int	obl	xxx	True	True
# no	2490	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# me	2493	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# hablaste	2496	hablar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# con	2505	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# la	2509	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# verdad	2512	verdad	NOUN	NOUN__Gender=Fem|Number=Sing	obl	xxxx	True	True
# de	2519	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# un	2522	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# comienzo	2525	comenzar	NOUN	NOUN__Gender=Masc|Number=Sing	nmod	xxxx	True	False
# de	2534	de	ADP	ADP__AdpType=Prep	mark	xx	True	True
# que	2537	que	SCONJ	SCONJ___	mark	xxx	True	True
# me	2541	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	iobj	xx	True	True
# ibas	2544	ir	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# a	2549	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# reventar	2551	reventar	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	False
# ?	2559	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# Eso	2561	Eso	PRON	PRON__Number=Sing|PronType=Dem	nsubj	Xxx	True	True
# no	2565	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# es	2568	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xx	True	True
# correcto	2571	correcto	ADJ	ADJ__Gender=Masc|Number=Sing	ROOT	xxxx	True	False
# ,	2579	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# una	2581	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	det	xxx	True	True
# amiga	2585	amigo	NOUN	NOUN__Gender=Fem|Number=Sing	nsubj	xxxx	True	False
# no	2591	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# le	2594	le	PRON	PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs	obj	xx	True	True
# hace	2597	hacer	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	True
# eso	2602	ese	PRON	PRON__Number=Sing|PronType=Dem	obj	xxx	True	True
# a	2606	a	ADP	ADP__AdpType=Prep	case	x	True	False
# una	2608	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	det	xxx	True	True
# compañera	2612	compañero	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# .	2621	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	2623
# 	SPACE	_SP
# 	False	False
# ¿	2624	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Mamá	2625	Mamá	PROPN	PROPN___	nsubj	Xxxx	True	False
# qué	2630	qué	PRON	PRON__Number=Sing|PronType=Int	nsubj	xxx	True	True
# te	2634	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	iobj	xx	True	True
# pasa	2637	paso	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# ultimamente	2642	ultimamente	ADV	ADV___	advmod	xxxx	True	False
# que	2654	que	SCONJ	SCONJ___	mark	xxx	True	True
# ya	2658	ya	ADV	ADV___	advmod	xx	True	True
# no	2661	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# me	2664	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# escuchas	2667	escuchar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# que	2676	que	PRON	PRON__PronType=Rel	mark	xxx	True	True
# ya	2680	ya	ADV	ADV___	advmod	xx	True	True
# no	2683	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# eres	2686	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# conmigo	2691	conmigo	PRON	PRON__Number=Sing|Person=1|PrepCase=Pre|PronType=Prs	csubj	xxxx	True	True
# la	2699	lo	PRON	PRON__Case=Acc|Gender=Fem|Number=Sing|Person=3|PronType=Prs	det	xx	True	True
# misma?Cuéntame	2702	misma?Cuéntame	NOUN	NOUN__Gender=Fem|Number=Sing	nsubj	xxxx?Xxxxx	False	False
# .	2716	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# ¿	2718	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Tienes	2719	Tienes	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ROOT	Xxxxx	True	False
# algún	2726	alguno	DET	DET__Gender=Masc|Number=Sing|PronType=Ind	det	xxxx	True	True
# problema	2732	problema	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# o	2741	o	CONJ	CCONJ___	cc	x	True	False
# estás	2743	estar	PROPN	PROPN___	conj	xxxx	True	False
# enferma	2749	enfermo	PROPN	PROPN___	obj	xxxx	True	False
# ?	2756	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
#
# 	2757
# 	SPACE	_SP
# 	False	False
# Pero	2758	Pero	CONJ	CCONJ___	cc	Xxxx	True	True
# recoge	2763	recoger	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# el	2770	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# reblujo	2773	reblujo	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# .	2780	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Mira	2782	Mira	VERB	VERB__Mood=Imp|Number=Sing|Person=2|VerbForm=Fin	ROOT	Xxxx	True	False
# que	2787	que	SCONJ	SCONJ___	mark	xxx	True	True
# vienen	2791	venir	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# mis	2798	mi	DET	DET__Number=Plur|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xxx	True	True
# papás	2802	papá	PROPN	PROPN___	obj	xxxx	True	False
# y	2808	y	CONJ	CCONJ___	cc	x	True	False
# no	2810	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# les	2813	les	PRON	PRON__Case=Dat|Number=Plur|Person=3|PronType=Prs	obj	xxx	True	True
# gusta	2817	gustar	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# el	2823	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# desorden	2826	desorden	NOUN	NOUN__Gender=Masc|Number=Sing	nsubj	xxxx	True	False
# .	2834	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Entonces	2836	Entonces	ADV	ADV___	advmod	Xxxxx	True	True
# colabórame	2845	colabórame	NOUN	NOUN__Gender=Fem|Number=Sing	ROOT	xxxx	True	False
# .	2855	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Ayúdame	2857	Ayúdame	PROPN	PROPN___	ROOT	Xxxxx	True	False
# ,	2864	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# colabórame	2866	colabórame	VERB	VERB__Mood=Imp|Number=Sing|Person=3|VerbForm=Fin	amod	xxxx	True	False
# con	2877	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# eso	2881	ese	PRON	PRON__Number=Sing|PronType=Dem	obl	xxx	True	True
# .	2884	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Para	2886	Para	ADP	ADP__AdpType=Prep	mark	Xxxx	True	True
# que	2891	que	SCONJ	SCONJ___	mark	xxx	True	True
# ...	2894	...	PUNCT	PUNCT__PunctType=Comm	punct	...	False	False
# cuando	2898	cuando	SCONJ	SCONJ___	mark	xxxx	True	True
# mis	2905	mi	DET	DET__Number=Plur|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xxx	True	True
# papas	2909	papar	NOUN	NOUN__Gender=Fem|Number=Plur	nsubj	xxxx	True	False
# lleguen	2915	llegar	VERB	VERB__Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# ,	2922	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# encuentran	2924	encontrar	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# una	2935	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	det	xxx	True	True
# casa	2939	casar	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# organizada	2944	organizar	ADJ	ADJ__Gender=Fem|Number=Sing|VerbForm=Part	amod	xxxx	True	False
# …	2954	…	NOUN	NOUN__AdvType=Tim	obj	…	False	False
# .	2955	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
#
# 	2956
#
# 	SPACE	_SP
#
# 	False	False
# Pero	2958	Pero	CONJ	CCONJ___	cc	Xxxx	True	True
# mira	2963	mirar	VERB	VERB__Mood=Imp|Number=Sing|Person=2|VerbForm=Fin	ROOT	xxxx	True	False
# que	2968	que	SCONJ	SCONJ___	mark	xxx	True	True
# si	2972	si	SCONJ	SCONJ___	mark	xx	True	True
# no	2975	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# te	2978	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# tomas	2981	tomar	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	advcl	xxxx	True	False
# la	2987	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# drogra	2990	drogra	ADJ	ADJ__Gender=Fem|Number=Sing	nsubj	xxxx	True	False
# ,	2996	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# te	2998	te	PRON	PRON__Number=Sing|Person=2	iobj	xx	True	True
# vas	3001	ir	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxx	True	False
# a	3005	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# enfermar	3007	enfermar	VERB	VERB__VerbForm=Inf	ccomp	xxxx	True	False
# .	3015	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# No	3017	No	ADV	ADV__Polarity=Neg	advmod	Xx	True	True
# finja	3020	fingir	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# delante	3026	delante	ADV	ADV___	advmod	xxxx	True	True
# de	3034	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# mí	3037	mí	PRON	PRON__Number=Sing|Person=1|PrepCase=Pre|PronType=Prs	obl	xx	True	True
# porque	3040	porque	SCONJ	SCONJ___	mark	xxxx	True	True
# no	3047	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# voy	3050	ir	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	aux	xxx	True	True
# a	3054	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# estar	3056	estar	VERB	VERB__VerbForm=Inf	advcl	xxxx	True	True
# todo	3062	todo	DET	DET__Gender=Masc|Number=Sing|PronType=Ind	det	xxxx	True	True
# el	3067	el	DET	DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# tiempo	3070	tiempo	NOUN	NOUN__Gender=Masc|Number=Sing	nsubj	xxxx	True	True
# contigo	3077	contigo	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	amod	xxxx	True	True
# .	3084	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	3085
# 	SPACE	_SP
# 	False	False
# ¿	3086	¿	PUNCT	PUNCT__PunctSide=Ini|PunctType=Qest	punct	¿	False	False
# Es	3087	Es	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	Xx	True	True
# que	3090	que	SCONJ	SCONJ___	mark	xxx	True	True
# acaso	3094	acaso	ADV	ADV___	advmod	xxxx	True	False
# no	3100	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# te	3103	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# caigo	3106	caer	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# bien	3112	bien	ADV	ADV___	advmod	xxxx	True	True
# ?	3116	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# Por	3118	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# favor	3122	favor	NOUN	NOUN___	obl	xxxx	True	False
# pásame	3128	pásame	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	amod	xxxx	True	False
# la	3135	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# ...
# que	30607	que	SCONJ	SCONJ___	mark	xxx	True	True
# le	30611	le	PRON	PRON__Case=Dat|Number=Sing|Person=3|PronType=Prs	obj	xx	True	True
# grites	30614	gritar	NOUN	NOUN__Number=Plur	csubj	xxxx	True	False
# a	30621	a	ADP	ADP__AdpType=Prep	case	x	True	False
# mi	30623	mi	DET	DET__Number=Sing|Number[psor]=Sing|Person=1|Poss=Yes|PronType=Prs	det	xx	True	True
# perro	30626	perro	NOUN	NOUN__Gender=Masc|Number=Sing	obl	xxxx	True	False
# ,	30631	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# que	30633	que	SCONJ	SCONJ___	mark	xxx	True	True
# los	30637	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# animales	30641	animal	NOUN	NOUN__Gender=Masc|Number=Plur	nsubj	xxxx	True	False
# también	30650	también	ADV	ADV___	advmod	xxxx	True	True
# merecen	30658	merecer	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# que	30666	que	SCONJ	SCONJ___	mark	xxx	True	True
# uno	30670	unir	PRON	PRON__Gender=Masc|Number=Sing|PronType=Ind	nsubj	xxx	True	True
# los	30674	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# respete	30678	respetar	NOUN	NOUN__Gender=Masc|Number=Sing	ccomp	xxxx	True	False
# y	30686	y	CONJ	CCONJ___	cc	x	True	False
# los	30688	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# trate	30692	tratar	VERB	VERB__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# bien	30698	bien	ADV	ADV___	advmod	xxxx	True	True
# .	30702	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Porque	30704	Porque	SCONJ	SCONJ___	mark	Xxxxx	True	True
# él	30711	él	PRON	PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs	nsubj	xx	True	True
# está	30714	estar	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# acostumbrado	30719	acostumbrar	ADJ	ADJ__Gender=Masc|Number=Sing|VerbForm=Part	ROOT	xxxx	True	False
# a	30732	a	ADP	ADP__AdpType=Prep	case	x	True	False
# un	30734	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# trato	30737	tratar	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# diferente	30743	diferente	ADJ	ADJ__Number=Sing	amod	xxxx	True	True
# .	30752	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	30753
# 	SPACE	_SP
# 	False	False
# Vea	30754	Vea	PROPN	PROPN___	nsubj	Xxx	True	False
# hija	30758	hijo	NOUN	NOUN__Gender=Fem|Number=Sing	flat	xxxx	True	False
# ,	30762	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# por	30764	por	ADP	ADP__AdpType=Prep	advmod	xxx	True	True
# favor	30768	favor	NOUN	NOUN___	fixed	xxxx	True	False
# ,	30773	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# vienen	30775	venir	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# nuestros	30782	nuestro	DET	DET__Gender=Masc|Number=Plur|Number[psor]=Plur|Person=1|Poss=Yes|PronType=Prs	det	xxxx	True	True
# papás	30791	papá	PROPN	PROPN___	obj	xxxx	True	False
# y	30797	y	CONJ	CCONJ___	cc	x	True	False
# la	30799	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# casa	30802	casar	NOUN	NOUN__Gender=Fem|Number=Sing	nsubj	xxxx	True	False
# está	30807	estar	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# muy	30812	muy	ADV	ADV___	advmod	xxx	True	True
# desorganizada	30816	desorganizar	ADJ	ADJ__Gender=Fem|Number=Sing|VerbForm=Part	conj	xxxx	True	False
# y	30830	y	CONJ	CCONJ___	cc	x	True	False
# yo	30832	yo	PRON	PRON__Case=Nom|Number=Sing|Person=1|PronType=Prs	nsubj	xx	True	True
# estoy	30835	estar	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# muy	30841	muy	ADV	ADV___	advmod	xxx	True	True
# ocupada	30845	ocupar	ADJ	ADJ__Gender=Fem|Number=Sing|VerbForm=Part	conj	xxxx	True	False
# .	30852	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Por	30854	Por	ADP	ADP__AdpType=Prep	advmod	Xxx	True	True
# favor	30858	favor	NOUN	NOUN___	fixed	xxxx	True	False
# ,	30863	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# ayúdame	30865	ayúdame	VERB	VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# que	30873	que	SCONJ	SCONJ___	mark	xxx	True	True
# además	30877	además	ADV	ADV___	advmod	xxxx	True	True
# yo	30884	yo	PRON	PRON__Case=Nom|Number=Sing|Person=1|PronType=Prs	nsubj	xx	True	True
# estoy	30887	estar	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# muy	30893	muy	ADV	ADV___	advmod	xxx	True	True
# cansada	30897	cansar	ADJ	ADJ__Gender=Fem|Number=Sing|VerbForm=Part	csubj	xxxx	True	False
# .	30904	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	30905
# 	SPACE	_SP
# 	False	False
# Por	30906	Por	ADP	ADP__AdpType=Prep	case	Xxx	True	True
# favor	30910	favor	NOUN	NOUN___	obl	xxxx	True	False
# ,	30915	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# les	30917	les	PRON	PRON__Case=Dat|Number=Plur|Person=3|PronType=Prs	obj	xxx	True	True
# puedes	30921	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# comentar	30928	comentar	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	False
# a	30937	a	ADP	ADP__AdpType=Prep	case	x	True	False
# las	30939	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# personas	30943	personar	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# que	30952	que	PRON	PRON__PronType=Rel	obj	xxx	True	True
# como	30956	comer	SCONJ	SCONJ___	mark	xxxx	True	True
# somos	30961	ser	AUX	AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	cop	xxxx	True	True
# mucho	30967	mucho	ADV	ADV___	acl	xxxx	True	True
# con	30973	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# gustos	30977	gusto	NOUN	NOUN__Gender=Masc|Number=Plur	obl	xxxx	True	False
# distintos	30984	distinto	ADJ	ADJ__Gender=Masc|Number=Plur	amod	xxxx	True	False
# ,	30993	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# si	30995	si	SCONJ	SCONJ___	mark	xx	True	True
# es	30998	ser	AUX	AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	cop	xx	True	True
# posible	31001	posible	ADJ	ADJ__Number=Sing	advcl	xxxx	True	True
# que	31009	que	SCONJ	SCONJ___	mark	xxx	True	True
# podamos	31013	poder	AUX	AUX__Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	csubj	xxxx	True	False
# un	31021	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# momentico	31024	momentico	ADJ	ADJ__Gender=Masc|Number=Sing	amod	xxxx	True	False
# suspender	31034	suspender	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	False
# la	31044	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# música	31047	músico	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# que	31054	que	PRON	PRON__PronType=Rel	nsubj	xxx	True	True
# vienen	31058	venir	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# y	31065	y	CONJ	CCONJ___	cc	x	True	False
# dar	31067	dar	VERB	VERB__VerbForm=Inf	conj	xxx	True	True
# la	31071	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# oportunidad	31074	oportunidad	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# que	31086	que	PRON	PRON__PronType=Rel	obj	xxx	True	True
# otros	31090	otro	PRON	PRON__Gender=Masc|Number=Plur|PronType=Ind	nsubj	xxxx	True	True
# disfruten	31096	disfrutar	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# con	31106	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# otra	31110	otro	PRON	PRON__Gender=Fem|Number=Sing|PronType=Ind	obl	xxxx	True	True
# .	31114	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	31115
# 	SPACE	_SP
# 	False	False
# Mami	31116	Mami	PROPN	PROPN___	nsubj	Xxxx	True	False
# ,	31120	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# mami	31122	mami	PROPN	PROPN___	conj	xxxx	True	False
# ,	31126	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# me	31128	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# puedes	31131	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# colaborar	31138	colaborar	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	False
# ?	31147	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# Nos	31149	Nos	PRON	PRON__Number=Plur|Person=1	obj	Xxx	True	True
# vamos	31153	ir	AUX	AUX__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	aux	xxxx	True	True
# a	31159	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# reunir	31161	reunir	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	False
# con	31168	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# las	31172	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# amigas	31176	amigo	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# y	31183	y	CONJ	CCONJ___	cc	x	True	False
# de	31185	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# todo	31188	todo	PRON	PRON__Gender=Masc|Number=Sing|PronType=Ind	conj	xxxx	True	True
# y	31193	y	CONJ	CCONJ___	cc	x	True	False
# acuérdate	31195	acuérdate	NOUN	NOUN__Gender=Masc|Number=Sing	conj	xxxx	True	False
# de	31205	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# los	31208	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# pasteles	31212	pastel	NOUN	NOUN__Number=Plur	nmod	xxxx	True	False
# y	31221	y	CONJ	CCONJ___	cc	x	True	False
# las	31223	los	DET	DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art	det	xxx	True	True
# galletas	31227	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	conj	xxxx	True	False
# que	31236	que	PRON	PRON__PronType=Rel	obj	xxx	True	True
# hicicmos	31240	hicicmos	VERB	VERB__Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# para	31249	parir	ADP	ADP__AdpType=Prep	case	xxxx	True	True
# ellos	31254	ellos	PRON	PRON__Gender=Masc|Number=Plur|Person=3|PronType=Prs	obl	xxxx	True	True
# y	31260	y	CONJ	CCONJ___	cc	x	True	False
# ahora	31262	ahora	ADV	ADV___	advmod	xxxx	True	True
# quieren	31268	querer	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	conj	xxxx	True	False
# repetirlas	31276	repetirlas	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# y	31287	y	CONJ	CCONJ___	cc	x	True	False
# yo	31289	yo	PRON	PRON__Case=Nom|Number=Sing|Person=1|PronType=Prs	nsubj	xx	True	True
# no	31292	no	ADV	ADV__Polarity=Neg	advmod	xx	True	True
# me	31295	me	PRON	PRON__Number=Sing|Person=1	obj	xx	True	True
# acuerdo	31298	acordar	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	conj	xxxx	True	True
# .	31305	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Me	31307	Me	PRON	PRON__Number=Sing|Person=1	obj	Xx	True	True
# puedes	31310	poder	AUX	AUX__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	aux	xxxx	True	False
# dar	31317	dar	VERB	VERB__VerbForm=Inf	ROOT	xxx	True	True
# la	31321	lo	DET	DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art	det	xx	True	True
# fórmula	31324	fórmula	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# nuevamente	31332	nuevamente	ADV	ADV___	advmod	xxxx	True	False
# ?	31342	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# Quiero	31344	Quiero	VERB	VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	ROOT	Xxxxx	True	False
# que	31351	que	SCONJ	SCONJ___	mark	xxx	True	True
# ellas	31355	ellos	PRON	PRON__Gender=Fem|Number=Plur|Person=3|PronType=Prs	nsubj	xxxx	True	True
# se	31361	se	PRON	PRON__Person=3	obj	xx	True	True
# sientan	31364	sentir	VERB	VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	ccomp	xxxx	True	False
# bien	31372	bien	ADV	ADV___	advmod	xxxx	True	True
# ,	31376	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# porque	31378	porque	SCONJ	SCONJ___	mark	xxxx	True	True
# están	31385	estar	AUX	AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	aux	xxxx	True	True
# aspirando	31391	aspirar	VERB	VERB__VerbForm=Ger	advcl	xxxx	True	False
# a	31401	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# volver	31403	volver	AUX	AUX__VerbForm=Inf	aux	xxxx	True	False
# a	31410	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# degustar	31412	degustar	VERB	VERB__VerbForm=Inf	xcomp	xxxx	True	False
# esas	31421	ese	DET	DET__Gender=Fem|Number=Plur|PronType=Dem	det	xxxx	True	True
# galletas	31426	galleta	NOUN	NOUN__Gender=Fem|Number=Plur	obj	xxxx	True	False
# tan	31435	tan	ADV	ADV___	advmod	xxx	True	True
# ricas	31439	rico	ADJ	ADJ__Gender=Fem|Number=Plur	amod	xxxx	True	False
# .	31444	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
# 	31445
# 	SPACE	_SP
# 	False	False
# Próximamente	31446	Próximamente	ADV	ADV___	advmod	Xxxxx	True	False
# ,	31458	,	PUNCT	PUNCT__PunctType=Comm	punct	,	False	False
# voy	31460	ir	AUX	AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	aux	xxx	True	True
# a	31464	a	ADP	ADP__AdpType=Prep	mark	x	True	False
# cumplir	31466	cumplir	VERB	VERB__VerbForm=Inf	ROOT	xxxx	True	False
# años	31474	año	NOUN	NOUN__Gender=Masc|Number=Plur	obj	xxxx	True	False
# y	31479	y	CONJ	CCONJ___	cc	x	True	False
# me	31481	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# gustaría	31484	gustar	VERB	VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	conj	xxxx	True	False
# hacer	31493	hacer	VERB	VERB__VerbForm=Inf	csubj	xxxx	True	True
# un	31499	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# paseo	31502	pasear	NOUN	NOUN__Gender=Masc|Number=Sing	obj	xxxx	True	False
# y	31508	y	CONJ	CCONJ___	cc	x	True	False
# estar	31510	estar	VERB	VERB__VerbForm=Inf	conj	xxxx	True	True
# cerca	31516	cercar	ADV	ADV___	advmod	xxxx	True	True
# por	31522	por	ADP	ADP__AdpType=Prep	case	xxx	True	True
# los	31526	lo	DET	DET__Definite=Def|Gender=Masc|Number=Plur|PronType=Art	det	xxx	True	True
# lados	31530	lado	NOUN	NOUN__Gender=Masc|Number=Plur	obl	xxxx	True	False
# de	31536	de	ADP	ADP__AdpType=Prep	case	xx	True	True
# un	31539	uno	DET	DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	det	xx	True	True
# río	31542	reír	NOUN	NOUN__Gender=Masc|Number=Sing	nmod	xxx	True	False
# o	31546	o	CONJ	CCONJ___	cc	x	True	False
# algo	31548	algo	PRON	PRON__Number=Sing|PronType=Ind	conj	xxxx	True	True
# .	31552	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
# Tú	31554	Tú	PRON	PRON__Case=Nom|Number=Sing|Person=2|PronType=Prs	nsubj	Xx	True	True
# me	31557	me	PRON	PRON__Number=Sing|Person=1|PronType=Prs	obj	xx	True	True
# acompañas	31560	acompañar	NOUN	NOUN__Gender=Fem|Number=Plur	ROOT	xxxx	True	False
# ?	31569	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# O	31571	O	CONJ	CCONJ___	advmod	X	True	False
# tienes	31573	tener	VERB	VERB__Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin	ROOT	xxxx	True	False
# otra	31580	otro	DET	DET__Gender=Fem|Number=Sing|PronType=Ind	det	xxxx	True	True
# propuesta	31585	proponer	NOUN	NOUN__Gender=Fem|Number=Sing	obj	xxxx	True	False
# mejor	31595	mejor	ADJ	ADJ__Number=Sing	amod	xxxx	True	True
# ?	31600	?	PUNCT	PUNCT__PunctSide=Fin|PunctType=Qest	punct	?	False	False
# Qué	31602	Qué	PRON	PRON__Number=Sing|PronType=Int	nsubj	Xxx	True	True
# te	31606	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# gustaría	31609	gustar	VERB	VERB__Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	ROOT	xxxx	True	False
# hacer	31618	hacer	VERB	VERB__VerbForm=Inf	csubj	xxxx	True	True
# y	31624	y	CONJ	CCONJ___	cc	x	True	False
# qué	31626	qué	PRON	PRON__Number=Sing|PronType=Int	det	xxx	True	True
# inconveniente	31630	inconveniente	ADV	ADV___	obj	xxxx	True	False
# tenemos	31644	tener	VERB	VERB__Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin	aux	xxxx	True	True
# de	31652	de	ADP	ADP__AdpType=Prep	mark	xx	True	True
# celebrar	31655	celebrar	VERB	VERB__VerbForm=Inf	conj	xxxx	True	False
# ese	31664	ese	DET	DET__Gender=Masc|Number=Sing|PronType=Dem	det	xxx	True	True
# cumpleaños	31668	cumpleaños	NOUN	NOUN__Gender=Masc	obj	xxxx	True	False
# juntos	31679	junto	ADJ	ADJ__Gender=Masc|Number=Plur	amod	xxxx	True	False
# con	31686	con	ADP	ADP__AdpType=Prep	case	xxx	True	True
# una	31690	uno	DET	DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	det	xxx	True	True
# actividad	31694	actividad	NOUN	NOUN__Gender=Fem|Number=Sing	obl	xxxx	True	False
# que	31704	que	PRON	PRON__PronType=Rel	obj	xxx	True	True
# a	31708	a	ADP	ADP__AdpType=Prep	case	x	True	False
# ti	31710	ti	PRON	PRON__Number=Sing|Person=2|PrepCase=Pre|PronType=Prs	obj	xx	True	True
# te	31713	te	PRON	PRON__Number=Sing|Person=2|PronType=Prs	obj	xx	True	True
# guste	31716	gustar	VERB	VERB__Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	acl	xxxx	True	False
# también	31722	también	ADV	ADV___	advmod	xxxx	True	True
# .	31729	.	PUNCT	PUNCT__PunctType=Peri	punct	.	False	False
#
#
# 	31730
#
# 	SPACE	_SP
#
# 	False	False

# %% [markdown]
# The above output contains for every token in a line the token itself, the lemma, the Part-of-Speech tag, the dependency label, the orthographic shape (upper and lower case characters as X or x respectively), the boolean for the token being an alphanumeric string, and the boolean for it being a *stopword*.

# %% [markdown]
# ### Dependency Parse

# %% [markdown]
# Using the same approach as above for PoS-tags, we can print the Dependency Parse relations:

# %%
for token in doc1:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
          [child for child in token.children])
# Out:
# ﻿Má nsubj contando VERB [,]
# , punct ﻿Má PROPN []
# te obj contando VERB []
# estoy aux contando VERB []
# contando ROOT contando VERB [﻿Má, te, estoy, noticia, preguntas, .]
# una det noticia NOUN []
# noticia obj contando VERB [una, importante]
# muy advmod importante ADJ []
# importante amod noticia NOUN [muy]
# y cc preguntas VERB []
# sólo advmod preguntas VERB []
# me obj preguntas VERB []
# preguntas conj contando VERB [y, sólo, me, pagué]
# si mark pagué VERB []
# pagué advcl preguntas VERB [si, tarjeta]
# mi det tarjeta NOUN []
# tarjeta obj pagué VERB [mi]
# . punct contando VERB []
# Qué det _ PROPN []
# _ ROOT _ PROPN [Qué, _, _, _, _, eres, .]
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# que mark eres PROPN []
# eres acl _ PROPN [que]
# . punct _ PROPN [
# ]
#
#   . PUNCT []
# Ma nsubj cuento VERB []
# , punct confío VERB []
# por mark confío VERB [favor]
# favor fixed por ADP []
# si mark confío VERB []
# yo nsubj confío VERB []
# confío advcl cuento VERB [,, por, si, yo, ti, ,]
# en case ti PRON []
# ti obl confío VERB [en]
# , punct confío VERB []
# te obj cuento VERB []
# cuento ccomp es AUX [Ma, confío, te, cosas, ,]
# mis det cosas NOUN []
# cosas obj cuento VERB [mis]
# , punct cuento VERB []
# es ROOT es AUX [cuento, aconseje, ...]
# para mark aconseje VERB []
# que mark aconseje VERB []
# me obj aconseje VERB []
# aconseje ccomp es AUX [para, que, me, no]
# , punct no ADV []
# no advmod aconseje VERB [,, para, estés]
# para case no ADV []
# que mark estés PROPN []
# estés advcl no ADV [que, impaciente]
# todo det impaciente ADJ []
# impaciente obj estés PROPN [todo]
# ... punct es AUX []
# por ROOT por ADP [todo, .]
# todo fixed por ADP []
# . punct por ADP [
#
# ]
#
#
#   . PUNCT []
# Amigo ROOT Amigo PROPN [?, ...]
# ? punct Amigo PROPN []
# ... punct Amigo PROPN []
# Mis det papás PROPN []
# papás nsubj gusta VERB [Mis]
# y cc gusta VERB []
# a case ellos PRON []
# ellos obj gusta VERB [a]
# no advmod gusta VERB []
# les obj gusta VERB []
# gusta ROOT gusta VERB [papás, y, ellos, no, les, desorden, .]
# el det desorden NOUN []
# desorden nsubj gusta VERB [el]
# . punct gusta VERB []
# Entonces advmod necesito VERB []
# necesito ROOT necesito VERB [Entonces, ayudes, .]
# que mark ayudes VERB []
# me obj ayudes VERB []
# ayudes ccomp necesito VERB [que, me, organizar]
# por mark organizar VERB [favor, a]
# favor fixed por ADP []
# a fixed por ADP []
# organizar advcl ayudes VERB [por, cosas]
# las det cosas NOUN []
# cosas obj organizar VERB [las, rápido]
# rápido amod cosas NOUN []
# . punct necesito VERB [
#
# ]
#
#
#   . PUNCT []
# Soy cop consciente ADJ []
# consciente ROOT consciente ADJ [Soy, estado, verte, ,, charlando, .]
# del case estado NOUN []
# estado nmod consciente ADJ [del, salud, tienes]
# de case salud NOUN []
# salud nmod estado NOUN [de]
# en case que PRON []
# el det que PRON []
# que obl tienes VERB [en, el]
# tienes acl estado NOUN [que, gustaría]
# y cc gustaría VERB []
# me obj gustaría VERB []
# gustaría conj tienes VERB [y, me]
# verte amod consciente ADJ [mejor]
# mejor amod verte NOUN []
# , punct consciente ADJ []
# poder aux charlando VERB []
# seguir aux charlando VERB []
# charlando acl consciente ADJ [poder, seguir, ,, jugando]
# , punct charlando VERB []
# seguir aux jugando VERB []
# jugando advcl charlando VERB [seguir, naipes]
# naipes obj jugando VERB []
# . punct consciente ADJ []
# charlamos ROOT charlamos VERB [gustaría, .]
# pues mark gustaría VERB [entonces]
# entonces fixed pues SCONJ []
# para mark salud NOUN []
# que mark salud NOUN []
# mejores amod salud NOUN []
# tu det salud NOUN []
# salud advcl gustaría VERB [para, que, mejores, tu, ,]
# , punct salud NOUN []
# me obj gustaría VERB []
# gustaría advcl charlamos VERB [pues, salud, me, tomes]
# que mark tomes VERB []
# te obj tomes VERB []
# tomes csubj gustaría VERB [que, te, pastillas, fingas]
# las det pastillas NOUN []
# pastillas obj tomes VERB [las]
# y cc fingas VERB []
# que mark fingas VERB []
# no advmod fingas VERB []
# fingas conj tomes VERB [y, que, no, botes]
# que mark botes NOUN []
# las det botes NOUN []
# botes obl fingas VERB [que, las]
# . punct charlamos VERB []
# La det verdad NOUN []
# verdad nsubj importante ADJ [La]
# es cop importante ADJ []
# muy advmod importante ADJ []
# importante ROOT importante ADJ [verdad, es, muy, mí, estés, .]
# para case mí PRON []
# mí obl importante ADJ [para]
# que nsubj estés VERB []
# estés csubj importante ADJ [que, bien, gustar]
# bien advmod estés VERB []
# porque mark gustar VERB []
# me obj gustar VERB []
# gustar advcl estés VERB [porque, me, estar]
# estar xcomp gustar VERB [contigo]
# contigo obj estar VERB []
# . punct importante ADJ [
# ]
#
#   . PUNCT []
# Ma obl acuerdas ADJ [,]
# , punct Ma PROPN []
# hola nsubj acuerdas ADJ []
# te obj acuerdas ADJ []
# acuerdas ROOT acuerdas ADJ [Ma, hola, te, galletas, es, ,, ayudarme]
# de case galletas NOUN []
# las det galletas NOUN []
# galletas obj acuerdas ADJ [de, las, preparamos]
# que obj preparamos VERB []
# preparamos acl galletas NOUN [que, vacaciones]
# en case vacaciones NOUN []
# las det vacaciones NOUN []
# vacaciones obl preparamos VERB [en, las, pasadas]
# pasadas amod vacaciones NOUN []
# es conj acuerdas ADJ [quiero]
# que mark quiero VERB []
# quiero ccomp es AUX [que, volverlas, preparar, gustaron]
# volverlas obj quiero VERB []
# a mark preparar VERB []
# preparar xcomp quiero VERB [a]
# porque mark gustaron VERB [ , novio]
#    porque SCONJ []
# a case novio NOUN []
# mi det novio NOUN []
# novio fixed porque SCONJ [a, mi]
# le obj gustaron VERB []
# gustaron advcl quiero VERB [porque, le, mucho, recuerdo]
# mucho advmod gustaron VERB []
# pero cc recuerdo VERB []
# no advmod recuerdo VERB []
# recuerdo conj gustaron VERB [pero, no, hacerlas]
# cómo nmod hacerlas NOUN []
# hacerlas obj recuerdo VERB [cómo]
# , punct acuerdas ADJ []
# ¿ punct ayudarme NOUN []
# me obj ayudarme NOUN []
# puedes aux ayudarme NOUN []
# ayudarme advcl acuerdas ADJ [¿, me, puedes, ?]
# ? punct ayudarme NOUN [
# ]
#
#   ? PUNCT []
# Hola nsubj quería VERB []
# te iobj quería VERB []
# quería ROOT quería VERB [Hola, te, queda, correr, ..., avisas, .]
# preguntar aux queda VERB []
# qué det día NOUN []
# día obl queda VERB [qué]
# te obj queda VERB []
# queda ccomp quería VERB [preguntar, día, te, reunirnos]
# fácil amod reunirnos ADJ []
# reunirnos obj queda VERB [fácil, empezar]
# para mark empezar VERB []
# empezar acl reunirnos ADJ [para, investigaciones, nos]
# con case investigaciones NOUN []
# las det investigaciones NOUN []
# investigaciones obl empezar VERB [con, las, química]
# de case química NOUN []
# química nmod investigaciones NOUN [de]
# que mark nos PRON []
# nos obj empezar VERB [que]
# ... punct correr VERB []
# para mark correr VERB []
# que mark correr VERB []
# no advmod correr VERB []
# nos obj correr VERB []
# dejemos aux correr VERB []
# correr advcl quería VERB [..., para, que, no, nos, dejemos, tiempo, podamos]
# del case tiempo NOUN []
# tiempo obl correr VERB [del]
# y cc podamos VERB []
# podamos conj correr VERB [y, me]
# me obj podamos VERB []
# ... punct quería VERB []
# me obj avisas VERB []
# avisas advcl quería VERB [me, visto]
# o cc visto VERB []
# a case horas NOUN []
# qué det horas NOUN []
# horas obl visto VERB [a, qué,
# ]
#
#   horas NOUN []
# He aux visto VERB []
# visto conj avisas VERB [o, horas, He, gustan]
# que mark gustan VERB []
# te obj gustan VERB []
# gustan ccomp visto VERB [que, te, mucho, perros]
# mucho advmod gustan VERB []
# los det perros NOUN []
# perros nsubj gustan VERB [los]
# . punct quería VERB []
# ¿ punct cuántos ADJ []
# cuántos ROOT cuántos ADJ [¿, perros, ?, ¿, Madre, preguntas, ?]
# perros amod cuántos ADJ [tienes]
# tienes amod perros NOUN []
# ? punct cuántos ADJ [
# ]
#
#   ? PUNCT []
# ¿ punct cuántos ADJ []
# Madre nsubj cuántos ADJ []
# por case qué PRON []
# qué obl preguntas NOUN [por]
# no advmod primero ADV []
# primero amod preguntas NOUN [no]
# preguntas amod cuántos ADJ [qué, primero, mí]
# por case mí PRON []
# mí obj preguntas NOUN [por]
# ? punct cuántos ADJ [
# ]
#
#   ? PUNCT []
# Ten ROOT Ten PROPN [cuidado, .]
# más advmod cuidado ADJ []
# cuidado amod Ten PROPN [más]
# . punct Ten PROPN [
# ]
#
#   . PUNCT []
# Madre ROOT Madre PROPN [favor, .]
# por case favor NOUN []
# favor nmod Madre PROPN [por, préstame, atención]
# préstame amod favor NOUN []
# más advmod atención NOUN []
# atención amod favor NOUN [más]
# . punct Madre PROPN [
# ]
#
#   . PUNCT []
# Por case favor NOUN []
# favor ROOT favor NOUN [Por, ayúdame, viene, .]
# ayúdame amod favor NOUN []
# a mark viene VERB []
# limpiar aux viene VERB []
# que mark viene VERB []
# viene acl favor NOUN [a, limpiar, que, gente]
# gente obj viene VERB [casa]
# para case casa NOUN []
# mi det casa NOUN []
# casa nmod gente NOUN [para, mi]
# . punct favor NOUN [
# ]
#
#   . PUNCT []
# Por case favor ADJ []
# favor ROOT favor ADJ [Por, tómate, pastillas, .]
# tómate flat favor ADJ []
# las det pastillas NOUN []
# pastillas flat favor ADJ [las, bien]
# que nsubj bien ADV []
# son cop bien ADV []
# bien acl pastillas NOUN [que, son, ti]
# para case ti PRON []
# ti obl bien ADV [para]
# . punct favor ADJ [
# ]
#
#   . PUNCT []
# Madre nsubj quiero VERB []
# , punct quiero VERB []
# quiero ROOT quiero VERB [Madre, ,, enseñes, .]
# que mark enseñes VERB []
# me iobj enseñes VERB []
# enseñes ccomp quiero VERB [que, me, hacer]
# a mark hacer VERB []
# hacer xcomp enseñes VERB [a, galletas]
# las det galletas NOUN []
# galletas obj hacer VERB [las, especiales, quiero]
# especiales amod galletas NOUN []
# que nsubj quiero VERB []
# quiero acl galletas NOUN [que, tener]
# tener xcomp quiero VERB [presente, amigos]
# un det presente NOUN []
# presente obj tener VERB [un]
# con case amigos NOUN []
# mis det amigos NOUN []
# amigos obl tener VERB [con, mis]
# . punct quiero VERB [
# ]
#
#   . PUNCT []
# ¿ punct quieres NOUN []
# Cuándo aux quieres NOUN []
# quieres ROOT quieres NOUN [¿, Cuándo, hacer, ?]
# que mark hacer VERB []
# empecemos aux hacer VERB []
# a mark hacer VERB []
# hacer acl quieres NOUN [que, empecemos, a, trabajos]
# los det trabajos NOUN []
# trabajos obj hacer VERB [los, adelantar]
# para mark adelantar VERB []
# adelantar acl trabajos NOUN [para]
# ? punct quieres NOUN [
# ]
#
#   ? PUNCT []
# ¿ punct tienes VERB []
# Solamente advmod tienes VERB []
# tienes ROOT tienes VERB [¿, Solamente, este, ?]
# este obj tienes VERB [tienes]
# o cc tienes NOUN []
# tienes conj este DET [o, más]
# más advmod tienes NOUN []
# ? punct tienes VERB [
# ]
#
#   ? PUNCT []
# Es ROOT Es AUX [recuerdo, .]
# que mark recuerdo VERB []
# no advmod recuerdo VERB []
# recuerdo ccomp Es AUX [que, no, nombre]
# tu det nombre NOUN []
# nombre obj recuerdo VERB [tu]
# . punct Es AUX []
# ¿ punct decir VERB []
# Me iobj decir VERB []
# lo obj decir VERB []
# puedes aux decir VERB []
# volver aux decir VERB []
# a mark decir VERB []
# decir ROOT decir VERB [¿, Me, lo, puedes, volver, a, favor, ?]
# por case favor NOUN []
# favor obl decir VERB [por]
# ? punct decir VERB [
# ]
#
#   ? PUNCT []
# Oye nsubj presta VERB []
# presta advcl mira VERB [Oye, atención, ,]
# atención obj presta VERB []
# , punct presta VERB []
# mira ROOT mira VERB [presta, acá, .]
# que mark acá NOUN []
# estamos cop acá NOUN []
# acá ccomp mira VERB [que, estamos]
# . punct mira VERB []
# Todos nsubj queremos VERB []
# queremos ROOT queremos VERB [Todos, ver, .]
# ver xcomp queremos VERB []
# . punct queremos VERB [
# ]
#
#   . PUNCT []
# ¿ punct pasó VERB []
# Ma case qué PRON []
# qué obj pasó VERB [Ma]
# pasó ROOT pasó VERB [¿, qué, ?]
# ? punct pasó VERB []
# ¿ punct dije VERB []
# Te obj dije VERB []
# dije ROOT dije VERB [¿, Te, algo, pasa, ?]
# algo obj dije VERB [molesta]
# que nsubj molesta VERB []
# te obj molesta VERB []
# molesta acl algo PRON [que, te]
# o cc pasa VERB []
# qué obj pasa VERB []
# pasa conj dije VERB [o, qué, contigo]
# contigo nsubj pasa VERB [rara]
# que nsubj rara ADJ []
# estás cop rara ADJ []
# tan advmod rara ADJ []
# rara acl contigo PRON [que, estás, tan]
# ? punct dije VERB [
# ]
#
#   ? PUNCT []
# Hey nsubj pasas VERB []
# , punct próxima ADJ []
# en case próxima ADJ []
# la det próxima ADJ []
# próxima obl pasas VERB [,, en, la, ,]
# , punct próxima ADJ []
# me obj pasas VERB []
# pasas ROOT pasas VERB [Hey, próxima, me, pelota, .]
# la det pelota NOUN []
# pelota nsubj pasas VERB [la]
# . punct pasas VERB [
# ]
#
#   . PUNCT []
# Mami nsubj acuerdas VERB [,]
# , punct Mami PROPN []
# te obj acuerdas VERB []
# acuerdas ROOT acuerdas VERB [Mami, te, año, hicimos, .]
# el det año NOUN []
# año obl acuerdas VERB [el, pasado]
# pasado amod año NOUN []
# hicimos advcl acuerdas VERB [galletas, amiga]
# unas det galletas NOUN []
# galletas obj hicimos VERB [unas, súper, ricas]
# súper amod galletas NOUN []
# ricas amod galletas NOUN []
# a case amiga NOUN []
# mi det amiga NOUN []
# mejor amod amiga NOUN []
# amiga obj hicimos VERB [a, mi, mejor]
# . punct acuerdas VERB []
# ¿ punct Será AUX []
# Será ROOT Será AUX [¿, ayudarías, ?]
# que mark ayudarías VERB []
# me obj ayudarías VERB []
# ayudarías ccomp Será AUX [que, me, vez, hacerselas]
# otra det vez NOUN []
# vez obl ayudarías VERB [otra]
# a case hacerselas NOUN []
# hacerselas obl ayudarías VERB [a]
# ? punct Será AUX [
# ]
#
#   ? PUNCT []
# Hola nsubj tuyo ADJ []
# , punct tienes VERB []
# ¿ punct tienes VERB []
# cuándo obl tienes VERB []
# tienes advcl tuyo ADJ [,, ¿, cuándo, tiempo, ?, ¿, perrito, ,]
# tiempo obj tienes VERB [hacer]
# para mark hacer VERB []
# hacer acl tiempo NOUN [para, trabajo]
# el det trabajo NOUN []
# trabajo obj hacer VERB [el]
# ? punct tienes VERB [
# ]
#
#   ? PUNCT []
# ¿ punct tienes VERB []
# Y cc perrito NOUN []
# este det perrito NOUN []
# perrito conj tienes VERB [Y, este, lindo]
# tan advmod lindo ADJ []
# lindo amod perrito NOUN [tan]
# , punct tienes VERB []
# también advmod tuyo ADJ []
# es cop tuyo ADJ []
# tuyo ROOT tuyo ADJ [Hola, tienes, también, es, conoces, ?]
# o cc conoces VERB []
# no advmod conoces VERB []
# lo det conoces VERB []
# conoces conj tuyo ADJ [o, no, lo]
# ? punct tuyo ADJ [
# ]
#
#   ? PUNCT []
# No advmod hacer VERB []
# puedes aux hacer VERB []
# hacer ROOT hacer VERB [No, puedes, eso, .]
# eso obj hacer VERB []
# . punct hacer VERB []
# Si mark ven VERB []
# te obj ven VERB []
# ven advcl regañar VERB [Si, te, ,]
# , punct ven VERB []
# te obj regañar VERB []
# van aux regañar VERB []
# a mark regañar VERB []
# regañar ROOT regañar VERB [ven, te, van, a, .]
# . punct regañar VERB []
# Además advmod bien ADV [,]
# , punct Además ADV []
# es cop bien ADV []
# por case tu NOUN []
# tu det bien ADV [por]
# bien ROOT bien ADV [Además, es, tu, .]
# . punct bien ADV []
# No advmod dando VERB []
# te iobj dando VERB []
# las obj dando VERB []
# están aux dando VERB []
# dando ROOT dando VERB [No, te, las, están, enfermes, .]
# para mark enfermes VERB []
# que mark enfermes VERB []
# te obj enfermes VERB []
# enfermes advcl dando VERB [para, que, te, más]
# más advmod enfermes VERB []
# . punct dando VERB [
# ]
#
#   . PUNCT []
# Ay nsubj respeta VERB []
# respeta ROOT respeta VERB [Ay, favor, .]
# por case favor NOUN []
# favor obl respeta VERB [por]
# . punct respeta VERB [
# ]
#
#   . PUNCT []
# ¿ punct Será AUX []
# Será ROOT Será AUX [¿, ayudar, ?]
# que mark ayudar VERB []
# me iobj ayudar VERB []
# puedes aux ayudar VERB []
# ayudar ccomp Será AUX [que, me, puedes, organizar]
# a mark organizar VERB []
# organizar xcomp ayudar VERB [a, un, casa]
# un advmod organizar VERB [poco]
# poco fixed un DET []
# esta det casa NOUN []
# casa obj organizar VERB [esta]
# ? punct Será AUX [
# ]
#
#   ? PUNCT []
# Vamos ROOT Vamos VERB [pásala, .]
# , punct pásala PROPN []
# pásala conj Vamos VERB [,]
# . punct Vamos VERB [
# ]
#
#   . PUNCT []
# Mamá nsubj gustan VERB [amiga]
# a case amiga NOUN []
# mi det amiga NOUN []
# amiga nmod Mamá PROPN [a, mi]
# le obj gustan VERB []
# gustan ROOT gustan VERB [Mamá, le, galletas, .]
# tus det galletas NOUN []
# galletas obj gustan VERB [tus]
# . punct gustan VERB []
# ¿ punct Será AUX []
# Será ROOT Será AUX [¿, indicas, ?]
# que mark indicas VERB []
# me obj indicas VERB []
# indicas ccomp Será AUX [que, me, hacen]
# cómo obl hacen VERB []
# se obj hacen VERB []
# hacen csubj indicas VERB [cómo, se]
# ? punct Será AUX [
# ]
#
#   ? PUNCT []
# Debemos nsubj posible ADJ [reunirnos]
# reunirnos flat Debemos AUX []
# lo det posible ADJ []
# más advmod pronto ADV []
# pronto advmod posible ADJ [más]
# posible ROOT posible ADJ [Debemos, lo, pronto, .]
# . punct posible ADJ []
# Mira aux cuándo PRON []
# a mark cuándo PRON []
# ver aux cuándo PRON []
# cuándo ROOT cuándo PRON [Mira, a, ver, avisas, .]
# y cc avisas VERB []
# me obj avisas VERB []
# avisas conj cuándo PRON [y, me]
# . punct cuándo PRON [
# ]
#
#   . PUNCT []
# ¿ punct traicionera ADJ []
# Por case qué PRON []
# qué obl traicionera ADJ [Por]
# eres cop traicionera ADJ []
# tan advmod traicionera ADJ []
# traicionera ROOT traicionera ADJ [¿, qué, eres, tan, ?]
# ? punct traicionera ADJ []
# ¿ punct hablaste VERB []
# Por case qué PRON []
# qué obl hablaste VERB [Por]
# no advmod hablaste VERB []
# me obj hablaste VERB []
# hablaste ROOT hablaste VERB [¿, qué, no, me, verdad, ?]
# con case verdad NOUN []
# la det verdad NOUN []
# verdad obl hablaste VERB [con, la, comienzo]
# de case comienzo NOUN []
# un det comienzo NOUN []
# comienzo nmod verdad NOUN [de, un, ibas]
# de mark ibas VERB []
# que mark ibas VERB []
# me iobj ibas VERB []
# ibas acl comienzo NOUN [de, que, me, reventar]
# a mark reventar VERB []
# reventar xcomp ibas VERB [a]
# ? punct hablaste VERB []
# Eso nsubj correcto ADJ []
# no advmod correcto ADJ []
# es cop correcto ADJ []
# correcto ROOT correcto ADJ [Eso, no, es, ,, hace, .]
# , punct correcto ADJ []
# una det amiga NOUN []
# amiga nsubj hace VERB [una]
# no advmod hace VERB []
# le obj hace VERB []
# hace advcl correcto ADJ [amiga, no, le, eso, compañera]
# eso obj hace VERB []
# a case compañera NOUN []
# una det compañera NOUN []
# compañera obj hace VERB [a, una]
# . punct correcto ADJ [
# ]
#
#   . PUNCT []
# ¿ punct pasa VERB []
# Mamá nsubj pasa VERB []
# qué nsubj pasa VERB []
# te iobj pasa VERB []
# pasa ROOT pasa VERB [¿, Mamá, qué, te, ultimamente, escuchas, .]
# ultimamente advmod pasa VERB []
# que mark escuchas VERB []
# ya advmod escuchas VERB []
# no advmod escuchas VERB []
# me obj escuchas VERB []
# escuchas ccomp pasa VERB [que, ya, no, me, conmigo]
# que mark conmigo PRON []
# ya advmod conmigo PRON []
# no advmod conmigo PRON []
# eres cop conmigo PRON []
# conmigo csubj escuchas VERB [que, ya, no, eres, misma?Cuéntame]
# la det misma?Cuéntame NOUN []
# misma?Cuéntame nsubj conmigo PRON [la]
# . punct pasa VERB []
# ¿ punct Tienes VERB []
# Tienes ROOT Tienes VERB [¿, problema, estás, ?]
# algún det problema NOUN []
# problema obj Tienes VERB [algún]
# o cc estás PROPN []
# estás conj Tienes VERB [o, enferma]
# enferma obj estás PROPN []
# ? punct Tienes VERB [
# ]
#
#   ? PUNCT []
# Pero cc recoge VERB []
# recoge ROOT recoge VERB [Pero, reblujo, .]
# el det reblujo NOUN []
# reblujo obj recoge VERB [el]
# . punct recoge VERB []
# Mira ROOT Mira VERB [vienen, gusta, .]
# que mark vienen VERB []
# vienen ccomp Mira VERB [que, papás]
# mis det papás PROPN []
# papás obj vienen VERB [mis]
# y cc gusta VERB []
# no advmod gusta VERB []
# les obj gusta VERB []
# gusta conj Mira VERB [y, no, les, desorden]
# el det desorden NOUN []
# desorden nsubj gusta VERB [el]
# . punct Mira VERB []
# Entonces advmod colabórame NOUN []
# colabórame ROOT colabórame NOUN [Entonces, .]
# . punct colabórame NOUN []
# Ayúdame ROOT Ayúdame PROPN [colabórame, .]
# , punct colabórame VERB []
# colabórame amod Ayúdame PROPN [,, eso]
# con case eso PRON []
# eso obl colabórame VERB [con]
# . punct Ayúdame PROPN []
# Para mark encuentran VERB []
# que mark encuentran VERB []
# ... punct lleguen VERB []
# cuando mark lleguen VERB []
# mis det papas NOUN []
# papas nsubj lleguen VERB [mis]
# lleguen advcl encuentran VERB [..., cuando, papas, ,]
# , punct lleguen VERB []
# encuentran ROOT encuentran VERB [Para, que, lleguen, casa, .]
# una det casa NOUN []
# casa obj encuentran VERB [una, organizada]
# organizada amod casa NOUN […]
# … obj organizada ADJ []
# . punct encuentran VERB [
#
# ]
#
#
#   . PUNCT []
# Pero cc mira VERB []
# mira ROOT mira VERB [Pero, enfermar, .]
# que mark enfermar VERB []
# si mark tomas VERB []
# no advmod tomas VERB []
# te obj tomas VERB []
# tomas advcl vas VERB [si, no, te, drogra, ,]
# la det drogra ADJ []
# drogra nsubj tomas VERB [la]
# , punct tomas VERB []
# te iobj vas VERB []
# vas aux enfermar VERB [tomas, te]
# a mark enfermar VERB []
# enfermar ccomp mira VERB [que, vas, a]
# . punct mira VERB []
# No advmod finja VERB []
# finja ROOT finja VERB [No, delante, estar, .]
# delante advmod finja VERB [mí]
# de case mí PRON []
# mí obl delante ADV [de]
# porque mark estar VERB []
# no advmod estar VERB []
# voy aux estar VERB []
# a mark estar VERB []
# estar advcl finja VERB [porque, no, voy, a, tiempo]
# todo det el DET []
# el det tiempo NOUN [todo]
# tiempo nsubj estar VERB [el, contigo]
# contigo amod tiempo NOUN []
# . punct finja VERB [
# ]
#
#   . PUNCT []
# ¿ punct Es AUX []
# Es ROOT Es AUX [¿, caigo, ?]
# que mark caigo VERB []
# acaso advmod caigo VERB []
# no advmod caigo VERB []
# te obj caigo VERB []
# caigo ccomp Es AUX [que, acaso, no, te, bien]
# bien advmod caigo VERB []
# ? punct Es AUX []
# Por case favor NOUN []
# favor obl es AUX [Por, pásame, pelota]
# pásame amod favor NOUN []
# la det pelota NOUN []
# pelota appos favor NOUN [la, trata]
# o cc trata VERB []
# al advmod trata VERB []
# menos advmod trata VERB []
# trata conj pelota NOUN [o, al, menos, compartirla]
# de case compartirla NOUN []
# compartirla nmod trata VERB [de, dime]
# o cc dime PROPN []
# dime conj compartirla NOUN [o]
# si mark es AUX []
# es ROOT es AUX [favor, si, caigo, .]
# que mark caigo VERB []
# no advmod caigo VERB []
# te obj caigo VERB []
# caigo ccomp es AUX [que, no, te, bien]
# bien advmod caigo VERB [punto]
# y cc punto NOUN []
# ya advmod punto NOUN []
# punto conj bien ADV [y, ya]
# . punct es AUX []
# Pero advmod dímelo VERB []
# dímelo ROOT dímelo VERB [Pero, sinceridad, .]
# con case sinceridad NOUN []
# sinceridad obl dímelo VERB [con]
# . punct dímelo VERB [
# ]
#
#   . PUNCT []
# Mamá nsubj acuerdas VERB [tú]
# como mark tú PRON []
# tú conj Mamá PROPN [como]
# te obj acuerdas VERB []
# acuerdas ROOT acuerdas VERB [Mamá, te, galletas, ,, dame, .]
# de case galletas NOUN []
# las det galletas NOUN []
# galletas obj acuerdas VERB [de, las, preparabas]
# que obj preparabas VERB []
# tú nsubj preparabas VERB []
# preparabas acl galletas NOUN [que, tú, deliciosas]
# tan advmod deliciosas ADJ []
# deliciosas obj preparabas VERB [tan]
# , punct acuerdas VERB []
# dame advcl acuerdas VERB [receta]
# tu det receta NOUN []
# receta obj dame PROPN [tu, quiero]
# que obj quiero VERB []
# yo nsubj quiero VERB []
# quiero acl receta NOUN [que, yo, volverlas]
# volverlas obj quiero VERB [preparar]
# a mark preparar VERB []
# preparar acl volverlas NOUN [a, amigas]
# para case amigas NOUN []
# mis det amigas NOUN []
# amigas obl preparar VERB [para, mis]
# . punct acuerdas VERB [
# ]
#
#   . PUNCT []
# Eh ROOT Eh PROPN [profe, llegastes]
# profe flat Eh PROPN []
# , punct llegastes ADJ []
# ¿ punct llegastes ADJ []
# para mark llegastes ADJ []
# que mark llegastes ADJ []
# no advmod llegastes ADJ []
# llegastes advmod Eh PROPN [,, ¿, para, que, no, citaste, ?]
# si mark citaste VERB []
# me obj citaste VERB []
# citaste advcl llegastes ADJ [si, me, temprano]
# tan advmod temprano ADV []
# temprano advmod citaste VERB [tan]
# ? punct llegastes ADJ []
# Me obj parece AUX []
# parece cop falta NOUN [Me]
# una det falta NOUN []
# falta ROOT falta NOUN [parece, una, respeto, tomé, .]
# de case respeto NOUN []
# respeto nmod falta NOUN [de]
# , punct tomé VERB []
# ya mark tomé VERB [que]
# que fixed ya ADV []
# yo nsubj tomé VERB []
# tomé advcl falta NOUN [,, ya, yo, tiempo, importante]
# mi det tiempo NOUN []
# tiempo obj tomé VERB [mi]
# y cc importante ADJ []
# si mark llegaste VERB []
# no advmod llegaste VERB []
# llegaste advcl importante ADJ [si, no]
# entonces advmod importante ADJ []
# no advmod importante ADJ []
# era cop importante ADJ []
# tan advmod importante ADJ []
# importante conj tomé VERB [y, llegaste, entonces, no, era, tan, ti]
# para case ti PRON []
# ti obl importante ADJ [para]
# . punct falta NOUN [
# ]
#
#   . PUNCT []
# Mami ROOT Mami PROPN [quieres, .]
# , punct quieres VERB []
# si mark quieres VERB []
# quieres acl Mami PROPN [,, si, tenga]
# que mark tenga VERB []
# yo nsubj tenga VERB []
# te obj tenga VERB []
# tenga ccomp quieres VERB [que, yo, te, teniendo]
# teniendo advcl tenga VERB [confianza]
# la det confianza NOUN [misma]
# misma det la DET []
# confianza obj teniendo VERB [la, deberías, criticarme]
# deberías amod confianza NOUN []
# de case criticarme VERB []
# no advmod criticarme VERB []
# criticarme acl confianza NOUN [de, no, tanto]
# tanto obj criticarme VERB []
# . punct Mami PROPN []
# Para case así ADV []
# así advmod tener VERB [Para, ,]
# , punct así ADV []
# tener ROOT tener VERB [así, relación, .]
# una det relación NOUN []
# mejor amod relación NOUN []
# relación obj tener VERB [una, mejor]
# . punct tener VERB [
# ]
#
#   . PUNCT []
# Mhh ROOT Mhh PROPN [favor, tome, .]
# por case favor NOUN []
# favor nmod Mhh PROPN [por, señora]
# señora amod favor NOUN []
# , punct tome VERB []
# tome acl Mhh PROPN [,, medicamente]
# su det medicamente NOUN []
# medicamente obj tome VERB [su]
# . punct Mhh PROPN []
# Mira ROOT Mira VERB [recomendados, .]
# que mark recomendados VERB []
# son aux recomendados VERB []
# recomendados ccomp Mira VERB [que, son, médico, morir]
# por case médico NOUN []
# el det médico NOUN []
# médico obj recomendados VERB [por, el]
# y cc morir VERB []
# si mark tomas VERB []
# no advmod tomas VERB []
# te iobj tomas VERB []
# los obj tomas VERB []
# tomas csubj morir VERB [si, no, te, los]
# te obj morir VERB []
# puedes aux morir VERB []
# morir conj recomendados VERB [y, tomas, te, puedes]
# . punct Mira VERB [
# ]
#
#   . PUNCT []
# Sí ROOT Sí ADV [.]
# . punct Sí ADV []
# Si mark vas VERB []
# me iobj vas VERB []
# vas ROOT vas VERB [Si, me, hacer, .]
# a mark hacer VERB []
# hacer xcomp vas VERB [a, favor]
# un det favor NOUN []
# favor obj hacer VERB [un, echar]
# , punct echar VERB []
# cómo obl echar VERB []
# me obj echar VERB [ ]
#    me PRON []
# vas aux echar VERB []
# a mark echar VERB []
# echar acl favor NOUN [,, cómo, me, vas, a, agua]
# al case agua NOUN []
# agua obj echar VERB [al]
# . punct vas VERB []
# Pues mark hay AUX []
# … nsubj hay AUX []
# no advmod hay AUX []
# hay advcl afecta VERB [Pues, …, no, razón, ...]
# razón obj hay AUX [hay]
# para mark hay AUX []
# que mark hay AUX []
# … nsubj hay AUX []
# no advmod hay AUX []
# hay acl razón NOUN [para, que, …, no, razón, tenía]
# razón obj hay AUX [prerjudiques]
# para mark … VERB []
# que mark … VERB []
# me obj … VERB []
# … advcl prerjudiques VERB [para, que, me]
# me obj prerjudiques VERB []
# prerjudiques acl razón NOUN […, me, así]
# así advmod prerjudiques VERB []
# , punct tenía VERB []
# si mark tenía VERB []
# , punct hiciste VERB []
# si mark hiciste VERB []
# me obj hiciste VERB []
# hiciste advcl tenía VERB [,, si, me, favor]
# el det favor NOUN []
# favor nsubj hiciste VERB [el]
# tenía advcl hay AUX [,, si, hiciste, hacelo]
# que mark hacelo VERB []
# hacelo ccomp tenía VERB [que, .., tenías, sé]
# .. obj hacelo VERB []
# Pues mark tenías NOUN []
# tenías obl hacelo VERB [Pues, hacerlo]
# que nsubj hacerlo VERB []
# hacerlo acl tenías NOUN [que, bien]
# bien advmod hacerlo VERB []
# , punct sé VERB []
# aunque mark sé VERB []
# sé advcl hacelo VERB [,, aunque, mal]
# que mark mal ADV []
# eso nsubj mal ADV []
# está cop mal ADV []
# mal ccomp sé VERB [que, eso, está, manera]
# pero cc manera NOUN []
# de case manera NOUN []
# igual amod manera NOUN []
# manera conj mal ADV [pero, de, igual]
# ... punct hay AUX []
# eso nsubj afecta VERB []
# me obj afecta VERB []
# afecta ROOT afecta VERB [hay, eso, me, demasiado, .]
# demasiado advmod afecta VERB []
# . punct afecta VERB [
# ]
#
#   . PUNCT []
# Que mark hacés VERB []
# por case qué PRON []
# qué obl hacés VERB [por]
# , punct hacés VERB []
# pues mark hacés VERB []
# por case qué PRON []
# qué obl hacés VERB [por]
# me obj hacés VERB []
# hacés ROOT hacés VERB [Que, qué, ,, pues, qué, me, eso, ?]
# eso obj hacés VERB []
# ? punct hacés VERB []
# Ya advmod ves VERB []
# ves ROOT ves VERB [Ya, finales, tengo, .]
# que mark finales NOUN []
# estoy cop finales NOUN []
# en case finales NOUN []
# finales ccomp ves VERB [que, estoy, en, …]
# y cc … NOUN []
# … conj finales NOUN [y]
# y cc tengo VERB []
# no advmod tengo VERB []
# tengo conj ves VERB [y, no, tiempo, pones]
# tiempo obj tengo VERB []
# y cc pones VERB []
# me obj pones VERB []
# pones conj tengo VERB [y, me, …, ir]
# a case … NOUN []
# … iobj pones VERB [a]
# a mark ir VERB []
# ir xcomp pones VERB [a, lado]
# hasta case lado NOUN []
# el det lado NOUN [otro]
# otro det el DET []
# lado obl ir VERB [hasta, el, campus]
# del case campus NOUN []
# campus nmod lado NOUN [del, temprano]
# y cc temprano ADV []
# bien advmod temprano ADV []
# temprano conj campus NOUN [y, bien]
# . punct ves VERB []
# Pues advmod toca VERB []
# y cc toca VERB []
# a case eso PRON [parte, de]
# parte fixed a ADP []
# de fixed a ADP []
# eso obl toca VERB [a]
# me obj toca VERB []
# toca ROOT toca VERB [Pues, y, eso, me, esperate, horas, .]
# esperate obj toca VERB []
# dos nummod horas NOUN []
# horas obl toca VERB [dos]
# . punct toca VERB []
# Vos nsubj sabé VERB []
# sabé ROOT sabé VERB [Vos, momento, ...]
# que mark momento NOUN []
# eso nsubj momento NOUN []
# es cop momento NOUN []
# un det momento NOUN []
# momento ccomp sabé VERB [que, eso, es, un, estudiando, preocupado]
# donde obl estudiando VERB []
# yo nsubj estudiando VERB []
# debería aux estudiando VERB []
# estar aux estudiando VERB []
# estudiando acl momento NOUN [donde, yo, debería, estar]
# y cc preocupado ADJ []
# usted nsubj preocupado ADJ []
# debería aux preocupado ADJ []
# estar aux preocupado ADJ []
# preocupado conj momento NOUN [y, usted, debería, estar, cosas]
# por case cosas NOUN []
# ... punct cosas NOUN []
# por case cosas NOUN []
# cosas obl preocupado ADJ [por, ..., por, el]
# como mark el DET []
# el nmod cosas NOUN [como]
# ... punct sabé VERB []
# el det final NOUN []
# final ROOT final NOUN [el, .]
# . punct final NOUN []
# Pues mark deberías NOUN []
# deberías ROOT deberías NOUN [Pues, tener, .]
# de mark tener VERB []
# tener acl deberías NOUN [de, consideración, deberías]
# más advmod consideración NOUN []
# consideración obj tener VERB [más, tiempo]
# con case tiempo NOUN []
# mi det tiempo NOUN []
# tiempo nmod consideración NOUN [con, mi]
# y cc deberías AUX []
# no advmod deberías AUX []
# deberías conj tener VERB [y, no, jugar]
# de mark jugar VERB []
# jugar acl deberías AUX [de, así]
# así advmod jugar VERB []
# . punct deberías NOUN [
# ]
#
#   . PUNCT []
# Hey ROOT Hey PROPN [señora, entrometido, .]
# señora flat Hey PROPN []
# , punct entrometido VERB []
# pues mark entrometido VERB []
# que mark entrometido VERB []
# pena nsubj entrometido VERB [contigo]
# contigo amod pena VERB []
# ser cop entrometido VERB []
# tan advmod entrometido VERB []
# entrometido advcl Hey PROPN [,, pues, que, pena, ser, tan, asuntos, notado]
# en case asuntos NOUN []
# tus det asuntos NOUN []
# asuntos obl entrometido VERB [en, tus]
# pero cc notado VERB []
# he aux notado VERB []
# notado conj entrometido VERB [pero, he, botado]
# que mark botado VERB []
# has aux botado VERB []
# botado ccomp notado VERB [que, has, pastillas, veces, bien]
# tus det pastillas NOUN []
# pastillas obj botado VERB [tus]
# varias det veces NOUN []
# veces obl botado VERB [varias]
# y cc bien ADV []
# pues mark bien ADV []
# la det verdad NOUN []
# verdad nsubj bien ADV [la]
# no advmod bien ADV []
# estás cop bien ADV []
# muy advmod bien ADV []
# bien conj botado VERB [y, pues, verdad, no, estás, muy, salud]
# de case salud NOUN []
# salud obl bien ADV [de]
# . punct Hey PROPN []
# Deberías nsubj botar VERB []
# replantear aux botar VERB []
# botar ROOT botar VERB [Deberías, replantear, pastillas, .]
# esas det pastillas NOUN []
# pastillas obj botar VERB [esas]
# . punct botar VERB []
# Eso ROOT Eso PRON […, mirá, .]
# … flat Eso PRON []
# pues mark mirá VERB []
# mirá acl Eso PRON [pues, bien]
# que mark bien ADV []
# eso nsubj bien ADV []
# es cop bien ADV []
# por case tu DET []
# tu det bien ADV [por]
# bien ccomp mirá VERB [que, eso, es, tu]
# . punct Eso PRON []
# Vos ROOT Vos PROPN [verás, todo, jugar, .]
# verás amod Vos PROPN []
# y cc todo PRON []
# todo conj Vos PROPN [y]
# , punct jugar VERB []
# pero cc jugar VERB []
# ... punct jugar VERB []
# pero cc jugar VERB []
# pues mark jugar VERB []
# con case salud NOUN []
# las det salud NOUN []
# salud obl jugar VERB [con, las]
# no advmod jugar VERB []
# se obj jugar VERB []
# puede aux jugar VERB []
# jugar conj Vos PROPN [,, pero, ..., pero, pues, salud, no, se, puede]
# . punct Vos PROPN []
# Deberías nsubj debería AUX [,]
# , punct Deberías PROPN []
# debería ROOT debería AUX [Deberías, tomartelas, en, .]
# de case tomartelas NOUN []
# tomartelas obj debería AUX [de]
# muy advmod en ADP []
# en advmod debería AUX [muy, serio]
# serio fixed en ADP []
# . punct debería AUX []
# Y advmod espero VERB []
# ... punct espero VERB []
# y advmod espero VERB []
# espero ROOT espero VERB [Y, ..., y, espero, .]
# , punct espero VERB []
# pues mark espero VERB []
# espero advcl espero VERB [,, pues, ver, porque, avisar]
# no advmod ver VERB []
# volvete aux ver VERB []
# a mark ver VERB []
# ver xcomp espero VERB [no, volvete, a]
# porque advmod espero VERB []
# , punct avisar VERB []
# porque mark avisar VERB []
# de advmod avisar VERB [lo, contrario]
# lo fixed de ADP []
# contrario fixed de ADP []
# voy aux avisar VERB []
# a mark avisar VERB []
# avisar advcl espero VERB [,, porque, de, voy, a, es]
# porque mark es AUX []
# es advcl avisar VERB [porque, es]
# que mark es AUX []
# es ccomp es AUX [que, jugar]
# jugar ccomp es AUX [salud]
# con case salud NOUN []
# tu det salud NOUN []
# salud obl jugar VERB [con, tu]
# . punct espero VERB [
# ]
#
#   . PUNCT []
# Esas det pastillas NOUN []
# pastillas nsubj salud NOUN [Esas]
# son cop salud NOUN []
# para case salud NOUN []
# tu det salud NOUN []
# salud ROOT salud NOUN [pastillas, son, para, tu, .]
# . punct salud NOUN []
# Espero ROOT Espero VERB [hagas, .]
# que mark hagas VERB []
# lo obj hagas VERB []
# hagas ccomp Espero VERB [que, lo, conciencia]
# a case conciencia NOUN []
# conciencia obl hagas VERB [a]
# . punct Espero VERB [
# ]
#
#   . PUNCT []
# Dime nsubj tienes NOUN []
# qué det fechas NOUN []
# fechas nsubj tienes NOUN [qué]
# tienes ROOT tienes NOUN [Dime, fechas, disponibles, .]
# disponibles obj tienes NOUN []
# . punct tienes NOUN []
# Haber aux coincidimos VERB []
# en case cuál PRON []
# cuál obl coincidimos VERB [en]
# coincidimos ROOT coincidimos VERB [Haber, cuál, .]
# . punct coincidimos VERB [
# ]
#
#   . PUNCT []
# Discúlpame nsubj tengo VERB [,]
# , punct Discúlpame PROPN []
# tengo ROOT tengo VERB [Discúlpame, cosas, cabeza, .]
# muchas det cosas NOUN []
# cosas obj tengo VERB [muchas]
# en case cabeza NOUN []
# la det cabeza NOUN []
# cabeza obl tengo VERB [en, la, entrenamiento]
# para case entrenamiento NOUN []
# este det entrenamiento NOUN []
# entrenamiento nmod cabeza NOUN [para, este]
# . punct tengo VERB []
# ¿ punct es AUX []
# Cómo obl es AUX []
# es ROOT es AUX [¿, Cómo, llamas, ?]
# que mark llamas VERB []
# te obj llamas VERB []
# llamas ccomp es AUX [que, te]
# ? punct es AUX [
# ]
#
#   ? PUNCT []
# Hola ROOT Hola PROPN [pasas]
# , punct pasas VERB []
# por case qué PRON []
# qué obl pasas VERB [por]
# no advmod pasas VERB []
# me obj pasas VERB []
# pasas acl Hola PROPN [,, qué, no, me, pelota, forma, .]
# la det pelota NOUN []
# pelota nsubj pasas VERB [la]
# en case forma NOUN []
# la det forma NOUN []
# siguiente amod forma NOUN []
# forma obl pasas VERB [en, la, siguiente, defendemos]
# para mark defendemos VERB []
# ver aux defendemos VERB []
# si mark defendemos VERB []
# nos obj defendemos VERB []
# defendemos acl forma NOUN [para, ver, si, nos]
# . punct pasas VERB [
# ]
#
#   . PUNCT []
# Hola ROOT Hola PROPN [recuerdas]
# , punct recuerdas VERB []
# me obj recuerdas VERB []
# recuerdas conj Hola PROPN [,, me, nombre, ?]
# cómo obl nombre NOUN []
# es cop nombre NOUN []
# tu det nombre NOUN []
# nombre ccomp recuerdas VERB [cómo, es, tu, olvidé]
# que nsubj olvidé VERB []
# lo obj olvidé VERB []
# olvidé acl nombre NOUN [que, lo]
# ? punct recuerdas VERB []
# Lo obj siento VERB []
# siento ROOT siento VERB [Lo, .]
# . punct siento VERB [
# ]
#
#   . PUNCT []
# Mami ROOT Mami PROPN [cambias, ?]
# , punct cambias NOUN []
# por case cambias NOUN []
# qué det cambias NOUN []
# cambias nmod Mami PROPN [,, por, qué, tanto]
# tanto advmod cambias NOUN []
# ? punct Mami PROPN []
# Sí ROOT Sí ADV [?]
# ? punct Sí ADV []
# Primero advmod tenía VERB []
# tenía ROOT tenía VERB [Primero, paciencia, quería, .]
# paciencia obj tenía VERB [esperabas]
# y cc esperabas NOUN []
# esperabas conj paciencia NOUN [y]
# y cc quería VERB []
# quería conj tenía VERB [y, conversábamos]
# que mark conversábamos VERB []
# conversábamos ccomp quería VERB [que]
# . punct tenía VERB [
# ]
#
#   . PUNCT []
# Nena ROOT Nena PROPN [,, ayúdame, .]
# , punct Nena PROPN []
# ayúdame conj Nena PROPN [arreglar]
# a mark arreglar VERB []
# arreglar xcomp ayúdame VERB [a, casa]
# la det casa NOUN []
# casa obj arreglar VERB [la]
# . punct Nena PROPN []
# Acuérdate ROOT Acuérdate VERB [ordenados, .]
# que mark ordenados ADJ []
# aquí advmod ordenados ADJ []
# son cop ordenados ADJ []
# muy advmod ordenados ADJ []
# ordenados ccomp Acuérdate VERB [que, aquí, son, muy, gusta]
# y cc gusta VERB []
# me obj gusta VERB []
# gusta conj ordenados ADJ [y, me, tener]
# tener csubj gusta VERB [todo, orden, vea]
# todo obj tener VERB []
# en case orden NOUN []
# orden obl tener VERB [en]
# y cc vea VERB []
# que nsubj vea VERB []
# se obj vea VERB []
# vea conj tener VERB [y, que, se, …]
# bien advmod buena ADJ []
# buena amod … NOUN [bien]
# … nsubj vea VERB [buena]
# . punct Acuérdate VERB [
#
# ]
#
#
#   . PUNCT []
# Cómo obl sigues VERB []
# sigues ROOT sigues VERB [Cómo, tratamiento, ?]
# con case tratamiento NOUN []
# tu det tratamiento NOUN []
# tratamiento obl sigues VERB [con, tu]
# ? punct sigues VERB []
# Te obj veo VERB []
# veo ROOT veo VERB [Te, bien, .]
# muy advmod bien ADV []
# bien advmod veo VERB [muy]
# . punct veo VERB [
# ]
#
#   . PUNCT []
# No advmod pá ADP []
# pá mark demorado VERB [No]
# , punct demorado VERB []
# por case culpa NOUN []
# tu det culpa NOUN []
# culpa obl demorado VERB [por, tu]
# me obj demorado VERB []
# he aux demorado VERB []
# demorado ROOT demorado VERB [pá, ,, culpa, me, he, buscando, pereza, .]
# más advmod buscando VERB []
# buscando advcl demorado VERB [más, mochila]
# mi det mochila NOUN []
# mochila obj buscando VERB [mi, …]
# … amod mochila NOUN []
# qué obj pereza NOUN []
# pereza obj demorado VERB [qué]
# . punct demorado VERB []
# Por advmod vuelvas VERB [favor, ,]
# favor fixed Por ADP []
# , punct Por ADP []
# no advmod vuelvas VERB []
# me iobj vuelvas VERB []
# vuelvas ROOT vuelvas VERB [Por, no, me, poner, .]
# a mark poner VERB []
# poner xcomp vuelvas VERB [a, ahí]
# ahí advmod poner VERB []
# . punct vuelvas VERB [
# ]
#
#   . PUNCT []
# Amigo ROOT Amigo PROPN [,, comiendo]
# , punct Amigo PROPN []
# te iobj acabo AUX []
# acabo aux ver VERB [te]
# de mark ver VERB []
# ver aux comiendo VERB [acabo, de, facebook]
# en case facebook NOUN []
# facebook obl ver VERB [en]
# comiendo acl Amigo PROPN [ver, sushi, .]
# sushi obj comiendo VERB []
# . punct comiendo VERB []
# Cuando mark pedí VERB []
# te obj pedí VERB []
# pedí advcl dijiste VERB [Cuando, te, dinero, ,]
# el det dinero NOUN []
# dinero obj pedí VERB [el]
# , punct pedí VERB []
# me iobj dijiste VERB []
# dijiste ROOT dijiste VERB [pedí, me, tenías, .]
# que mark tenías VERB []
# no advmod tenías VERB []
# lo obj tenías VERB []
# tenías ccomp dijiste VERB [que, no, lo]
# . punct dijiste VERB []
# ¿ punct qué PRON []
# Por case qué PRON []
# qué ROOT qué PRON [¿, Por, ?]
# ? punct qué PRON []
# Me obj parece AUX []
# parece cop falta NOUN [Me]
# una det falta NOUN []
# falta ROOT falta NOUN [parece, una, respeto, seas, .]
# de case respeto NOUN []
# respeto nmod falta NOUN [de]
# que mark seas NOUN []
# seas acl falta NOUN [que, capaz, dinero]
# capaz amod seas NOUN [pagarme]
# de case pagarme ADJ []
# pagarme nmod capaz ADJ [de]
# el det dinero NOUN []
# dinero obj seas NOUN [el, presté, gastes]
# que nsubj presté VERB []
# te obj presté VERB []
# presté acl dinero NOUN [que, te]
# y cc gastes VERB []
# te iobj gastes VERB []
# lo obj gastes VERB []
# gastes conj dinero NOUN [y, te, lo, cosas]
# en case cosas NOUN []
# otras det cosas NOUN []
# cosas obl gastes VERB [en, otras]
# . punct falta NOUN [
# ]
#
#   . PUNCT []
# Disculpa ROOT Disculpa PROPN [clara, .]
# pero cc clara ADJ []
# yo nsubj clara ADJ []
# fui cop clara ADJ []
# muy advmod clara ADJ []
# clara conj Disculpa PROPN [pero, yo, fui, muy, pedí]
# cuando mark pedí VERB []
# te obj pedí VERB []
# pedí advcl clara ADJ [cuando, te, plato]
# mi det plato NOUN []
# plato obj pedí VERB [mi, trajera]
# que nsubj trajera VERB []
# no advmod trajera VERB []
# trajera acl plato NOUN [que, no, berenjena, alérgica]
# berenjena obj trajera VERB []
# porque mark alérgica ADJ []
# soy cop alérgica ADJ []
# alérgica advcl trajera VERB [porque, soy]
# . punct Disculpa PROPN []
# ¿ punct cambiar VERB []
# Entonces advmod cambiar VERB []
# me obj cambiar VERB []
# puedes aux cambiar VERB []
# cambiar ROOT cambiar VERB [¿, Entonces, me, puedes, plato, favor, ?]
# el det plato NOUN []
# plato nsubj cambiar VERB [el]
# por case favor NOUN []
# favor obl cambiar VERB [por]
# ? punct cambiar VERB [ ]
#    ? PUNCT []
# porque mark comer VERB []
# no advmod comer VERB []
# lo obj comer VERB []
# puedo aux comer VERB []
# comer ROOT comer VERB [porque, no, lo, puedo, .]
# . punct comer VERB [
# ]
#
#   . PUNCT []
# La det verdad NOUN []
# verdad nsubj gustó VERB [La]
# no advmod gustó VERB []
# me obj gustó VERB []
# gustó ROOT gustó VERB [verdad, no, me, gritaste, .]
# cómo obl gritaste VERB []
# le obj gritaste VERB []
# gritaste ccomp gustó VERB [cómo, le, perrro, día]
# a case perrro NOUN []
# mi det perrro NOUN []
# perrro obj gritaste VERB [a, mi]
# aquel det día NOUN []
# día obl gritaste VERB [aquel, vino]
# que nsubj vino VERB []
# vino acl día NOUN [que, amigo]
# tu det amigo NOUN []
# amigo nsubj vino VERB [tu]
# . punct gustó VERB []
# Por advmod vuelvas PRON [favor]
# favor fixed Por ADP []
# no advmod vuelvas PRON []
# lo det vuelvas PRON []
# vuelvas ROOT vuelvas PRON [Por, no, lo, molestó, .]
# a mark molestó VERB []
# hacer aux molestó VERB []
# que mark molestó VERB []
# la det verdad NOUN []
# verdad nsubj molestó VERB [la]
# me obj molestó VERB []
# molestó acl vuelvas PRON [a, hacer, que, verdad, me, demasiado]
# demasiado advmod molestó VERB []
# . punct vuelvas PRON [
#
# ]
#
#
#   . PUNCT []
# Papi nsubj retrasas VERB [favor, eso, ,]
# por case favor NOUN []
# favor nmod Papi PROPN [por, hagas]
# hagas flat favor NOUN []
# eso obj Papi PROPN []
# , punct Papi PROPN []
# me obj retrasas VERB []
# retrasas ROOT retrasas VERB [Papi, me, .]
# . punct retrasas VERB [
#
# ]
#
#
#   . PUNCT []
# ¿ punct pagas VERB []
# Por case qué PRON []
# qué obl pagas VERB [Por]
# no advmod pagas VERB []
# me obj pagas VERB []
# pagas ROOT pagas VERB [¿, qué, no, me, dinero, ?]
# mi det dinero NOUN []
# dinero nsubj pagas VERB [mi]
# ? punct pagas VERB [
# ]
#
#   ? PUNCT []
# Debes aux prestar VERB []
# prestar ROOT prestar VERB [Debes, atención, dije, .]
# más advmod atención NOUN []
# atención obj prestar VERB [más]
# a mark dije VERB []
# lo det dije VERB []
# que nsubj dije VERB []
# te obj dije VERB []
# dije ccomp prestar VERB [a, lo, que, te]
# . punct prestar VERB []
# Me obj hace VERB []
# hace ROOT hace VERB [Me, daño, .]
# daño obj hace VERB []
# . punct hace VERB [
# ]
#
#   . PUNCT []
# Por case favor NOUN []
# favor ROOT favor NOUN [Por, colabórame, .]
# colabórame amod favor NOUN []
# . punct favor NOUN [
# ]
#
#   . PUNCT []
# Cambiemos ROOT Cambiemos PROPN [género, .]
# de case género NOUN []
# género flat Cambiemos PROPN [de]
# . punct Cambiemos PROPN []
# La det gente NOUN []
# gente nsubj gustando VERB [La]
# no advmod gustando VERB []
# le obj gustando VERB []
# está aux gustando VERB []
# gustando ROOT gustando VERB [gente, no, le, está, .]
# . punct gustando VERB []
# Pon ROOT Pon ADV [esta, especial, .]
# esta obj Pon ADV []
# en case especial ADJ [ ]
#    en ADP []
# especial obl Pon ADV [en]
# . punct Pon ADV [
#
# ]
#
#
#   . PUNCT []
# Sabes ROOT Sabes VERB [trabajo, .]
# el det trabajo NOUN []
# trabajo obj Sabes VERB [el, tengo]
# que obj tengo VERB []
# tengo acl trabajo NOUN [que, padre]
# padre obj tengo VERB []
# . punct Sabes VERB [
# ]
#
#   . PUNCT []
# ¿ punct quieres NOUN []
# Qué det quieres NOUN []
# quieres nsubj Será AUX [¿, Qué, hagamos, ?, ¿]
# que obj hagamos VERB []
# hagamos acl quieres NOUN [que]
# ? punct quieres NOUN [
# ]
#
#   ? PUNCT []
# ¿ punct quieres NOUN []
# Será ROOT Será AUX [quieres, tienes, ?]
# que mark tienes VERB []
# ya advmod tienes VERB []
# tienes ccomp Será AUX [que, ya, dinero]
# el det dinero NOUN []
# dinero obj tienes VERB [el]
# ? punct Será AUX []
# Es ROOT Es AUX [urge, .]
# que mark urge AUX []
# en advmod urge AUX [verdad]
# verdad fixed en ADP []
# me obj urge AUX []
# urge ccomp Es AUX [que, en, me, tener]
# tener csubj urge AUX [dinero]
# el det dinero NOUN []
# dinero obj tener VERB [el]
# . punct Es AUX [
# ]
#
#   . PUNCT []
# Hola ROOT Hola PROPN [pena, será, ?]
# qué det pena NOUN []
# pena obj Hola PROPN [qué, contigo]
# contigo amod pena NOUN []
# , punct será AUX []
# ¿ punct será AUX []
# pero cc será AUX []
# será conj Hola PROPN [,, ¿, pero, podrías]
# que mark podrías VERB []
# me iobj podrías VERB []
# podrías ccomp será AUX [que, me, cambiar]
# cambiar xcomp podrías VERB [plato, favor]
# este det plato NOUN []
# plato obj cambiar VERB [este]
# por case favor NOUN []
# favor obl cambiar VERB [por]
# ? punct Hola PROPN []
# Porque mark dije VERB []
# te iobj dije VERB []
# dije advcl hay AUX [Porque, te, comer]
# que mark comer VERB []
# no advmod comer VERB []
# podía aux comer VERB []
# comer xcomp dije VERB [que, no, podía, berenjena, sin]
# berenjena obj comer VERB []
# sin advmod comer VERB [embargo]
# embargo fixed sin ADP []
# aquí advmod hay AUX []
# hay ROOT hay AUX [dije, aquí, pedazo, .]
# un det pedazo NOUN []
# pedazo obj hay AUX [un, berenjena]
# de case berenjena NOUN []
# berenjena nmod pedazo NOUN [de]
# . punct hay AUX [
# ]
#
#   . PUNCT []
# Pa ROOT Pa PROPN [,, porfis]
# , punct Pa PROPN []
# hacéme nsubj porfis PROPN []
# porfis appos Pa PROPN [hacéme, favor, .]
# un det favor NOUN []
# favor obj porfis PROPN [un]
# . punct porfis PROPN []
# Pues mark es AUX []
# es advcl están AUX [Pues, mira, ,]
# que mark mira VERB []
# mira ccomp es AUX [que]
# , punct es AUX []
# las det cajas NOUN []
# cajas nsubj están AUX [las]
# están cop desorganizadas NOUN [es, cajas]
# súper aux desorganizadas NOUN []
# desorganizadas ROOT desorganizadas NOUN [están, súper, ayudando, .]
# y cc ayudando VERB []
# no advmod ayudando VERB []
# me obj ayudando VERB []
# estás aux ayudando VERB []
# ayudando conj desorganizadas NOUN [y, no, me, estás, casi]
# casi advmod ayudando VERB []
# . punct desorganizadas NOUN [
# ]
#
#   . PUNCT []
# Mira nsubj es AUX []
# es ROOT es AUX [Mira, gustó, .]
# que mark gustó VERB []
# no advmod gustó VERB []
# me obj gustó VERB []
# gustó ccomp es AUX [que, no, me, manera, gustaría]
# la det manera NOUN []
# manera obj gustó VERB [la, trataste]
# en case que PRON []
# que obl trataste VERB [en]
# trataste acl manera NOUN [que, perro, día]
# a case perro NOUN []
# mi det perro NOUN []
# perro obl trataste VERB [a, mi]
# ese det día NOUN []
# día obl trataste VERB [ese, vino]
# que obl vino VERB []
# vino acl día NOUN [que, amigo]
# tu det amigo NOUN []
# amigo nsubj vino VERB [tu]
# y cc gustaría VERB []
# la det verdad NOUN []
# verdad nsubj gustaría VERB [la]
# me obj gustaría VERB []
# gustaría conj gustó VERB [y, verdad, me, trataras]
# que mark trataras VERB []
# lo det trataras VERB []
# trataras csubj gustaría VERB [que, lo, mejor, lindo]
# mejor amod trataras VERB []
# porque mark lindo VERB []
# es cop lindo VERB []
# muy advmod lindo VERB []
# lindo advcl trataras VERB [porque, es, muy, contigo]
# contigo obj lindo VERB []
# . punct es AUX [
# ]
#
#   . PUNCT []
# ¿ punct pasa VERB []
# Qué obj pasa VERB []
# pasa ROOT pasa VERB [¿, Qué, contigo, ?]
# contigo nsubj pasa VERB []
# ? punct pasa VERB []
# ¿ punct poniendo VERB []
# Por case qué PRON []
# qué obl poniendo VERB [Por]
# estás aux poniendo VERB []
# poniendo ROOT poniendo VERB [¿, qué, estás, canciones, ?]
# las det canciones NOUN []
# canciones obj poniendo VERB [las, malucas]
# tan advmod malucas ADJ []
# malucas amod canciones NOUN [tan]
# ? punct poniendo VERB [
# ]
#
#   ? PUNCT []
# La det verdad NOUN []
# verdad nsubj es AUX [La]
# es ROOT es AUX [verdad, hablado, .]
# que mark hablado VERB []
# ya advmod hablado VERB []
# he aux hablado VERB []
# hablado ccomp es AUX [que, ya, he, mí]
# tanto cc mí PRON []
# de case mí PRON []
# mí obl hablado VERB [tanto, de]
# . punct es AUX []
# Cuéntame ROOT Cuéntame PROPN [tú, .]
# tú flat Cuéntame PROPN []
# . punct Cuéntame PROPN []
# ¿ punct gustaría VERB []
# Qué nsubj gustaría VERB []
# te obj gustaría VERB []
# gustaría ROOT gustaría VERB [¿, Qué, te, hacer, ?, ¿, conoces, ?]
# hacer csubj gustaría VERB [cumpleaños]
# para case cumpleaños NOUN []
# tu det cumpleaños NOUN []
# cumpleaños obl hacer VERB [para, tu]
# ? punct gustaría VERB [
# ]
#
#   ? PUNCT []
# ¿ punct gustaría VERB []
# Y advmod conoces ADJ []
# tú nsubj conoces ADJ []
# conoces conj gustaría VERB [Y, tú, novio]
# al case novio NOUN []
# novio obj conoces ADJ [al, novia]
# o cc novia NOUN []
# la det novia NOUN []
# novia conj novio NOUN [o, la]
# ? punct gustaría VERB [
# ]
#
#   ? PUNCT []
# No advmod vuelvas VERB []
# le iobj vuelvas VERB []
# vuelvas ROOT vuelvas VERB [No, le, gritar, .]
# a mark gritar VERB []
# gritar xcomp vuelvas VERB [a, perro]
# al case perro NOUN []
# perro obj gritar VERB [al]
# . punct vuelvas VERB [
# ]
#
#   . PUNCT []
# ¿ punct poner VERB []
# Puedes aux poner VERB []
# poner ROOT poner VERB [¿, Puedes, canciones, ?]
# otras det canciones NOUN []
# canciones obj poner VERB [otras]
# ? punct poner VERB []
# Es ROOT Es AUX [maluquitas, .]
# que mark maluquitas NOUN []
# estas nsubj maluquitas NOUN []
# están cop maluquitas NOUN []
# como mark maluquitas NOUN []
# ...
# regañona obj volviendo VERB [muy, cansona]
# y cc cansona PROPN []
# cansona conj regañona ADJ [y]
# . punct es AUX []
# Entonces advmod nooo PROPN []
# nooo nsubj bájele VERB [Entonces, ,]
# , punct nooo PROPN []
# bájele ROOT bájele VERB [nooo, poquito, tono, .]
# un det poquito ADJ []
# poquito obj bájele VERB [un]
# el det tono NOUN []
# tono obj bájele VERB [el, mami]
# mami amod tono NOUN []
# . punct bájele VERB [
# ]
#
#   . PUNCT []
# Vea nsubj tengo VERB [amigo]
# amigo flat Vea PROPN []
# , punct es AUX []
# si mark es AUX []
# de advmod es AUX [pronto]
# pronto fixed de ADP []
# es advcl tengo VERB [,, si, de, gustan, ,]
# que mark gustan VERB []
# a case ti PRON []
# ti obj gustan VERB [a]
# no advmod gustan VERB []
# te obj gustan VERB []
# gustan ccomp es AUX [que, ti, no, te, perros]
# los det perros NOUN []
# perros nsubj gustan VERB [los]
# , punct es AUX []
# dale nsubj tengo VERB [yo]
# yo flat dale VERB []
# no advmod tengo VERB []
# tengo ROOT tengo VERB [Vea, es, dale, no, problema, .]
# ningun amod problema NOUN []
# problema obj tengo VERB [ningun]
# . punct tengo VERB []
# Cuando mark vengas VERB []
# tú nsubj vengas VERB []
# vengas advcl guardo VERB [Cuando, tú, ,]
# , punct vengas VERB []
# entonces advmod guardo VERB []
# yo nsubj guardo VERB []
# guardo ROOT guardo VERB [vengas, entonces, yo, perro, lugar, moleste, .]
# mi det perro NOUN []
# perro obj guardo VERB [mi]
# en case lugar NOUN []
# otro det lugar NOUN []
# lugar obl guardo VERB [en, otro]
# para mark moleste VERB []
# que mark moleste VERB []
# no advmod moleste VERB []
# te obj moleste VERB []
# moleste advcl guardo VERB [para, que, no, te, gusta]
# pero cc gusta VERB []
# tampoco advmod gusta VERB []
# me obj gusta VERB []
# gusta conj moleste VERB [pero, tampoco, me, desprecies]
# que mark desprecies VERB []
# lo obj desprecies VERB []
# desprecies csubj gusta VERB [que, lo]
# . punct guardo VERB [
# ]
#
#   . PUNCT []
# Ay nsubj será AUX [hola]
# hola flat Ay PROPN []
# , punct será AUX []
# ¿ punct será AUX []
# será ROOT será AUX [Ay, ,, ¿, ayudar, ?]
# que mark ayudar VERB []
# tú nsubj ayudar VERB []
# me obj ayudar VERB []
# puedes aux ayudar VERB []
# ayudar ccomp será AUX [que, tú, me, puedes, poquito, papeles, yo, timbrar]
# un det poquito ADJ []
# poquito obj ayudar VERB [un]
# con case papeles NOUN []
# estos det papeles NOUN []
# papeles obl ayudar VERB [con, estos]
# para case yo PRON []
# yo obl ayudar VERB [para]
# poder aux timbrar VERB []
# timbrar xcomp ayudar VERB [poder, piso]
# en case piso NOUN []
# el det piso NOUN []
# tercer amod piso NOUN []
# piso obl timbrar VERB [en, el, tercer]
# ? punct será AUX []
# ¿ punct pinchar VERB []
# O advmod pinchar VERB []
# tú nsubj pinchar VERB []
# me obj pinchar VERB []
# puedes aux pinchar VERB []
# pinchar ROOT pinchar VERB [¿, O, tú, me, puedes, piso, sí, ?]
# el det piso NOUN []
# tercer amod piso NOUN []
# piso obj pinchar VERB [el, tercer]
# sí advmod pinchar VERB []
# ? punct pinchar VERB []
# Por ROOT Por ADP [favor, ,, gracias, .]
# favor fixed Por ADP []
# , punct Por ADP []
# gracias fixed Por ADP []
# . punct Por ADP [
# ]
#
#   . PUNCT []
# Bueno ROOT Bueno ADJ [tú]
# ¿ punct tú PRON []
# tú obj Bueno ADJ [¿, quieres, ?]
# que mark quieres NOUN []
# quieres conj tú PRON [que]
# ? punct tú PRON []
# ¿ punct aliviarte VERB []
# aliviarte ROOT aliviarte VERB [¿, regular, molesten, ?]
# estar aux regular ADJ []
# regular csubj aliviarte VERB [estar, salud]
# de case salud NOUN []
# salud obl regular ADJ [de]
# , punct molesten VERB []
# que mark molesten VERB []
# esos det achaques NOUN []
# achaques nsubj molesten VERB [esos, tienes]
# que obj tienes VERB []
# tienes acl achaques NOUN [que]
# te obj molesten VERB []
# molesten advcl aliviarte VERB [,, que, achaques, te, día, momento, tener]
# todo det el DET []
# el det día NOUN [todo]
# día obl molesten VERB [el]
# en case momento NOUN []
# todo det el DET []
# el det momento NOUN [todo]
# momento obl molesten VERB [en, el]
# o cc tener VERB []
# tener conj molesten VERB [o, de, calidad]
# de advmod tener VERB [pronto]
# pronto fixed de ADP []
# una det calidad NOUN []
# mejor amod calidad NOUN []
# calidad obj tener VERB [una, mejor, vida]
# de case vida NOUN []
# vida nmod calidad NOUN [de]
# ? punct aliviarte VERB []
# Si mark quieres VERB []
# quieres ROOT quieres VERB [Si, calidad, .]
# una det calidad NOUN []
# mejor amod calidad NOUN []
# calidad obj quieres VERB [una, mejor, vida, debes]
# de case vida NOUN []
# vida nmod calidad NOUN [de]
# , punct debes NOUN []
# debes appos calidad NOUN [,, tomarte, pastillas]
# de case tomarte NOUN []
# tomarte nmod debes NOUN [de]
# las det pastillas NOUN []
# pastillas obj debes NOUN [las]
# . punct quieres VERB []
# Tómalelas ROOT Tómalelas NOUN [tranquilidad, verá, .]
# con case tranquilidad NOUN []
# tranquilidad nmod Tómalelas NOUN [con]
# y cc verá VERB []
# verá conj Tómalelas NOUN [y, que]
# que obj verá VERB []
# . punct Tómalelas NOUN []
# Todos det los DET []
# los det días NOUN [Todos]
# días obl aceptar AUX [los]
# vas aux aceptar AUX []
# a mark aceptar AUX []
# aceptar ROOT aceptar AUX [días, vas, a, es, .]
# que mark es AUX []
# eso nsubj es AUX []
# es ccomp aceptar AUX [que, eso, tienes]
# lo det tienes VERB []
# que obj hacer VERB []
# tienes ccomp es AUX [lo, hacer]
# que cc hacer VERB []
# hacer conj tienes VERB [que, que, mejorarte]
# para case mejorarte VERB []
# mejorarte obl hacer VERB [para, salud]
# de case salud NOUN []
# salud nmod mejorarte VERB [de]
# . punct aceptar AUX []
# Ok dep voy AUX [,]
# , punct Ok PROPN []
# yo nsubj voy AUX []
# todos det los DET []
# los det días NOUN [todos]
# días obl voy AUX [los]
# voy ROOT voy AUX [Ok, yo, días, estimularte, hagas, .]
# a case estimularte NOUN []
# estimularte obl voy AUX [a]
# para mark hagas VERB []
# que mark hagas VERB []
# lo obj hagas VERB []
# hagas advcl voy AUX [para, que, lo]
# . punct voy AUX [
# ]
#
#   . PUNCT []
# Hey ROOT Hey PROPN [DJ, ,, quiero]
# DJ flat Hey PROPN []
# , punct Hey PROPN []
# yo nsubj quiero VERB []
# quiero acl Hey PROPN [yo, canción, ,, .]
# esa det canción NOUN []
# canción obj quiero VERB [esa, encanta]
# que nsubj encanta VERB []
# me obj encanta VERB []
# encanta acl canción NOUN [que, me]
# , punct quiero VERB []
# . punct quiero VERB []
# Ay advmod cámbiale VERB []
# hermano nsubj cámbiale VERB []
# cámbiale ROOT cámbiale VERB [Ay, hermano, poquito, música, acabar, .]
# un det poquito ADJ []
# poquito obj cámbiale VERB [un]
# esa det música NOUN []
# música obj cámbiale VERB [esa, desanimados]
# que nsubj desanimados ADJ []
# estamos cop desanimados ADJ []
# como mark desanimados ADJ []
# desanimados acl música NOUN [que, estamos, como]
# y cc acabar VERB []
# la det fiesta NOUN []
# fiesta nsubj acabar VERB [la]
# se obj acabar VERB []
# va aux acabar VERB []
# a mark acabar VERB []
# acabar conj cámbiale VERB [y, fiesta, se, va, a]
# . punct cámbiale VERB []
# No advmod dale VERB [,]
# , punct No ADV []
# dale ROOT dale VERB [No, .]
# . punct dale VERB []
# Cambia ROOT Cambia VERB [música, .]
# la det música NOUN []
# música nsubj Cambia VERB [la]
# . punct Cambia VERB []
# Yo nsubj quiero VERB []
# quiero ROOT quiero VERB [Yo, pongas, .]
# que mark pongas VERB []
# me obj pongas VERB []
# pongas ccomp quiero VERB [que, me, canción]
# una det canción NOUN []
# canción nsubj pongas VERB [una, _]
# por case _ PROPN [ejemplo]
# ejemplo fixed por ADP []
# _ nmod canción NOUN [por, _, _, _, _, _, _, _, _]
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# _ flat _ PROPN []
# . punct quiero VERB []
# Para mark enrumbemos VERB []
# que mark enrumbemos VERB []
# nos obj enrumbemos VERB []
# enrumbemos advcl pásame VERB [Para, que, nos,
# , Hey]
#
#   enrumbemos VERB []
# Hey nsubj enrumbemos VERB []
# pásame ROOT pásame VERB [enrumbemos, pelota, .]
# pues mark pelota NOUN []
# la det pelota NOUN []
# pelota obj pásame VERB [pues, la, equipo]
# que obj equipo NOUN []
# yo nsubj equipo NOUN []
# también advmod equipo NOUN []
# estoy cop equipo NOUN []
# en case equipo NOUN []
# el det equipo NOUN []
# equipo acl pelota NOUN [que, yo, también, estoy, en, el]
# . punct pásame VERB []
# Pásamela ROOT Pásamela PROPN [.]
# . punct Pásamela PROPN [
# ]
#
#   . PUNCT []
# Ay nsubj papá VERB []
# papá ROOT papá VERB [Ay, rico, .]
# qué det rico ADJ []
# rico obj papá VERB [qué, imagináte]
# , punct imagináte NOUN []
# imagináte amod rico ADJ [,, quiero]
# que nsubj quiero VERB []
# quiero acl imagináte NOUN [que,  , hacer]
#    quiero VERB []
# hacer xcomp quiero VERB [árbol]
# el det árbol NOUN []
# árbol obj hacer VERB [el, genealógicao, familia]
# genealógicao amod árbol NOUN []
# de case familia NOUN []
# la det familia NOUN []
# familia nmod árbol NOUN [de, la]
# . punct papá VERB []
# Y advmod sé VERB []
# yo nsubj sé VERB []
# sé ROOT sé VERB [Y, yo, tiene, .]
# que mark tiene VERB []
# usted nsubj tiene VERB []
# tiene ccomp sé VERB [que, usted, memoria]
# una det memoria NOUN []
# memoria obj tiene VERB [una, espectactular]
# espectactular amod memoria NOUN []
# . punct sé VERB []
# Por case ahí ADV []
# ahí advmod cuentas VERB [Por]
# derecho nsubj cuentas VERB []
# me obj cuentas VERB []
# cuentas ROOT cuentas VERB [ahí, derecho, me, historias, Quiero, .]
# historias obj cuentas VERB []
# Quiero nsubj cuentas VERB [tatarabuelos]
# saeber aux tatarabuelos NOUN []
# como mark quíenes NOUN []
# todo det quíenes NOUN []
# quíenes nsubj tatarabuelos NOUN [como, todo]
# eran cop tatarabuelos NOUN []
# mis det tatarabuelos NOUN []
# tatarabuelos ccomp Quiero VERB [saeber, quíenes, eran, mis, abuelos]
# , punct abuelos NOUN []
# abuelos appos tatarabuelos NOUN [,]
# . punct cuentas VERB []
# Para mark hacer VERB []
# poder aux hacer VERB []
# hacer advcl cuentas VERB [Para, poder, tus, de]
# la det tus NOUN []
# tus obj hacer VERB [la]
# de advmod hacer VERB [hecho]
# hecho fixed de ADP []
# me obj cuentas VERB []
# cuentas ROOT cuentas VERB [hacer, me, historias, .]
# tus det historias NOUN []
# historias obj cuentas VERB [tus, fascinantes, tienes]
# fascinantes amod historias NOUN []
# que obj tienes VERB []
# tienes acl historias NOUN [que]
# . punct cuentas VERB [
# ]
#
#   . PUNCT []
# Ay nsubj acuerda VERB [mami]
# mami flat Ay PROPN []
# ¿ punct acuerda VERB []
# se obj acuerda VERB []
# acuerda ROOT acuerda VERB [Ay, ¿, se, galletas, ?]
# de case galletas NOUN []
# las det galletas NOUN []
# galletas obj acuerda VERB [de, las, hicimos]
# que obj hicimos VERB []
# hicimos acl galletas NOUN [que, año, diciembre]
# el det año NOUN []
# año obl hicimos VERB [el, pasado]
# pasado amod año NOUN []
# en case diciembre NOUN []
# diciembre obl hicimos VERB [en]
# ? punct acuerda VERB []
# Ay obj dame VERB []
# dame ROOT dame VERB [Ay, receta, .]
# la det receta NOUN []
# receta nsubj dame VERB [la, hacer]
# , punct hacer VERB []
# que obj hacer VERB []
# estas det quieres NOUN []
# quieres nsubj hacer VERB [estas]
# hacer acl receta NOUN [,, que, quieres, galletas]
# de case galletas NOUN []
# esas det galletas NOUN []
# galletas obj hacer VERB [de, esas]
# . punct dame VERB [
# ]
#
#   . PUNCT []
# Ay obj hablado VERB []
# qué det pena NOUN []
# pena obj hablado VERB [qué, contigo, ,]
# contigo amod pena NOUN []
# , punct pena NOUN []
# he aux hablado VERB []
# hablado ROOT hablado VERB [Ay, pena, he, tiempo, .]
# todo det el DET []
# el det tiempo NOUN [todo]
# tiempo obj hablado VERB [el]
# . punct hablado VERB []
# No advmod hablar VERB []
# te obj hablar VERB []
# he aux hablar VERB []
# dejado aux hablar VERB []
# hablar ROOT hablar VERB [No, te, he, dejado, ti, .]
# a case ti PRON []
# ti obj hablar VERB [a]
# . punct hablar VERB []
# ¿ punct gustaría VERB []
# Y advmod gustaría VERB []
# qué nsubj gustaría VERB []
# te obj gustaría VERB []
# gustaría ROOT gustaría VERB [¿, Y, qué, te, hacer, ?]
# hacer csubj gustaría VERB [ti, día]
# a case ti PRON []
# ti obj hacer VERB [a]
# en case día NOUN []
# el det día NOUN []
# día obl hacer VERB [en, el, cumpleaños]
# de case cumpleaños NOUN []
# tu det cumpleaños NOUN []
# cumpleaños nmod día NOUN [de, tu]
# ? punct gustaría VERB [
# ]
#
#   ? PUNCT []
# Bueno ROOT Bueno ADJ [querida, qué]
# querida flat Bueno ADJ []
# , punct qué PRON []
# ¿ punct qué PRON []
# entonces advmod qué PRON []
# qué conj Bueno ADJ [,, ¿, entonces, ?]
# ? punct qué PRON []
# Nos obj tocar AUX []
# vuelve aux tocar AUX []
# a mark tocar AUX []
# tocar ROOT tocar AUX [Nos, vuelve, a, trabajar, .]
# trabajar csubj tocar AUX [juntas]
# juntas obj trabajar VERB []
# . punct tocar AUX []
# Entonces advmod dime VERB []
# dime ROOT dime VERB [Entonces, hacemos, .]
# cómo obl hacemos VERB []
# hacemos csubj dime VERB [cómo]
# . punct dime VERB []
# ¿ punct hago VERB []
# Yo nsubj hago VERB []
# hago ROOT hago VERB [¿, Yo, parte, tu, ..., partes, compartimos, ?]
# una det parte NOUN []
# parte obj hago VERB [una]
# y cc tu DET []
# luego advmod tu DET []
# tu conj hago VERB [y, luego, reunimos]
# y cc reunimos VERB []
# nos obj reunimos VERB []
# reunimos conj tu DET [y, nos]
# ... punct hago VERB []
# las det partes NOUN [dos]
# dos nummod las DET []
# partes obj hago VERB [las]
# y cc compartimos VERB []
# lo obj compartimos VERB []
# compartimos conj hago VERB [y, lo]
# ? punct hago VERB []
# ¿ punct encontramos VERB []
# O advmod encontramos VERB []
# nos obj encontramos VERB []
# encontramos ROOT encontramos VERB [¿, O, nos, trabajamos, ?]
# y cc trabajamos VERB []
# trabajamos conj encontramos VERB [y,  , a]
#    trabajamos VERB []
# a advmod trabajamos VERB [la, vez]
# la fixed a ADP []
# vez fixed a ADP []
# ? punct encontramos VERB []
# Dime ROOT Dime PROPN [hacemos, .]
# cómo obl hacemos VERB []
# hacemos csubj Dime PROPN [cómo]
# . punct Dime PROPN []
# ¿ punct propones NOUN []
# Qué det propones NOUN []
# propones ROOT propones NOUN [¿, Qué, tú, ?]
# tú nsubj propones NOUN []
# ? punct propones NOUN [
# ]
#
#   ? PUNCT []
# Hágame ROOT Hágame PROPN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-b9a8d59b2926> in <module>
#       1 for token in doc1:
#       2     print(token.text, token.dep_, token.head.text, token.head.pos_,
# ----> 3           [child for child in token.children])
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#      39
#      40     def write(self, text):
# ---> 41         self.__convertor.write(text)
#      42
#      43     def isatty(self):
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#     160     def write(self, text):
#     161         if self.strip or self.convert:
# --> 162             self.write_and_convert(text)
#     163         else:
#     164             self.wrapped.write(text)
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_and_convert(self, text)
#     188             self.convert_ansi(*match.groups())
#     189             cursor = end
# --> 190         self.write_plain_text(text, cursor, len(text))
#     191
#     192
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_plain_text(self, text, start, end)
#     193     def write_plain_text(self, text, start, end):
#     194         if start < end:
# --> 195             self.wrapped.write(text[start:end])
#     196             self.wrapped.flush()
#     197
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# As specified in the code, each line represents one token. The token is printed in the first column, followed by the dependency relation to it from the token in the third column, followed by its main category type.

# %% [markdown]
# ### Named Entity Recognition

# %% [markdown]
# Similarly to PoS-tags and Dependency Parse Relations, we can print out Named Entity labels:

# %%
for ent in doc1.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# ﻿Má 0 3 MISC
# Qué 91 94 PER
# Ma 111 113 PER
# Soy 368 371 PER
# La verdad 615 624 MISC
# Ma 698 700 PER
# Hola 902 906 PER
# He 1102 1104 PER
# Madre 1169 1174 PER
# Ten más cuidado 1212 1227 MISC
# Madre 1229 1234 ORG
# Madre 1379 1384 PER
# Oye 1659 1662 PER
# Todos queremos ver.
#  1702 1722 MISC
# Ma qué pasó? 1723 1735 MISC
# Te 1737 1739 MISC
# Hey 1804 1807 MISC
# Mami 1844 1848 ORG
# Será 1929 1933 MISC
# Hola 1974 1978 PER
# No puedes hacer eso. 2085 2105 MISC
# Si te ven 2106 2115 MISC
# Además 2135 2141 LOC
# No te las están 2159 2174 MISC
# Ay 2207 2209 MISC
# Será 2230 2234 MISC
# Vamos 2287 2292 LOC
# Mamá 2302 2306 PER
# Será 2343 2347 MISC
# Debemos 2378 2385 MISC
# Mira 2419 2423 LOC
# Por qué eres 2451 2463 MISC
# Por qué no me hablaste 2482 2504 MISC
# Eso no es correcto 2561 2579 MISC
# Mamá qué te 2625 2636 PER
# misma?Cuéntame 2702 2716 ORG
# Tienes algún problema 2719 2740 PER
# Mira 2782 2786 LOC
# Entonces colabórame 2836 2855 MISC
# Ayúdame 2857 2864 MISC
# … 2954 2955 LOC
# No finja delante de mí 3017 3039 MISC
# Pero dímelo con sinceridad 3224 3250 MISC
# Mamá 3252 3256 PER
# Eh profe 3394 3402 MISC
# Mami 3569 3573 ORG
# Mhh 3699 3702 MISC
# Mira 3742 3746 LOC
# Pues… 3882 3887 LOC
# … 3909 3910 PER
# me… me prerjudiques así 3933 3956 MISC
# Pues tenías 4004 4015 MISC
# Que por qué 4110 4121 MISC
# qué me hacés 4132 4144 PER
# … y no tengo tiempo y me pones a… 4179 4212 MISC
# Pues y a parte de eso me toca 4265 4294 MISC
# Vos sabé 4315 4323 MISC
# Pues deberías 4451 4464 MISC
# Hey señora 4534 4544 MISC
# Deberías 4705 4713 PER
# Eso… 4747 4751 MISC
# Vos verás 4786 4795 MISC
# Deberías 4855 4863 PER
# Esas pastillas 5026 5040 MISC
# Espero 5060 5066 PER
# Dime qué 5094 5102 MISC
# Haber 5130 5135 PER
# Discúlpame 5157 5167 PER
# Cómo 5227 5231 PER
# Hola 5250 5254 PER
# Hola 5336 5340 PER
# Lo siento.
#  5388 5399 MISC
# Mami 5399 5403 ORG
# Nena 5496 5500 LOC
# Acuérdate 5530 5539 PER
# … 5621 5622 MISC
# No pá 5674 5679 MISC
# Por favor 5745 5754 MISC
# Amigo, 5783 5789 MISC
# Cuando te pedí el dinero 5834 5858 MISC
# Por qué? 5890 5898 MISC
# Disculpa 6011 6019 MISC
# La verdad no me gustó cómo 6187 6213 MISC
# Por favor no lo vuelvas 6267 6290 MISC
# Por qué no me pagas mi dinero?
#  6377 6408 MISC
# Debes 6408 6413 ORG
# Me hace daño 6453 6465 MISC
# Por favor colabórame 6467 6487 MISC
# Cambiemos de género 6489 6508 MISC
# La gente 6510 6518 MISC
# Pon esta en  especial 6540 6561 MISC
# Sabes 6564 6569 PER
# Qué 6599 6602 PER
# Será 6625 6629 LOC
# Hola 6697 6701 PER
# Pa, hacéme 6865 6875 MISC
# Pues es que mira 6893 6909 MISC
# Mira 6977 6981 LOC
# Qué 7140 7143 PER
# Por qué estás 7159 7172 PER
# La verdad 7209 7218 MISC
# Cuéntame tú 7253 7264 MISC
# Qué te gustaría 7267 7282 ORG
# No le vuelvas 7344 7357 MISC
# Puedes 7378 7384 PER
# Recureda 7444 7452 PER
# Papá 7484 7488 PER
# No 7569 7571 LOC
# Papá 7607 7611 LOC
# Para mi cumpleaños 7650 7668 MISC
# Por favor 7707 7716 MISC
# Por favor no me mueva las cosas 7740 7771 MISC
# Papá ten más paciencia 7773 7795 MISC
# Pero ten paciencia 7888 7906 MISC
# Por qué 7909 7916 MISC
# Por favor presiona el botón 8099 8126 MISC
# Señor 8170 8175 PER
# Colócame 8400 8408 MISC
# Colócame 8437 8445 MISC
# Papá 8493 8497 PER
# Si tú lo sabes 8616 8630 MISC
# Ya pensaste qué 8676 8691 MISC
# Dímelo 8735 8741 PER
# Señor 8804 8809 PER
# Por favor dame la dirección 8883 8910 MISC
# Hemos 8960 8965 LOC
# Ehh 9094 9097 PER
# Pa! 9253 9256 MISC
# Si las vas a mover 9291 9309 MISC
# Parce 9346 9351 PER
# Amigo 9520 9525 LOC
# Y que pena!
#  9566 9578 MISC
# Amigo y a ti qué te gustaría 9578 9606 MISC
# Ehhh 9710 9714 LOC
# Hey 9759 9762 MISC
# Está 9865 9869 PER
# Si el perro quiere saludalo 9919 9946 MISC
# Además 9964 9970 MISC
# Cómo así? 10177 10186 MISC
# Y al perro 10225 10235 MISC
# Qué pena 10276 10284 MISC
# Papá 10364 10368 PER
# Oye 10414 10417 PER
# Sé 10437 10439 MISC
# Papá 10462 10466 MISC
# Perdona 10533 10540 LOC
# Dime qué 10558 10566 MISC
# Parce 10601 10606 PER
# Pá 10715 10717 MISC
# Por favor 10736 10745 MISC
# Por ahí no se pueden poner porque se dañan 10769 10811 MISC
# Eso es muy delicado 10813 10832 MISC
# Disculpe 10834 10842 LOC
# Papá 10889 10893 LOC
# … que yo me concentre 10916 10937 MISC
# Ten 11042 11045 MISC
# La fiesta está muy sabrosa 11086 11112 MISC
# Ay amiga 11158 11166 MISC
# Hey me puedes 11238 11251 MISC
# Es para animar más la fiesta….
#
#  11272 11304 MISC
# Mira 11324 11328 LOC
# Disculpa señora 11345 11360 MISC
# Papi 11389 11393 PER
# Bueno 11453 11458 PER
# Pues bueno Profe 11698 11714 MISC
# Yo creo que a veces 11774 11793 MISC
# Hey 11854 11857 MISC
# Mami 11899 11903 ORG
# Veo 12030 12033 ORG
# Disculpa 12093 12101 MISC
# Papi 12146 12150 PER
# Gracias.
#  12197 12207 LOC
# Mami 12207 12211 ORG
# Te quiero contar mis problemas 12260 12290 MISC
# El sólo 12344 12351 MISC
# Me puedes 12386 12395 MISC
# Muchas gracias.
#  12455 12471 MISC
# Papi 12471 12475 PER
# Madre 12566 12571 PER
# Cuéntame 12685 12693 LOC
# Eres 12710 12714 LOC
# Ay 12778 12780 LOC
# Tienes 12808 12814 LOC
# Mamá 12829 12833 LOC
# Estoy 12900 12905 PER
# Por qué 12921 12928 MISC
# Pero primero investiga 12962 12984 MISC
# Por qué 13154 13161 MISC
# Por qué tienes 13221 13235 MISC
# Pero por qué has 13254 13270 MISC
# Por qué tienes 13524 13538 MISC
# Por qué no me ayudas 13562 13582 MISC
# Hay que poner más orden 13696 13719 MISC
# Cómo 13879 13883 PER
# Mira 13903 13907 LOC
# Cámbiame 13939 13947 LOC
# Debes 14003 14008 ORG
# Aquí 14074 14078 PER
# Tenemos 14112 14119 ORG
# Mira 14169 14173 LOC
# Me es imposible 14381 14396 MISC
# Tú tienes más conocimiento 14398 14424 MISC
# Ya 14453 14455 MISC
# Mamá 14538 14542 PER
# Dime 14754 14758 PER
# Enctonces  cómo hacemos? 14866 14890 MISC
# Por favor dime tu 14915 14932 MISC
# Aquí 14965 14969 PER
# Por favor dime tu nombre.
#  15035 15061 MISC
# Te he dicho 15061 15072 MISC
# Realmente 15121 15130 PER
# No entiendo por que no me has pagado aún 15239 15279 MISC
# Quiero que me expliques 15281 15304 MISC
# Necesito 15350 15358 PER
# Recuerda 15454 15462 MISC
# Si no las tomas 15502 15517 MISC
# Entonces realmente es tu responsabilidad 15559 15599 MISC
# Tienes 15601 15607 PER
# Me extraña que esta música 15672 15698 MISC
# Fíjate 15771 15777 PER
# Será 15904 15908 MISC
# Recuredas 15935 15944 MISC
# Si te acuerdas 16032 16046 MISC
# Qué 16090 16093 PER
# Discúlpame 16160 16170 LOC
# Por favor 16219 16228 MISC
# Por favor me 16271 16283 MISC
# Cuéntame 16304 16312 PER
# O 16474 16475 LOC
# …si no vas a 16610 16622 MISC
# Acá 16660 16663 MISC
# Me 16723 16725 LOC
# Oye 16859 16862 PER
# Hay oye 16935 16942 MISC
# Papá 16981 16985 MISC
# Mamá 17035 17039 PER
# Págame 17088 17094 PER
# Si tienes para ir a comer sushi 17106 17137 MISC
# Entonces antes de ir allá 17173 17198 MISC
# Y después 17221 17230 MISC
# Pero primero me pagas 17292 17313 MISC
# Ten cuidado 17336 17347 MISC
# Pon mas cuidado 17409 17424 MISC
# Papá 17454 17458 MISC
# Son cosas delicadas 17501 17520 MISC
# Son… 17522 17526 MISC
# Mamá 17588 17592 PER
# Ya no eres 17656 17666 MISC
# Ya 17753 17755 MISC
# Si no te gusta mi perro 17794 17817 MISC
# Por favor 17855 17864 MISC
# Yo estoy muy ocupada 17912 17932 MISC
# Si no... 17948 17956 MISC
# Por favor tómate 18060 18076 MISC
# No las botes 18128 18140 MISC
# Mira 18168 18172 LOC
# Por favor DJ 18277 18289 MISC
# No estamos divertiendo 18337 18359 MISC
# Por favor 18386 18395 MISC
# Por favor no te 18482 18497 MISC
# Pásamela 18521 18529 PER
# Es que el juego 18536 18551 MISC
# Pásame 18595 18601 PER
# Quiero 18641 18647 PER
# Por favor papá 18660 18674 MISC
# Nunca los conocí 18742 18758 MISC
# Entonces quiero que me cuentes 18760 18790 MISC
# Yo quiero saber más.
#  18857 18878 MISC
# A mí me gusta acampar 18878 18899 MISC
# Te gustaría venir conmigo 18953 18978 ORG
# Cuando tú digas 19117 19132 MISC
# Por favor me acuerdas cómo te llamas 19150 19186 MISC
# Tienes 19189 19195 PER
# Mami 19218 19222 ORG
# Por qué le gritas 19330 19347 MISC
# Lo asusta 19349 19358 MISC
# ¡A mí 19360 19365 MISC
# Mami 19492 19496 ORG
# Por favor 19654 19663 MISC
# No recuerdo por dónde vine 19724 19750 MISC
# Estás 19775 19780 PER
# Usted 19849 19854 PER
# Qué 19888 19891 PER
# Hola 19918 19922 PER
# Hola 19951 19955 PER
# Ya te lo había advertido 20094 20118 MISC
# Qué 20120 20123 PER
# Por favor me lo retiras 20138 20161 MISC
# Hola 20163 20167 PER
# Ya te lo había advertido 20306 20330 MISC
# Qué 20332 20335 PER
# Por favor me lo retiras 20350 20373 MISC
# Ay 20375 20377 MISC
# No me ven 20508 20517 MISC
# Recuerda 20538 20546 MISC
# Ay mamá tú 20567 20577 MISC
# Y es rico 20611 20620 MISC
# Pero es que te estás 20654 20674 MISC
# Vea 20756 20759 MISC
# Cuando tú vengas 20851 20867 MISC
# Ay hola 20975 20982 MISC
# O tú me puedes 21085 21099 MISC
# Bueno 21147 21152 LOC
# Tómalelas 21392 21401 LOC
# Todos los días 21432 21446 MISC
# Ok 21521 21523 MISC
# Hey DJ 21581 21587 MISC
# Ay hermano 21628 21638 MISC
# No, dale 21727 21735 MISC
# Cambia 21737 21743 MISC
# Yo quiero que me pongas 21755 21778 MISC
# Hey 21839 21842 MISC
# Pásamela 21900 21908 PER
# Ay papá qué rico 21910 21926 MISC
# Y yo sé que usted 21993 22010 MISC
# Por ahí derecho me cuentas historias Quiero saeber 22044 22094 MISC
# Ay 22228 22230 MISC
# Ay dame la receta 22304 22321 MISC
# Ay qué pena contigo 22365 22384 MISC
# No te he 22413 22421 MISC
# Bueno 22500 22505 MISC
# Entonces dime cómo hacemos 22566 22592 MISC
# Yo hago una parte 22595 22612 MISC
# O 22676 22677 LOC
# Dime cómo hacemos 22718 22735 MISC
# Hágame 22756 22762 ORG
# Chico 22791 22796 PER
# Chica 22892 22897 PER
# Oye 23000 23003 PER
# … 23061 23062 PER
# Hola 23128 23132 PER
# Pues 23240 23244 LOC
# Amigo 23290 23295 MISC
# Porque la verdad hoy estás 23395 23421 MISC
# Hola 23483 23487 PER
# hotel Inter 23539 23550 LOC
# Oye 23626 23629 LOC
# Profe 23734 23739 LOC
# Mujer 23830 23835 LOC
# Señora 23922 23928 LOC
# Quizás 23977 23983 MISC
# No me preguntas 24024 24039 MISC
# No pongas eso tan desordenado 24050 24079 MISC
# No te metas tanto en mi vida 24081 24109 MISC
# Pásala 24129 24135 PER
# Qué te gustaría 24138 24153 ORG
# Madre 24166 24171 LOC
# Ok? 24285 24288 MISC
# Madre 24289 24294 MISC
# Voy 24334 24337 PER
# Voy 24394 24397 MISC
# ok? 24443 24446 MISC
# Padre 24447 24452 MISC
# Madre 24620 24625 LOC
# Amiga 24820 24825 MISC
# Madre 24967 24972 MISC
# Por favor me recuerda tu nombre? 25069 25101 MISC
# Papá 25102 25106 LOC
# No me interesa 25157 25171 MISC
# Sabes 25196 25201 PER
# Por favor 25231 25240 MISC
# Hey 25298 25301 MISC
# Hola 25402 25406 PER
# Hey 25521 25524 MISC
# Hola mamá 25601 25610 PER
# … 25675 25676 ORG
# Eh hola 25691 25698 MISC
# Por favor, me indicas 25715 25736 MISC
# Por favor 25759 25768 MISC
# Por favor 25847 25856 MISC
# Acuérdate 25900 25909 LOC
# Por favor 26032 26041 MISC
# A mi no me 26195 26205 MISC
# Si me ibas 26255 26265 MISC
# Si o qué? 26348 26357 MISC
# Si no tienes 26358 26370 MISC
# Mamá 26698 26702 LOC
# Por qué 26754 26761 MISC
# Dime 26788 26792 MISC
# Pues mira 26823 26832 MISC
# Por favor 26877 26886 MISC
# Pero por favor no me gusta 26919 26945 MISC
# Por favor 26972 26981 MISC
# Por favor mira 27099 27113 MISC
# Tómatelas 27139 27148 PER
# Por favor 27150 27159 MISC
# Tómate 27234 27240 LOC
# El juego 27419 27427 MISC
# Por favor, no te apoderes de la pelota. 27442 27481 MISC
# Pasa el balón 27482 27495 MISC
# Porque todas queremos divertirnos 27521 27554 MISC
# Cuéntame 27556 27564 PER
# Ay mamá 27652 27659 PER
# Amigo 27778 27783 PER
# … 27868 27869 PER
# Pero no sé 27919 27929 MISC
# Así 27944 27947 PER
# … 27956 27957 PER
# Ayúdame 28030 28037 PER
# Por favor 28083 28092 MISC
# Señora 28161 28167 ORG
# Me recuerdas tu nombre y si 28204 28231 MISC
# Cuéntame 28292 28300 LOC
# Cuéntame 28372 28380 PER
# Por qué me cojes mis cosas 28452 28478 MISC
# Me parece el colmo 28515 28533 MISC
# Madre 28588 28593 PER
# Tú 28654 28656 LOC
# Tienes 28687 28693 PER
# Me gustaría que tú me eligieras la canción para yo ponertela 28763 28823 MISC
# Hey parce 28876 28885 MISC
# Yo también estoy jugando. 28923 28948 MISC
# Mirá 28949 28953 MISC
# Ma 28972 28974 PER
# Cuando quieras… 29077 29092 MISC
# ….
#
#  29116 29120 MISC
# Pero papá 29182 29191 MISC
# Oye muchacha 29285 29297 MISC
# Oye 29357 29360 PER
# Por qué me la trajo? 29409 29429 MISC
# Oye parce 29430 29439 MISC
# No nos estorbe 29455 29469 MISC
# Hombre 29471 29477 MISC
# Hágame 29532 29538 PER
# Oye 29575 29578 PER
# Por favor 29693 29702 MISC
# Ole 29723 29726 PER
# Pásamela 29813 29821 PER
# Oye 29823 29826 PER
# Cuál 29870 29874 PER
# … De 29928 29932 PER
# Cuál 29948 29952 PER
# Por qué no nos sentamos 29990 30013 MISC
# Mama 30028 30032 PER
# Cuáles 30128 30134 PER
# Digame compa 30213 30225 PER
# Vamos al río 30265 30277 MISC
# Dígame 30299 30305 PER
# Oye 30321 30324 PER
# Muchas gracias 30386 30400 MISC
# Mamá 30402 30406 PER
# Por favor 30562 30571 MISC
# Porque él está 30704 30718 MISC
# Vea 30754 30757 MISC
# Por favor 30854 30863 MISC
# Por favor 30906 30915 MISC
# Mami 31116 31120 ORG
# Me puedes dar la fórmula 31307 31331 MISC
# Tú me acompañas? 31554 31570 MISC
# Qué te gustaría hacer 31602 31623 MISC

# %% [markdown]
# We can extend the input with some more entities:

# %%
doc = nlp(u'Ali Hassan Kuban said that Apple Inc. will buy Google in May 2018.')

# %% [markdown]
# The corresponding NE-labels are:

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Ali Hassan Kuban 0 16 PERSON
# Apple Inc. 27 37 ORG
# Google 47 53 ORG
# May 2018 57 65 DATE

# %% [markdown]
# ### Pattern Matching in spaCy

# %%
from spacy.matcher import Matcher

matcher = Matcher(nlp.vocab)
pattern = [{'LOWER': 'hello'}, {'IS_PUNCT': True}, {'LOWER': 'world'}]
matcher.add('HelloWorld', None, pattern)

doc = nlp(u'Hello, world! Hello... world!')
matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(match_id, string_id, start, end, span.text)
print("-" * 50)
doc = nlp(u'Hello, world! Hello world!')
matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]  # Get string representation
    span = doc[start:end]  # The matched span
    print(match_id, string_id, start, end, span.text)
# Out:
# 15578876784678163569 HelloWorld 0 3 Hello, world
# 15578876784678163569 HelloWorld 4 7 Hello... world
# --------------------------------------------------
# 15578876784678163569 HelloWorld 0 3 Hello, world

# %% [markdown]
# ### spaCy is Missing

# %% [markdown]
# From the linguistic standpoint, when looking at the analytical output of the NLP pipeline in spaCy, there are some important components missing:

# %% [markdown]
# - Clause boundary detection
# - Constituent structure trees (scope relations over constituents and phrases)
# - Anaphora resolution
# - Coreference analysis
# - Temporal reference resolution
# - ...

# %% [markdown]
# #### Clause Boundary Detection

# %% [markdown]
# Complex sentences consist of clauses. For precise processing of semantic properties of natural language utterances we need to segment the sentences into clauses. The following sentence:

# %% [markdown]
# *The man said that the woman claimed that the child broke the toy.*

# %% [markdown]
# can be broken into the following clauses:

# %% [markdown]
# - Matrix clause: [ *the man said* ]
# - Embedded clause: [ *that the woman claimed* ]
# - Embedded clause: [ *that the child broke the toy* ]

# %% [markdown]
# These clauses do not form an ordered list or flat sequence, they in fact are hierarchically organized. The matrix clause verb selects as its complement an embedded finite clause with the complementizer *that*. The embedded predicate *claimed* selects the same kind of clausal complement. We express this hierarchical relation in form of embedding in tree representations:

# %% [markdown]
# [ *the man said* [ *that the woman claimed* [ *that the child broke the toy* ] ] ]

# %% [markdown]
# Or using a graphical representation in form of a tree:

# %% [markdown]
# <img src="Embedded_Clauses_1.png" width="60%" height="60%">

# %% [markdown]
# The hierarchical relation of sub-clauses is relevant when it comes to semantics. The clause *John sold his car* can be interpreted as an assertion that describes an event with *John* as the agent, and *the car* as the object of a *selling* event in the past. If the clause is embedded under a matrix clause that contains a sentential negation, the proposition is assumed to NOT be true: [ *Mary did not say that* [ *John sold his car* ] ]

# %% [markdown]
# It is possible with additional effort to translate the Dependency Trees into clauses and reconstruct the clause hierarchy into a relevant form or data structure. SpaCy does not offer a direct data output of such relations.

# %% [markdown]
# One problem still remains, and this is *clausal discontinuities*. None of the common NLP pipelines, and spaCy in particular, can deal with any kind of discontinuities in any reasonable way. Discontinuities can be observed when sytanctic structures are split over the clause or sentence, or elements ocur in a cannoically different position, as in the following example:

# %% [markdown]
# *Which car did John claim that Mary took?*

# %% [markdown]
# The embedded clause consists of the sequence [ *Mary took which car* ]. One part of the sequence appears dislocated and precedes the matrix clause in the above example. Simple Dependency Parsers cannot generate any reasonable output that makes it easy to identify and reconstruct the relations of clausal elements in these structures.

# %% [markdown]
# #### Constitutent Structure Trees

# %% [markdown]
# Dependency Parse trees are a simplification of relations of elements in the clause. They ignore structural and hierarchical relations in a sentence or clause, as shown in the examples above. Instead the Dependency Parse trees show simple functional relations in the sense of sentential functions like *subject* or *object* of a verb.

# %% [markdown]
# SpaCy does not output any kind of constituent structure and more detailed relational properties of phrases and more complex structural units in a sentence or clause.

# %% [markdown]
# Since many semantic properties are defined or determined in terms of structural relations and hierarchies, that is *scope relations*, this is more complicated to reconstruct or map from the Dependency Parse trees.

# %% [markdown]
# #### Anaphora Resolution

# %% [markdown]
# SpaCy does not offer any anaphora resolution annotation. That is, the referent of a pronoun, as in the following examples, is not annotated in the resulting linguistic data structure:

# %% [markdown]
# - *John saw **him**.*
# - *John said that **he** saw the house.*
# - *Tim sold **his** house. **He** moved to Paris.*
# - *John saw **himself** in the mirror.*

# %% [markdown]
# Knowing the restrictions of pronominal binding (in English for example), we can partially generate the potential or most likely anaphora - antecedent relations. This - however - is not part of the spaCy output.

# %% [markdown]
# One problem, however, is that spaCy does not provide parse trees of the *constituent structure* and *clausal hierarchies*, which is crucial for the correct analysis of pronominal anaphoric relations.

# %% [markdown]
# #### Coreference Analysis

# %% [markdown]
# Some NLP pipelines are capable of providing coreference analyses for constituents in clauses. For example, the two clauses should be analyzed as talking about the same subject:

# %% [markdown]
# *The CEO of Apple, Tim Cook, decided to apply for a job at Google. Cook said that he is not satisfied with the quality of the iPhones anymore. He prefers the Pixel 2.*

# %% [markdown]
# The constituents [ *the CEO of Apple, Tim Cook* ] in the first sentence, [ *Cook* ] in the second sentence, and [ *he* ] in the third, should all be tagged as referencing the same entity, that is the one mentioned in the first sentence. SpaCy does not provide such a level of analysis or annotation.

# %% [markdown]
# #### Temporal Reference

# %% [markdown]
# For various analysis levels it is essential to identify the time references in a sentence or utterance, for example the time the utterance is made or the time the described event happened.

# %% [markdown]
# Certain tenses are expressed as periphrastic constructions, including auxiliaries and main verbs. SpaCy does not provide the relevant information to identify these constructions and tenses.

# %% [markdown]
# ## Using the Dependency Parse Visualizer

# %% [markdown]
# More on Dependency Parse trees

# %%
import spacy

# %% [markdown]
# We can load the visualizer:

# %%
from spacy import displacy

# %% [markdown]
# Loading the English NLP pipeline:

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# Process an input sentence:

# %%
#doc = nlp(u'John said yesterday that Mary bought a new car for her older son.')
#doc = nlp(u"Dick ran and Jane danced yesterday.")
doc = nlp(u"Tim Cook is the CEO of Apple.")
#doc = nlp(u"Born in a small town, she took the midnight train going anywhere.")
#doc = nlp(u"John met Peter and Susan called Paul.")

# %% [markdown]
# If you want to generate a visualization running code outside of the Jupyter notebook, you could use the following code. You should not use this code, if you are running the notebook. Instead, use the function *display.render* two cells below.
#
# Visualizing the Dependency Parse tree can be achieved by running the following server code and opening up a new tab on the URL [http://localhost:5000/](http://localhost:5000/). You can shut down the server by clicking on the stop button at the top in the notebook toolbar.

# %%
displacy.serve(doc, style='dep')

# %% [markdown]
# Instead of serving the graph, one can render it directly into a Jupyter Notebook:

# %%
displacy.render(doc, style='dep', jupyter=True, options={"distance": 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="556ee1ae4f0344c787c26ee570c5aeaa-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Cook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Apple.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-0" stroke-width="2px" d="M70,122.0 C70,62.0 165.0,62.0 165.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,124.0 L62,112.0 78,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-1" stroke-width="2px" d="M190,122.0 C190,62.0 285.0,62.0 285.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,124.0 L182,112.0 198,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-2" stroke-width="2px" d="M430,122.0 C430,62.0 525.0,62.0 525.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,124.0 L422,112.0 438,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-3" stroke-width="2px" d="M310,122.0 C310,2.0 530.0,2.0 530.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M530.0,124.0 L538.0,112.0 522.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-4" stroke-width="2px" d="M550,122.0 C550,62.0 645.0,62.0 645.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,124.0 L653.0,112.0 637.0,112.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-5" stroke-width="2px" d="M670,122.0 C670,62.0 765.0,62.0 765.0,122.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-556ee1ae4f0344c787c26ee570c5aeaa-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,124.0 L773.0,112.0 757.0,112.0" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# In addition to the visualization of the Dependency Trees, we can visualize named entity annotations:

# %%
text = """Apple decided to fire Tim Cook and hire somebody called John Doe as the new CEO.
They also discussed a merger with Google. On the long run it seems more likely that Apple
will merge with Amazon and Microsoft with Google. The companies will all relocate to
Austin in Texas before the end of the century."""

doc = nlp(text)
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  decided to fire
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tim Cook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and hire somebody called
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     John Doe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the new CEO.</br>They also discussed a merger with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . On the long run it seems more likely that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Apple
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# will merge with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The companies will all relocate to</br>Austin in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Texas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  before
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the end of the century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>

# %% [markdown]
# ## Vectors

# %% [markdown]
# To use vectors in spaCy, you might consider installing the larger models for the particular language. The common module and language packages only come with the small models. The larger models can be installed as described on the [spaCy vectors page](https://spacy.io/usage/vectors-similarity):
#
#     python -m spacy download en_core_web_lg
#
# The large model *en_core_web_lg* contains more than 1 million unique vectors.

# %% [markdown]
# Let us restart all necessary modules again, in particular spaCy:

# %%
import spacy

# %% [markdown]
# We can now import the English NLP pipeline to process some word list. Since the small models in spacy only include context-sensitive tensors, we should use the dowloaded large model for better word vectors. We load the large model as follows:

# %%
nlp = spacy.load('en_core_web_lg')
#nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# We can process a list of words by the pipeline using the *nlp* object:

# %%
tokens = nlp(u'dog poodle beagle cat banana apple')

# %% [markdown]
# As described in the spaCy chapter *[Word Vectors and Semantic Similarity](https://spacy.io/usage/vectors-similarity)*, the resulting elements of *Doc*, *Span*, and *Token* provide a method *similarity()*, which returns the similarities between words:

# %%
for token1 in tokens:
    for token2 in tokens:
        print(token1, token2, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog poodle 0.6750745
# dog beagle 0.66592145
# dog cat 0.80168545
# dog banana 0.24327648
# dog apple 0.2633902
# poodle dog 0.6750745
# poodle poodle 1.0
# poodle beagle 0.7116687
# poodle cat 0.573045
# poodle banana 0.22574888
# poodle apple 0.19250019
# beagle dog 0.66592145
# beagle poodle 0.7116687
# beagle beagle 1.0
# beagle cat 0.55627644
# beagle banana 0.17828682
# beagle apple 0.21266587
# cat dog 0.80168545
# cat poodle 0.573045
# cat beagle 0.55627644
# cat cat 1.0
# cat banana 0.28154367
# cat apple 0.28213844
# banana dog 0.24327648
# banana poodle 0.22574888
# banana beagle 0.17828682
# banana cat 0.28154367
# banana banana 1.0
# banana apple 0.5831844
# apple dog 0.2633902
# apple poodle 0.19250019
# apple beagle 0.21266587
# apple cat 0.28213844
# apple banana 0.5831844
# apple apple 1.0

# %% [markdown]
# We can access the *vectors* of these objects using the *vector* attribute:

# %%
tokens = nlp(u'dog cat banana sasquatch')

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# sasquatch True 6.9789977 False
# Damir True 9.316109 False

# %% [markdown]
# The attribute *has_vector* returns a boolean depending on whether the token has a vector in the model or not. The token *sasquatch* has no vector. It is also out-of-vocabulary (OOV), as the fourth column shows. Thus, it also has a norm of $0$, that is, it has a length of $0$.

# %% [markdown]
# Here the token vector has a length of $300$. We can print out the vector for a token:

# %%
n = 0
print(tokens[n].text, len(tokens[n].vector), tokens[n].vector)
# Out:
# dog 300 [-4.0176e-01  3.7057e-01  2.1281e-02 -3.4125e-01  4.9538e-02  2.9440e-01
#  -1.7376e-01 -2.7982e-01  6.7622e-02  2.1693e+00 -6.2691e-01  2.9106e-01
#  -6.7270e-01  2.3319e-01 -3.4264e-01  1.8311e-01  5.0226e-01  1.0689e+00
#   1.4698e-01 -4.5230e-01 -4.1827e-01 -1.5967e-01  2.6748e-01 -4.8867e-01
#   3.6462e-01 -4.3403e-02 -2.4474e-01 -4.1752e-01  8.9088e-02 -2.5552e-01
#  -5.5695e-01  1.2243e-01 -8.3526e-02  5.5095e-01  3.6410e-01  1.5361e-01
#   5.5738e-01 -9.0702e-01 -4.9098e-02  3.8580e-01  3.8000e-01  1.4425e-01
#  -2.7221e-01 -3.7016e-01 -1.2904e-01 -1.5085e-01 -3.8076e-01  4.9583e-02
#   1.2755e-01 -8.2788e-02  1.4339e-01  3.2537e-01  2.7226e-01  4.3632e-01
#  -3.1769e-01  7.9405e-01  2.6529e-01  1.0135e-01 -3.3279e-01  4.3117e-01
#   1.6687e-01  1.0729e-01  8.9418e-02  2.8635e-01  4.0117e-01 -3.9222e-01
#   4.5217e-01  1.3521e-01 -2.8878e-01 -2.2819e-02 -3.4975e-01 -2.2996e-01
#   2.0224e-01 -2.1177e-01  2.7184e-01  9.1703e-02 -2.0610e-01 -6.5758e-01
#   1.8949e-01 -2.6756e-01  9.2639e-02  4.3316e-01 -4.8868e-01 -3.8309e-01
#  -2.1910e-01 -4.4183e-01  9.8044e-01  6.7423e-01  8.4003e-01 -1.8169e-01
#   1.7385e-01  4.1848e-01  1.6098e-01 -1.0490e-01 -4.1965e-01 -3.5660e-01
#  -1.6837e-01 -6.3458e-01  3.8422e-01 -3.5043e-01  1.7486e-01  5.3528e-01
#   2.0143e-01  3.7877e-02  4.7105e-01 -4.4344e-01  1.6840e-01 -1.6685e-01
#  -2.4022e-01 -1.0077e-01  3.0334e-01  4.2730e-01  3.3803e-01 -4.3481e-01
#   1.1343e-01  6.1958e-02  6.1808e-02 -1.4007e-01  8.2018e-02 -3.9130e-02
#   5.1442e-02  2.8725e-01  5.8025e-01 -5.7641e-01 -3.4652e-01  1.0132e-01
#   1.4463e-01  1.1569e-02 -3.3701e-01 -1.7586e-01 -3.5724e-01 -2.1423e-01
#   1.1429e-02  4.7645e-01 -3.7463e-02 -2.9488e-01 -1.7465e-01  3.0255e-01
#   6.0317e-01 -6.6790e-02 -2.7050e+00 -7.0308e-01  4.0548e-01  6.2874e-01
#   6.3080e-01 -5.4513e-01 -9.6191e-03  2.6533e-01  2.3391e-01 -5.1886e-02
#  -6.5759e-03  1.8573e-02 -4.5693e-01 -7.0351e-02 -3.0621e-01 -1.4018e-02
#  -2.0408e-01  3.7100e-01 -3.2354e-01 -8.4646e-01  2.7092e-01 -1.1961e-01
#  -9.5576e-02 -6.0464e-01  4.2409e-02  2.4656e-01  3.8445e-02 -2.5467e-02
#  -9.2908e-02 -2.1356e-01  3.6120e-01  1.9113e-02  6.2741e-02 -1.3083e-01
#  -1.5146e-03  5.8238e-01 -1.8956e-01  7.8105e-01  1.0477e-02  1.0928e+00
#   1.0140e-01 -3.6248e-01 -1.1962e-01 -3.4462e-01 -5.5704e-01  2.5797e-01
#   3.3356e-01  3.3194e-01 -3.1298e-01 -7.5547e-01 -7.5290e-01 -9.3072e-02
#  -1.1173e-01 -5.7251e-01  1.6639e-01  6.3579e-01  2.4006e-01 -2.9211e-01
#   9.0182e-01  1.2425e-01 -5.7751e-01  4.7986e-02 -4.2748e-01  2.4446e-01
#   4.7232e-02  3.5694e-01  4.4241e-01 -2.3055e-01  6.6037e-01 -7.3983e-03
#  -3.7857e-01  2.2759e-01 -3.7138e-01  3.1055e-01 -7.2105e-02 -2.4490e-01
#  -3.9761e-02  5.3650e-01 -4.1478e-01  1.6563e-01  3.3707e-01  1.0920e-01
#   3.7219e-01 -5.5727e-01 -7.8060e-01  1.4251e-01 -3.5828e-01  4.1638e-01
#   2.1446e-01  1.8410e-01 -4.7704e-01 -2.2005e-02 -2.3634e-01 -2.2840e-01
#   3.4722e-01  2.3667e-01  7.4249e-02 -8.8416e-02  2.8618e-01 -4.6942e-01
#  -4.3914e-01 -2.6474e-01 -3.0690e-01 -1.5260e-01 -8.4870e-02  2.8410e-01
#  -1.8481e-01 -2.2122e-01 -1.1169e-01 -2.5241e-02  4.5968e-02  3.5343e-02
#   2.2467e-01  5.1556e-01 -6.5137e-04  9.9559e-02 -1.4215e-01  2.0136e-01
#   2.8334e-01 -2.8772e-01  3.7766e-02 -3.7608e-01 -1.1681e-01 -6.7020e-01
#  -4.6265e-02  3.8784e-01 -3.2295e-02 -5.4291e-02 -4.5384e-01  1.9552e-01
#  -2.9470e-01  8.5009e-01  1.0345e-01  9.7010e-02  1.1339e-01  3.9502e-01
#   5.9043e-02  2.1978e-01  1.8845e-01 -1.5891e-01 -1.0301e-01  3.3164e-01
#   6.1477e-02 -2.9848e-01  4.4510e-01  4.7329e-01  2.6312e-01 -1.8495e-01
#   1.4652e-01 -3.1510e-02  2.2908e-02 -2.5929e-01 -3.0862e-01  1.7545e-03
#  -1.8962e-01  5.4789e-01  3.1194e-01  2.4693e-01  2.9929e-01 -7.4861e-02]

# %% [markdown]
# Here just another example of similarities for some famous words:

# %%
tokens = nlp(u'queen king chef')

for token1 in tokens:
    for token2 in tokens:
        print(token1, token2, token1.similarity(token2))
# Out:
# queen queen 1.0
# queen king 0.72526103
# queen chef 0.24236034
# king queen 0.72526103
# king king 1.0
# king chef 0.2525855
# chef queen 0.24236034
# chef king 0.2525855
# chef chef 1.0

# %% [markdown]
# ### Similarities in Context

# %% [markdown]
# In spaCy parsing, tagging and NER models make use of vector representations of contexts that represent the *meaning of words*. A text *meaning representation* is represented as an array of floats, i.e. a tensor, computed during the NLP pipeline processing. With this approach words that have not been seen before can be typed or classified. SpaCy uses a 4-layer convolutional network for the computation of these tensors. In this approach these tensors model a context of four words left and right of any given word.

# %% [markdown]
# Let us use the example from the spaCy documentation and check the word *labrador*:

# %%
tokens = nlp(u'labrador')

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# labrador True 6.850418 False

# %% [markdown]
# We can now test for the context:

# %%
doc1 = nlp(u"The labrador barked.")
doc2 = nlp(u"The labrador swam.")
doc3 = nlp(u"the labrador people live in canada.")

dog = nlp(u"dog")

count = 0
for doc in [doc1, doc2, doc3]:
    lab = doc[1]
    count += 1
    print(str(count) + ":", lab.similarity(dog))
# Out:
# 1: 0.6349026162074578
# 2: 0.6349026162074578
# 3: 0.6349026162074578

# %% [markdown]
# Using this strategy we can compute document or text similarities as well:

# %%
docs = ( nlp(u"Paris is the largest city in France."),
        nlp(u"Vilnius is the capital of Lithuania."),
        nlp(u"An emu is a large bird.") )

for x in range(len(docs)):
    for y in range(len(docs)):
        print(x, y, docs[x].similarity(docs[y]))
# Out:
# 0 0 1.0
# 0 1 0.934300716500096
# 0 2 0.8682399997331975
# 1 0 0.934300716500096
# 1 1 1.0
# 1 2 0.8744093458915202
# 2 0 0.8682399997331975
# 2 1 0.8744093458915202
# 2 2 1.0

# %%
docs = ( (doc1),
        (doc2),
        (doc3) )

for x in range(len(docs)):
    for y in range(len(docs)):
        print(x, y, docs[x].similarity(docs[y]))
# Out:
# 0 0 1.0
# 0 1 0.9788525427936002
# 0 2 0.9815796034542605
# 1 0 0.9788525427936002
# 1 1 1.0
# 1 2 0.9985039291144205
# 2 0 0.9815796034542605
# 2 1 0.9985039291144205
# 2 2 1.0

# %% [markdown]
# We can vary the word order in sentences and compare them:

# %%
docs = [nlp(u"dog bites man"), nlp(u"man bites dog"),
        nlp(u"man dog bites"), nlp(u"cat eats mouse")]

for doc in docs:
    for other_doc in docs:
        print('"' + doc.text + '"', '"' + other_doc.text + '"', doc.similarity(other_doc))
# Out:
# "dog bites man" "dog bites man" 1.0
# "dog bites man" "man bites dog" 0.9999999711588186
# "dog bites man" "man dog bites" 0.9999999726761114
# "dog bites man" "cat eats mouse" 0.7096953502122842
# "man bites dog" "dog bites man" 0.9999999711588186
# "man bites dog" "man bites dog" 1.0
# "man bites dog" "man dog bites" 0.999999971568008
# "man bites dog" "cat eats mouse" 0.7096953494258684
# "man dog bites" "dog bites man" 0.9999999726761114
# "man dog bites" "man bites dog" 0.999999971568008
# "man dog bites" "man dog bites" 1.0
# "man dog bites" "cat eats mouse" 0.7096953505026842
# "cat eats mouse" "dog bites man" 0.7096953502122842
# "cat eats mouse" "man bites dog" 0.7096953494258684
# "cat eats mouse" "man dog bites" 0.7096953505026842
# "cat eats mouse" "cat eats mouse" 1.0

# %% [markdown]
# ### Custom Models

# %% [markdown]
# #### Optimization

# %%
nlp = spacy.load('en_core_web_lg')
